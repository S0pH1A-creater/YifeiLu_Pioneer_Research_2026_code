# %% [markdown]
# # RMSE index — 7-day 1-minute `2023-03-09_to_2023-03-15`
#
# Calendar week **2023-03-09 → 2023-03-15** (RTH: 9, 10, 13, 14, 15 Mar).
# Lookback **1 day**. Rolling **hourly** / **minutely**.
#
# RMSE = LSM American price vs Black–Scholes European benchmark (no 2023 listed quotes in the project options panel).

# %% [markdown]
# ### SPY — RMSE index (hourly / minutely)
#
# | Regime | Model | hourly | minutely | best rolling | file |
# |--------|-------|-------:|---------:|--------------|------|
# | 2023-03-09_to_2023-03-15 | GBM | 0.1775 | 0.1691 | `minutely` | [7d_1min_gbm.md](7d_1min_gbm.md) |
# | 2023-03-09_to_2023-03-15 | Merton | 0.1779 | 0.2332 | `hourly` | [7d_1min_merton.md](7d_1min_merton.md) |
# | 2023-03-09_to_2023-03-15 | Heston–Merton | 6.6873 | 6.7165 | `hourly` | [7d_1min_heston_merton.md](7d_1min_heston_merton.md) |
# | 2023-03-09_to_2023-03-15 | GARCH–Merton | 0.6866 | 0.7421 | `hourly` | [7d_1min_garch_merton.md](7d_1min_garch_merton.md) |

# %% [markdown]
# ### AAPL — RMSE index (hourly / minutely)
#
# | Regime | Model | hourly | minutely | best rolling | file |
# |--------|-------|-------:|---------:|--------------|------|
# | 2023-03-09_to_2023-03-15 | GBM | 0.0782 | 0.0673 | `minutely` | [7d_1min_gbm.md](7d_1min_gbm.md) |
# | 2023-03-09_to_2023-03-15 | Merton | 0.0639 | 0.0638 | `minutely` | [7d_1min_merton.md](7d_1min_merton.md) |
# | 2023-03-09_to_2023-03-15 | Heston–Merton | 3.0344 | 3.0103 | `minutely` | [7d_1min_heston_merton.md](7d_1min_heston_merton.md) |
# | 2023-03-09_to_2023-03-15 | GARCH–Merton | 0.2917 | 0.3820 | `hourly` | [7d_1min_garch_merton.md](7d_1min_garch_merton.md) |

# %% [markdown]
# ### MSFT — RMSE index (hourly / minutely)
#
# | Regime | Model | hourly | minutely | best rolling | file |
# |--------|-------|-------:|---------:|--------------|------|
# | 2023-03-09_to_2023-03-15 | GBM | 0.1840 | 0.1220 | `minutely` | [7d_1min_gbm.md](7d_1min_gbm.md) |
# | 2023-03-09_to_2023-03-15 | Merton | 0.1805 | 0.1261 | `minutely` | [7d_1min_merton.md](7d_1min_merton.md) |
# | 2023-03-09_to_2023-03-15 | Heston–Merton | 3.4993 | 2.9344 | `minutely` | [7d_1min_heston_merton.md](7d_1min_heston_merton.md) |
# | 2023-03-09_to_2023-03-15 | GARCH–Merton | 1.7023 | 0.5051 | `minutely` | [7d_1min_garch_merton.md](7d_1min_garch_merton.md) |
