# %% [markdown]
# # V2 Optimal stopping comparison — 7-day 1-minute — rolling = `hourly`
#
# **Window:** `2023-03-09_to_2023-03-15`.
# **Source:** `V2-Models_result/results/7d_1min/2023-03-09_to_2023-03-15/{TICKER}/`
# Same synthetic contracts / seeds / LSM harness for **SPY**, **AAPL**, and **MSFT** (n=24, seed=42, n_paths=2000, dte=2 trading days).
#
# Listed American quotes are 2008–2020 only, so they do not overlap this 2023 week.
# **RMSE is model LSM vs a Black–Scholes European benchmark** built from 1-minute σ on the same 24 contracts (not exchange quotes).
#
# | Fixed | Value |
# |-------|-------|
# | Window | `2023-03-09_to_2023-03-15` |
# | Lookback | 1 day |
# | Rolling | `hourly` only |
# | Underlyings | SPY, AAPL, MSFT |
#
# ## Layout
# For each ticker: GBM → Merton → Heston–Merton → GARCH–Merton.
# Each block: label + RMSE + three-panel graph.

# %% [markdown]
# # Underlying: `SPY`

# %% [markdown]
# ## Quick RMSE table — `SPY` · `hourly`
#
# | # | Regime | Model | RMSE | MAE | Bias |
# |---|--------|-------|-----:|----:|-----:|
# | 1 | 2023-03-09_to_2023-03-15 | GBM | **0.1775** | 0.1338 | 0.0868 |
# | 2 | 2023-03-09_to_2023-03-15 | Merton | **0.1779** | 0.1328 | 0.0544 |
# | 3 | 2023-03-09_to_2023-03-15 | Heston–Merton | **6.6873** | 3.6272 | 2.9591 |
# | 4 | 2023-03-09_to_2023-03-15 | GARCH–Merton | **0.6866** | 0.5403 | 0.4899 |

# %% [markdown]
# ---
#
# ## Study 1/4 — GBM · 2023-03-09_to_2023-03-15 · SPY
#
# > **underlying=`SPY` · model=`GBM` · regime=`2023-03-09_to_2023-03-15` · rolling=`hourly` · lookback=1 day**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.1775** |
# | MAE | 0.1338 |
# | Bias (model − BS bench) | 0.0868 |
# | Mean early-exercise frac | 0.511 |
#
# ### Three-panel graph — GBM · 2023-03-09_to_2023-03-15 · SPY · `hourly`
#
# ![Study 1 SPY](results/SPY/figures/7d_1min_gbm/hourly_panel.png)

# %% [markdown]
# ---
#
# ## Study 2/4 — Merton · 2023-03-09_to_2023-03-15 · SPY
#
# > **underlying=`SPY` · model=`Merton` · regime=`2023-03-09_to_2023-03-15` · rolling=`hourly` · lookback=1 day**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.1779** |
# | MAE | 0.1328 |
# | Bias (model − BS bench) | 0.0544 |
# | Mean early-exercise frac | 0.498 |
#
# ### Three-panel graph — Merton · 2023-03-09_to_2023-03-15 · SPY · `hourly`
#
# ![Study 2 SPY](results/SPY/figures/7d_1min_merton/hourly_panel.png)

# %% [markdown]
# ---
#
# ## Study 3/4 — Heston–Merton · 2023-03-09_to_2023-03-15 · SPY
#
# > **underlying=`SPY` · model=`Heston–Merton` · regime=`2023-03-09_to_2023-03-15` · rolling=`hourly` · lookback=1 day**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **6.6873** |
# | MAE | 3.6272 |
# | Bias (model − BS bench) | 2.9591 |
# | Mean early-exercise frac | 0.371 |
#
# ### Three-panel graph — Heston–Merton · 2023-03-09_to_2023-03-15 · SPY · `hourly`
#
# ![Study 3 SPY](results/SPY/figures/7d_1min_heston_merton/hourly_panel.png)

# %% [markdown]
# ---
#
# ## Study 4/4 — GARCH–Merton · 2023-03-09_to_2023-03-15 · SPY
#
# > **underlying=`SPY` · model=`GARCH–Merton` · regime=`2023-03-09_to_2023-03-15` · rolling=`hourly` · lookback=1 day**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.6866** |
# | MAE | 0.5403 |
# | Bias (model − BS bench) | 0.4899 |
# | Mean early-exercise frac | 0.475 |
#
# ### Three-panel graph — GARCH–Merton · 2023-03-09_to_2023-03-15 · SPY · `hourly`
#
# ![Study 4 SPY](results/SPY/figures/7d_1min_garch_merton/hourly_panel.png)

# %% [markdown]
# # Underlying: `AAPL`

# %% [markdown]
# ## Quick RMSE table — `AAPL` · `hourly`
#
# | # | Regime | Model | RMSE | MAE | Bias |
# |---|--------|-------|-----:|----:|-----:|
# | 1 | 2023-03-09_to_2023-03-15 | GBM | **0.0782** | 0.0627 | 0.0493 |
# | 2 | 2023-03-09_to_2023-03-15 | Merton | **0.0639** | 0.0450 | 0.0320 |
# | 3 | 2023-03-09_to_2023-03-15 | Heston–Merton | **3.0344** | 1.7296 | 1.5082 |
# | 4 | 2023-03-09_to_2023-03-15 | GARCH–Merton | **0.2917** | 0.2198 | 0.2158 |

# %% [markdown]
# ---
#
# ## Study 1/4 — GBM · 2023-03-09_to_2023-03-15 · AAPL
#
# > **underlying=`AAPL` · model=`GBM` · regime=`2023-03-09_to_2023-03-15` · rolling=`hourly` · lookback=1 day**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.0782** |
# | MAE | 0.0627 |
# | Bias (model − BS bench) | 0.0493 |
# | Mean early-exercise frac | 0.519 |
#
# ### Three-panel graph — GBM · 2023-03-09_to_2023-03-15 · AAPL · `hourly`
#
# ![Study 1 AAPL](results/AAPL/figures/7d_1min_gbm/hourly_panel.png)

# %% [markdown]
# ---
#
# ## Study 2/4 — Merton · 2023-03-09_to_2023-03-15 · AAPL
#
# > **underlying=`AAPL` · model=`Merton` · regime=`2023-03-09_to_2023-03-15` · rolling=`hourly` · lookback=1 day**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.0639** |
# | MAE | 0.0450 |
# | Bias (model − BS bench) | 0.0320 |
# | Mean early-exercise frac | 0.491 |
#
# ### Three-panel graph — Merton · 2023-03-09_to_2023-03-15 · AAPL · `hourly`
#
# ![Study 2 AAPL](results/AAPL/figures/7d_1min_merton/hourly_panel.png)

# %% [markdown]
# ---
#
# ## Study 3/4 — Heston–Merton · 2023-03-09_to_2023-03-15 · AAPL
#
# > **underlying=`AAPL` · model=`Heston–Merton` · regime=`2023-03-09_to_2023-03-15` · rolling=`hourly` · lookback=1 day**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **3.0344** |
# | MAE | 1.7296 |
# | Bias (model − BS bench) | 1.5082 |
# | Mean early-exercise frac | 0.320 |
#
# ### Three-panel graph — Heston–Merton · 2023-03-09_to_2023-03-15 · AAPL · `hourly`
#
# ![Study 3 AAPL](results/AAPL/figures/7d_1min_heston_merton/hourly_panel.png)

# %% [markdown]
# ---
#
# ## Study 4/4 — GARCH–Merton · 2023-03-09_to_2023-03-15 · AAPL
#
# > **underlying=`AAPL` · model=`GARCH–Merton` · regime=`2023-03-09_to_2023-03-15` · rolling=`hourly` · lookback=1 day**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.2917** |
# | MAE | 0.2198 |
# | Bias (model − BS bench) | 0.2158 |
# | Mean early-exercise frac | 0.477 |
#
# ### Three-panel graph — GARCH–Merton · 2023-03-09_to_2023-03-15 · AAPL · `hourly`
#
# ![Study 4 AAPL](results/AAPL/figures/7d_1min_garch_merton/hourly_panel.png)

# %% [markdown]
# # Underlying: `MSFT`

# %% [markdown]
# ## Quick RMSE table — `MSFT` · `hourly`
#
# | # | Regime | Model | RMSE | MAE | Bias |
# |---|--------|-------|-----:|----:|-----:|
# | 1 | 2023-03-09_to_2023-03-15 | GBM | **0.1840** | 0.1457 | 0.0976 |
# | 2 | 2023-03-09_to_2023-03-15 | Merton | **0.1805** | 0.1324 | 0.0871 |
# | 3 | 2023-03-09_to_2023-03-15 | Heston–Merton | **3.4993** | 2.1802 | 1.8698 |
# | 4 | 2023-03-09_to_2023-03-15 | GARCH–Merton | **1.7023** | 1.2647 | 1.2614 |

# %% [markdown]
# ---
#
# ## Study 1/4 — GBM · 2023-03-09_to_2023-03-15 · MSFT
#
# > **underlying=`MSFT` · model=`GBM` · regime=`2023-03-09_to_2023-03-15` · rolling=`hourly` · lookback=1 day**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.1840** |
# | MAE | 0.1457 |
# | Bias (model − BS bench) | 0.0976 |
# | Mean early-exercise frac | 0.509 |
#
# ### Three-panel graph — GBM · 2023-03-09_to_2023-03-15 · MSFT · `hourly`
#
# ![Study 1 MSFT](results/MSFT/figures/7d_1min_gbm/hourly_panel.png)

# %% [markdown]
# ---
#
# ## Study 2/4 — Merton · 2023-03-09_to_2023-03-15 · MSFT
#
# > **underlying=`MSFT` · model=`Merton` · regime=`2023-03-09_to_2023-03-15` · rolling=`hourly` · lookback=1 day**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.1805** |
# | MAE | 0.1324 |
# | Bias (model − BS bench) | 0.0871 |
# | Mean early-exercise frac | 0.519 |
#
# ### Three-panel graph — Merton · 2023-03-09_to_2023-03-15 · MSFT · `hourly`
#
# ![Study 2 MSFT](results/MSFT/figures/7d_1min_merton/hourly_panel.png)

# %% [markdown]
# ---
#
# ## Study 3/4 — Heston–Merton · 2023-03-09_to_2023-03-15 · MSFT
#
# > **underlying=`MSFT` · model=`Heston–Merton` · regime=`2023-03-09_to_2023-03-15` · rolling=`hourly` · lookback=1 day**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **3.4993** |
# | MAE | 2.1802 |
# | Bias (model − BS bench) | 1.8698 |
# | Mean early-exercise frac | 0.323 |
#
# ### Three-panel graph — Heston–Merton · 2023-03-09_to_2023-03-15 · MSFT · `hourly`
#
# ![Study 3 MSFT](results/MSFT/figures/7d_1min_heston_merton/hourly_panel.png)

# %% [markdown]
# ---
#
# ## Study 4/4 — GARCH–Merton · 2023-03-09_to_2023-03-15 · MSFT
#
# > **underlying=`MSFT` · model=`GARCH–Merton` · regime=`2023-03-09_to_2023-03-15` · rolling=`hourly` · lookback=1 day**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.7023** |
# | MAE | 1.2647 |
# | Bias (model − BS bench) | 1.2614 |
# | Mean early-exercise frac | 0.532 |
#
# ### Three-panel graph — GARCH–Merton · 2023-03-09_to_2023-03-15 · MSFT · `hourly`
#
# ![Study 4 MSFT](results/MSFT/figures/7d_1min_garch_merton/hourly_panel.png)
