# %% [markdown]
# # V2 Optimal stopping comparison — 7-day 1-minute — rolling = `minutely`
#
# **Window:** `2023-03-09_to_2023-03-15`.
# **Source:** `V2-Models_result/results/7d_1min/2023-03-09_to_2023-03-15/{TICKER}/`
# Same synthetic contracts / seeds / LSM harness for **SPY**, **AAPL**, and **MSFT** (n=24, seed=42, n_paths=2000, dte=2 trading days).
#
# Listed American quotes are 2008–2020 only, so they do not overlap this 2023 week.
# **RMSE is model LSM vs a Black–Scholes European benchmark** built from 1-minute σ on the same 24 contracts (not exchange quotes).
#
# | Fixed | Value |
# |-------|-------|
# | Window | `2023-03-09_to_2023-03-15` |
# | Lookback | 1 day |
# | Rolling | `minutely` only |
# | Underlyings | SPY, AAPL, MSFT |
#
# ## Layout
# For each ticker: GBM → Merton → Heston–Merton → GARCH–Merton.
# Each block: label + RMSE + three-panel graph.

# %% [markdown]
# # Underlying: `SPY`

# %% [markdown]
# ## Quick RMSE table — `SPY` · `minutely`
#
# | # | Regime | Model | RMSE | MAE | Bias |
# |---|--------|-------|-----:|----:|-----:|
# | 1 | 2023-03-09_to_2023-03-15 | GBM | **0.1691** | 0.1265 | 0.1044 |
# | 2 | 2023-03-09_to_2023-03-15 | Merton | **0.2332** | 0.1705 | 0.1199 |
# | 3 | 2023-03-09_to_2023-03-15 | Heston–Merton | **6.7165** | 3.6485 | 2.9442 |
# | 4 | 2023-03-09_to_2023-03-15 | GARCH–Merton | **0.7421** | 0.6056 | 0.5457 |

# %% [markdown]
# ---
#
# ## Study 1/4 — GBM · 2023-03-09_to_2023-03-15 · SPY
#
# > **underlying=`SPY` · model=`GBM` · regime=`2023-03-09_to_2023-03-15` · rolling=`minutely` · lookback=1 day**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.1691** |
# | MAE | 0.1265 |
# | Bias (model − BS bench) | 0.1044 |
# | Mean early-exercise frac | 0.508 |
#
# ### Three-panel graph — GBM · 2023-03-09_to_2023-03-15 · SPY · `minutely`
#
# ![Study 1 SPY](results/SPY/figures/7d_1min_gbm/minutely_panel.png)

# %% [markdown]
# ---
#
# ## Study 2/4 — Merton · 2023-03-09_to_2023-03-15 · SPY
#
# > **underlying=`SPY` · model=`Merton` · regime=`2023-03-09_to_2023-03-15` · rolling=`minutely` · lookback=1 day**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.2332** |
# | MAE | 0.1705 |
# | Bias (model − BS bench) | 0.1199 |
# | Mean early-exercise frac | 0.494 |
#
# ### Three-panel graph — Merton · 2023-03-09_to_2023-03-15 · SPY · `minutely`
#
# ![Study 2 SPY](results/SPY/figures/7d_1min_merton/minutely_panel.png)

# %% [markdown]
# ---
#
# ## Study 3/4 — Heston–Merton · 2023-03-09_to_2023-03-15 · SPY
#
# > **underlying=`SPY` · model=`Heston–Merton` · regime=`2023-03-09_to_2023-03-15` · rolling=`minutely` · lookback=1 day**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **6.7165** |
# | MAE | 3.6485 |
# | Bias (model − BS bench) | 2.9442 |
# | Mean early-exercise frac | 0.419 |
#
# ### Three-panel graph — Heston–Merton · 2023-03-09_to_2023-03-15 · SPY · `minutely`
#
# ![Study 3 SPY](results/SPY/figures/7d_1min_heston_merton/minutely_panel.png)

# %% [markdown]
# ---
#
# ## Study 4/4 — GARCH–Merton · 2023-03-09_to_2023-03-15 · SPY
#
# > **underlying=`SPY` · model=`GARCH–Merton` · regime=`2023-03-09_to_2023-03-15` · rolling=`minutely` · lookback=1 day**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.7421** |
# | MAE | 0.6056 |
# | Bias (model − BS bench) | 0.5457 |
# | Mean early-exercise frac | 0.499 |
#
# ### Three-panel graph — GARCH–Merton · 2023-03-09_to_2023-03-15 · SPY · `minutely`
#
# ![Study 4 SPY](results/SPY/figures/7d_1min_garch_merton/minutely_panel.png)

# %% [markdown]
# # Underlying: `AAPL`

# %% [markdown]
# ## Quick RMSE table — `AAPL` · `minutely`
#
# | # | Regime | Model | RMSE | MAE | Bias |
# |---|--------|-------|-----:|----:|-----:|
# | 1 | 2023-03-09_to_2023-03-15 | GBM | **0.0673** | 0.0515 | 0.0474 |
# | 2 | 2023-03-09_to_2023-03-15 | Merton | **0.0638** | 0.0432 | 0.0345 |
# | 3 | 2023-03-09_to_2023-03-15 | Heston–Merton | **3.0103** | 1.6808 | 1.4579 |
# | 4 | 2023-03-09_to_2023-03-15 | GARCH–Merton | **0.3820** | 0.2545 | -0.0511 |

# %% [markdown]
# ---
#
# ## Study 1/4 — GBM · 2023-03-09_to_2023-03-15 · AAPL
#
# > **underlying=`AAPL` · model=`GBM` · regime=`2023-03-09_to_2023-03-15` · rolling=`minutely` · lookback=1 day**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.0673** |
# | MAE | 0.0515 |
# | Bias (model − BS bench) | 0.0474 |
# | Mean early-exercise frac | 0.517 |
#
# ### Three-panel graph — GBM · 2023-03-09_to_2023-03-15 · AAPL · `minutely`
#
# ![Study 1 AAPL](results/AAPL/figures/7d_1min_gbm/minutely_panel.png)

# %% [markdown]
# ---
#
# ## Study 2/4 — Merton · 2023-03-09_to_2023-03-15 · AAPL
#
# > **underlying=`AAPL` · model=`Merton` · regime=`2023-03-09_to_2023-03-15` · rolling=`minutely` · lookback=1 day**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.0638** |
# | MAE | 0.0432 |
# | Bias (model − BS bench) | 0.0345 |
# | Mean early-exercise frac | 0.514 |
#
# ### Three-panel graph — Merton · 2023-03-09_to_2023-03-15 · AAPL · `minutely`
#
# ![Study 2 AAPL](results/AAPL/figures/7d_1min_merton/minutely_panel.png)

# %% [markdown]
# ---
#
# ## Study 3/4 — Heston–Merton · 2023-03-09_to_2023-03-15 · AAPL
#
# > **underlying=`AAPL` · model=`Heston–Merton` · regime=`2023-03-09_to_2023-03-15` · rolling=`minutely` · lookback=1 day**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **3.0103** |
# | MAE | 1.6808 |
# | Bias (model − BS bench) | 1.4579 |
# | Mean early-exercise frac | 0.345 |
#
# ### Three-panel graph — Heston–Merton · 2023-03-09_to_2023-03-15 · AAPL · `minutely`
#
# ![Study 3 AAPL](results/AAPL/figures/7d_1min_heston_merton/minutely_panel.png)

# %% [markdown]
# ---
#
# ## Study 4/4 — GARCH–Merton · 2023-03-09_to_2023-03-15 · AAPL
#
# > **underlying=`AAPL` · model=`GARCH–Merton` · regime=`2023-03-09_to_2023-03-15` · rolling=`minutely` · lookback=1 day**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.3820** |
# | MAE | 0.2545 |
# | Bias (model − BS bench) | -0.0511 |
# | Mean early-exercise frac | 0.507 |
#
# ### Three-panel graph — GARCH–Merton · 2023-03-09_to_2023-03-15 · AAPL · `minutely`
#
# ![Study 4 AAPL](results/AAPL/figures/7d_1min_garch_merton/minutely_panel.png)

# %% [markdown]
# # Underlying: `MSFT`

# %% [markdown]
# ## Quick RMSE table — `MSFT` · `minutely`
#
# | # | Regime | Model | RMSE | MAE | Bias |
# |---|--------|-------|-----:|----:|-----:|
# | 1 | 2023-03-09_to_2023-03-15 | GBM | **0.1220** | 0.0936 | 0.0823 |
# | 2 | 2023-03-09_to_2023-03-15 | Merton | **0.1261** | 0.0966 | 0.0763 |
# | 3 | 2023-03-09_to_2023-03-15 | Heston–Merton | **2.9344** | 1.7415 | 1.4045 |
# | 4 | 2023-03-09_to_2023-03-15 | GARCH–Merton | **0.5051** | 0.4384 | 0.4384 |

# %% [markdown]
# ---
#
# ## Study 1/4 — GBM · 2023-03-09_to_2023-03-15 · MSFT
#
# > **underlying=`MSFT` · model=`GBM` · regime=`2023-03-09_to_2023-03-15` · rolling=`minutely` · lookback=1 day**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.1220** |
# | MAE | 0.0936 |
# | Bias (model − BS bench) | 0.0823 |
# | Mean early-exercise frac | 0.510 |
#
# ### Three-panel graph — GBM · 2023-03-09_to_2023-03-15 · MSFT · `minutely`
#
# ![Study 1 MSFT](results/MSFT/figures/7d_1min_gbm/minutely_panel.png)

# %% [markdown]
# ---
#
# ## Study 2/4 — Merton · 2023-03-09_to_2023-03-15 · MSFT
#
# > **underlying=`MSFT` · model=`Merton` · regime=`2023-03-09_to_2023-03-15` · rolling=`minutely` · lookback=1 day**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.1261** |
# | MAE | 0.0966 |
# | Bias (model − BS bench) | 0.0763 |
# | Mean early-exercise frac | 0.514 |
#
# ### Three-panel graph — Merton · 2023-03-09_to_2023-03-15 · MSFT · `minutely`
#
# ![Study 2 MSFT](results/MSFT/figures/7d_1min_merton/minutely_panel.png)

# %% [markdown]
# ---
#
# ## Study 3/4 — Heston–Merton · 2023-03-09_to_2023-03-15 · MSFT
#
# > **underlying=`MSFT` · model=`Heston–Merton` · regime=`2023-03-09_to_2023-03-15` · rolling=`minutely` · lookback=1 day**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.9344** |
# | MAE | 1.7415 |
# | Bias (model − BS bench) | 1.4045 |
# | Mean early-exercise frac | 0.408 |
#
# ### Three-panel graph — Heston–Merton · 2023-03-09_to_2023-03-15 · MSFT · `minutely`
#
# ![Study 3 MSFT](results/MSFT/figures/7d_1min_heston_merton/minutely_panel.png)

# %% [markdown]
# ---
#
# ## Study 4/4 — GARCH–Merton · 2023-03-09_to_2023-03-15 · MSFT
#
# > **underlying=`MSFT` · model=`GARCH–Merton` · regime=`2023-03-09_to_2023-03-15` · rolling=`minutely` · lookback=1 day**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.5051** |
# | MAE | 0.4384 |
# | Bias (model − BS bench) | 0.4384 |
# | Mean early-exercise frac | 0.512 |
#
# ### Three-panel graph — GARCH–Merton · 2023-03-09_to_2023-03-15 · MSFT · `minutely`
#
# ![Study 4 MSFT](results/MSFT/figures/7d_1min_garch_merton/minutely_panel.png)
