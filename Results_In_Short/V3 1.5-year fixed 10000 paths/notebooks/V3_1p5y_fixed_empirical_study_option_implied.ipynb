# %% [markdown]
# # V3 empirical study — 1.5-year fixed calibration — option-implied Heston family
#
# **This notebook is the computational source of truth.** The PDF in this folder is written from the same `payload` dict, so every table number matches.
#
# | Item | Setting |
# |------|---------|
# | Models | Heston, Heston–Merton |
# | Companies | SPY (primary), AAPL, MSFT, AMZN |
# | Regimes | Crisis 2008-08-01→2009-07-31 · Normal 2014-01-01→2014-12-31 · Late-cycle 2018-10-01→2019-09-30 · COVID 2019-09-01→2020-08-31 |
# | Calibration | **1.5-year** lookback, **none** recalibration |
# | Primary metric | Percentage RMSE |
# | Secondary | MAE, Bias $ (model − market), Bias%, Early-exercise fraction |
# | Paths | LSM American calls, `n_paths=10000`, `seed=42` |
# | Code | V3 notebooks + `option_filters.py` + Euler-corrected Heston step |
#
# In every table the **BEST** model is the lowest RMSE%. That row is **bold and green**.

# %% [markdown]
# ## 0. Methodology and conditions
#
# ### No look-ahead
# At the first session t0 of each 1-year evaluation window, parameters use only returns and listed quotes with `trading_date ≤ t0`. Those parameters are held for every Monday contract in the window. LSM prices each contract with that single calibration row. Option quotes are as-of the grid timestamp (same session, else the prior session).
#
# ### Shared sample (no model-specific data selection)
# For each company × regime the Monday nearest-ATM listed-call sample is drawn **once** and passed to all two models in this report. Filters, testing dates, simulation settings, and the market benchmark are therefore identical.
#
# ### Filters (applied in this order)
# 1. Calls only; finite S, K, C.
# 2. No-arbitrage: C ≥ max(0, S−K).
# 3. Maturity: 7 ≤ DTE ≤ 60.
# 4. Moneyness: |S/K − 1| ≤ 10%.
# 5. Liquidity: premium ≥ 0.05; valid bid–ask and relative spread ≤ 50% when those columns exist; volume ≥ 1 when present.
#
# ### Metrics
# - Primary: RMSE%.
# - Secondary: MAE (dollars), Bias $ = mean(model − market), **Bias% = 100 × mean((model − market)/market)**, early-exercise fraction.
# - Ranking uses RMSE% only. The dollar bias column is kept; Bias% is the scale-free companion.
#
# ### Model-correctness adjustments
# - Heston / Heston–Merton: option-implied Fourier NLS for (κ, θ, ξ, ρ, v0). Not Method A.
# - Euler: stock return over [t, t+Δt] uses **current** v_t; then update v_{t+Δt}.
# - LSM never averages paths before stopping.
#
# ### Data limits
# Equity adj-close starts **2003-12-01**. Listed-option panels start **2008-01**. Estimators use all available history when the requested lookback is longer than the file.
#
# ### Re-run
# This notebook is a grouped companion. It loads stored cells and does **not** re-run LSM. To rebuild only this group's PDF/notebook, call `groups.write_group(...)`. Do not set RECOMPUTE on the six-model engine; that would overwrite the original study files.

# %%
import sys
from pathlib import Path
from IPython.display import display, HTML, Markdown, Image
ROOT = Path.cwd()
for cand in [ROOT, *ROOT.parents]:
    scripts = cand / 'V3-Models_result' / 'scripts'
    if scripts.exists():
        sys.path.insert(0, str(scripts))
        break
import run_v3_1p5y_10k_monthly_empirical_study_groups as groups
payload = groups.load_group('option_implied')
print('cells', len(payload['cells']), 'models', payload['meta']['models'])
# Rebuild this group's PDF/notebook only (does not overwrite the six-model study):
# groups.write_group('option_implied')
# Out:
# <pre>cells 32 models ['Heston', 'Heston–Merton']</pre>

# %% [markdown]
# ## 1. Shared evaluation sample

# %%
from IPython.display import HTML, display
rows = ['<h4>n contracts (identical across models)</h4>']
display(HTML(''.join(study._html_table(payload['tables'][k]) if False else '')))
meta = payload['shared_contracts']
import pandas as pd
df = pd.DataFrame([{ 'regime': r, **meta[r]['n'], 'start': meta[r]['period_start'], 'end': meta[r]['period_end']} for r in study.REGIME_ORDER])
display(df)
# Out:
# <h2>1. Shared evaluation sample</h2><p>One Monday ATM listed-call sample per company × regime. Copied to all two models in this report.</p><table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;'><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;'>Regime</th><th style='background:#1F3A5F;color:white;padding:6px 8px;'>Window</th><th style='background:#1F3A5F;color:white;padding:6px 8px;'>SPY</th><th style='background:#1F3A5F;color:white;padding:6px 8px;'>AAPL</th><th style='background:#1F3A5F;color:white;padding:6px 8px;'>MSFT</th><th style='background:#1F3A5F;color:white;padding:6px 8px;'>AMZN</th></tr><tr><td style='padding:5px 8px;border:1px solid #D0D5DD;'>2008-2009 Crisis</td><td style='padding:5px 8px;border:1px solid #D0D5DD;'>2008-08-01 → 2009-07-31</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td></tr><tr><td style='padding:5px 8px;border:1px solid #D0D5DD;'>2013-2014 Normal</td><td style='padding:5px 8px;border:1px solid #D0D5DD;'>2014-01-01 → 2014-12-31</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td></tr><tr><td style='padding:5px 8px;border:1px solid #D0D5DD;'>2018-2019 Late-cycle</td><td style='padding:5px 8px;border:1px solid #D0D5DD;'>2018-10-01 → 2019-09-30</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>51</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>51</td></tr><tr><td style='padding:5px 8px;border:1px solid #D0D5DD;'>2019-2020 COVID</td><td style='padding:5px 8px;border:1px solid #D0D5DD;'>2019-09-01 → 2020-08-31</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td></tr></table>

# %% [markdown]
# ## 2.1 Detailed tables — `SPY`

# %% [markdown]
# ### Table SPY-1. SPY · 2008-2009 · Crisis
#
# 2008-08-01 → 2009-07-31 · n = 50 contracts · **BEST = Heston–Merton** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['SPY|2008-2009'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>37.99</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.4513</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-1.1865</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-24.31</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>29.0%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston–Merton</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>37.76</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.4404</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-1.1711</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-23.83</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>27.2%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr></tbody></table>

# %% [markdown]
# ### Table SPY-2. SPY · 2013-2014 · Normal
#
# 2014-01-01 → 2014-12-31 · n = 50 contracts · **BEST = Heston** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['SPY|2013-2014'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>80.89</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.6010</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+1.5789</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+70.66</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>25.2%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston–Merton</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>80.98</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.6058</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+1.5835</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+70.80</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>25.2%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr></tbody></table>

# %% [markdown]
# ### Table SPY-3. SPY · 2018-2019 · Late-cycle
#
# 2018-10-01 → 2019-09-30 · n = 50 contracts · **BEST = Heston–Merton** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['SPY|2018-2019'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>26.62</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.9285</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.1483</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+7.58</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>19.5%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston–Merton</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.17</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.9016</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.3351</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-3.49</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>11.7%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr></tbody></table>

# %% [markdown]
# ### Table SPY-4. SPY · 2019-2020 · COVID
#
# 2019-09-01 → 2020-08-31 · n = 50 contracts · **BEST = Heston** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['SPY|2019-2020'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>80.30</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3.3486</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.8238</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+44.02</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>30.1%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston–Merton</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>86.96</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3.5301</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+1.2470</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+51.47</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.5%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr></tbody></table>

# %% [markdown]
# ## 2.2 Detailed tables — `AAPL`

# %% [markdown]
# ### Table AAPL-1. AAPL · 2008-2009 · Crisis
#
# 2008-08-01 → 2009-07-31 · n = 50 contracts · **BEST = Heston** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['AAPL|2008-2009'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>34.03</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.7307</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2640</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+1.23</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>22.3%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston–Merton</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>34.10</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.7166</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2799</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+1.17</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>19.5%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr></tbody></table>

# %% [markdown]
# ### Table AAPL-2. AAPL · 2013-2014 · Normal
#
# 2014-01-01 → 2014-12-31 · n = 50 contracts · **BEST = Heston** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['AAPL|2013-2014'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>58.84</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3.9883</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+3.9883</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+52.30</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>19.8%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston–Merton</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>58.99</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3.9831</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+3.9831</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+52.19</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>17.1%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr></tbody></table>

# %% [markdown]
# ### Table AAPL-3. AAPL · 2018-2019 · Late-cycle
#
# 2018-10-01 → 2019-09-30 · n = 51 contracts · **BEST = Heston–Merton** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['AAPL|2018-2019'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>31.34</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.5900</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+1.3922</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+23.98</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>19.8%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston–Merton</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>21.47</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.0270</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.5515</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+10.59</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>22.7%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr></tbody></table>

# %% [markdown]
# ### Table AAPL-4. AAPL · 2019-2020 · COVID
#
# 2019-09-01 → 2020-08-31 · n = 50 contracts · **BEST = Heston** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['AAPL|2019-2020'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>45.09</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3.3073</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+1.1657</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+23.85</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>26.1%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston–Merton</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>45.11</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3.3287</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+1.1442</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+23.69</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>20.6%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr></tbody></table>

# %% [markdown]
# ## 2.3 Detailed tables — `MSFT`

# %% [markdown]
# ### Table MSFT-1. MSFT · 2008-2009 · Crisis
#
# 2008-08-01 → 2009-07-31 · n = 50 contracts · **BEST = Heston** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['MSFT|2008-2009'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>27.04</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.3008</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2200</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-14.34</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>27.4%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston–Merton</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>27.09</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.3016</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2193</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-14.22</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.5%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr></tbody></table>

# %% [markdown]
# ### Table MSFT-2. MSFT · 2013-2014 · Normal
#
# 2014-01-01 → 2014-12-31 · n = 50 contracts · **BEST = Heston** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['MSFT|2013-2014'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>62.26</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.4275</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.4254</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+52.75</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>24.5%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston–Merton</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>62.79</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.4308</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.4271</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+53.09</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>18.6%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr></tbody></table>

# %% [markdown]
# ### Table MSFT-3. MSFT · 2018-2019 · Late-cycle
#
# 2018-10-01 → 2019-09-30 · n = 50 contracts · **BEST = Heston** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['MSFT|2018-2019'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>28.71</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.7076</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.4085</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+15.07</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>22.6%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston–Merton</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>30.54</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.7557</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.4887</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+17.50</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>20.4%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr></tbody></table>

# %% [markdown]
# ### Table MSFT-4. MSFT · 2019-2020 · COVID
#
# 2019-09-01 → 2020-08-31 · n = 50 contracts · **BEST = Heston–Merton** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['MSFT|2019-2020'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>47.96</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.7733</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.1593</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+19.55</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>25.7%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston–Merton</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>45.23</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.7365</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0483</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+15.57</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>21.2%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr></tbody></table>

# %% [markdown]
# ## 2.4 Detailed tables — `AMZN`

# %% [markdown]
# ### Table AMZN-1. AMZN · 2008-2009 · Crisis
#
# 2008-08-01 → 2009-07-31 · n = 50 contracts · **BEST = Heston–Merton** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['AMZN|2008-2009'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>29.77</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.2161</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.3467</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-3.72</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>24.3%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston–Merton</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>28.96</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.1935</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.5002</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-7.24</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>14.4%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr></tbody></table>

# %% [markdown]
# ### Table AMZN-2. AMZN · 2013-2014 · Normal
#
# 2014-01-01 → 2014-12-31 · n = 50 contracts · **BEST = Heston–Merton** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['AMZN|2013-2014'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>59.01</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>5.2473</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+5.1382</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+49.55</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>19.3%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston–Merton</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>44.80</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3.7149</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+3.3705</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+34.36</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>21.4%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr></tbody></table>

# %% [markdown]
# ### Table AMZN-3. AMZN · 2018-2019 · Late-cycle
#
# 2018-10-01 → 2019-09-30 · n = 51 contracts · **BEST = Heston–Merton** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['AMZN|2018-2019'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>53.74</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>24.7431</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+22.4495</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+40.39</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>19.5%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston–Merton</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>48.52</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>21.8398</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+18.6520</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+34.17</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>18.0%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr></tbody></table>

# %% [markdown]
# ### Table AMZN-4. AMZN · 2019-2020 · COVID
#
# 2019-09-01 → 2020-08-31 · n = 50 contracts · **BEST = Heston** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['AMZN|2019-2020'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>39.20</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.2576</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-2.6623</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+12.80</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>28.2%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston–Merton</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>58.56</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>27.2428</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+15.5745</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+37.07</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>19.1%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr></tbody></table>

# %% [markdown]
# ## 3. Summary tables

# %% [markdown]
# ### Table S1 — Overall ranking

# %%
display(HTML('overall ranking table is rendered from payload["summary_overall"]'))
# Out:
# <h3>Table S1 · Overall ranking (mean RMSE% over 16 cells)</h3><table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;'><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;'>Rank</th><th style='background:#1F3A5F;color:white;padding:6px 8px;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;'>Mean RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;'>Median RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;'># cells best</th></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston–Merton BEST</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>45.94</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>44.95</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>7</td></tr><tr><td style='background:#F4F7FB;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td><td style='background:#F4F7FB;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#F4F7FB;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>46.43</td><td style='background:#F4F7FB;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>42.15</td><td style='background:#F4F7FB;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>9</td></tr></table>

# %% [markdown]
# ## 4. Figures

# %% [markdown]
# ### Figure 1 — RMSE% by regime (mean of four companies)

# %%
pass  # figure embedded from the same payload used for the PDF

# %% [markdown]
# ### Figure 2 — RMSE% by company

# %%
pass

# %% [markdown]
# ### Figure 3 — Rank heatmap

# %%
pass

# %% [markdown]
# ## 5. Final analysis
#
# - On mean percentage RMSE across the 16 company×regime cells, Heston–Merton is the best overall model (mean RMSE% = 45.94; 7 of 16 cells).
#
# - Second overall is Heston (mean RMSE% = 46.43; 9 cells).
#
# - The ranking is not stable. Best-in-cell models across the 16 tables: Heston, Heston–Merton.
#
# - SPY: lowest mean RMSE% is Heston (56.45); wins 2 of 4 regimes.
#
# - AAPL: lowest mean RMSE% is Heston–Merton (39.92); wins 1 of 4 regimes.
#
# - MSFT: lowest mean RMSE% is Heston–Merton (41.41); wins 1 of 4 regimes.
#
# - AMZN: lowest mean RMSE% is Heston–Merton (45.21); wins 3 of 4 regimes.
#
# - 2008-2009 (Crisis): best mean RMSE% is Heston–Merton (31.98).
#
# - 2013-2014 (Normal): best mean RMSE% is Heston–Merton (61.89).
#
# - 2018-2019 (Late-cycle): best mean RMSE% is Heston–Merton (30.93).
#
# - 2019-2020 (COVID): best mean RMSE% is Heston (53.14).
#
# - Jump models as a group have lower mean RMSE% (45.94) than the no-jump models in this report (46.43).
#
# - For the overall winner (Heston–Merton), crisis RMSE% is 31.98 vs 61.89 in the 2014 normal year — absolute pricing error is regime-dependent even when the ranking is not.
#
# - These conclusions are conditional on the V3 filters, 1.5-year fixed calibration, Monday ATM sample, LSM with 10,000 paths, and American-call quotes only. They are not a statement about European options or other tenors.

# %% [markdown]
# ## 6. Reproducibility
#
# This grouped report is assembled from the frozen 10,000-path cells. No new calibration or LSM.
#
# ```python
# import run_v3_1p5y_10k_monthly_empirical_study_groups as groups
# payload = groups.load_group('option_implied')
# groups.write_group('option_implied')
# ```
#
# The original six-model files `V3_1p5y_monthly_empirical_study.pdf` / `.ipynb` are not rewritten.
# Partial results remain in `V3-Models_result/results/empirical_study_1p5y_fixed_10000/partial/`.
# Shared contracts are frozen in `shared_contracts.json`.
