# %% [markdown]
# # V3 empirical study — 1.5-year fixed calibration — return-based models
#
# **This notebook is the computational source of truth.** The PDF in this folder is written from the same `payload` dict, so every table number matches.
#
# | Item | Setting |
# |------|---------|
# | Models | GBM, Modified GBM, GARCH, Merton, GARCH–Merton |
# | Companies | SPY (primary), AAPL, MSFT, AMZN |
# | Regimes | Crisis 2008-08-01→2009-07-31 · Normal 2014-01-01→2014-12-31 · Late-cycle 2018-10-01→2019-09-30 · COVID 2019-09-01→2020-08-31 |
# | Calibration | **1.5-year** lookback, **none** recalibration |
# | Primary metric | Percentage RMSE |
# | Secondary | MAE, Bias $ (model − market), Bias%, Early-exercise fraction |
# | Paths | LSM American calls, `n_paths=10000`, `seed=42` |
# | Code | V3 notebooks + `option_filters.py` + Euler-corrected Heston step |
#
# In every table the **BEST** model is the lowest RMSE%. That row is **bold and green**.

# %% [markdown]
# ## 0. Methodology and conditions
#
# ### No look-ahead
# At the first session t0 of each 1-year evaluation window, parameters use only returns and listed quotes with `trading_date ≤ t0`. Those parameters are held for every Monday contract in the window. LSM prices each contract with that single calibration row. Option quotes are as-of the grid timestamp (same session, else the prior session).
#
# ### Shared sample (no model-specific data selection)
# For each company × regime the Monday nearest-ATM listed-call sample is drawn **once** and passed to all five models in this report. Filters, testing dates, simulation settings, and the market benchmark are therefore identical.
#
# ### Filters (applied in this order)
# 1. Calls only; finite S, K, C.
# 2. No-arbitrage: C ≥ max(0, S−K).
# 3. Maturity: 7 ≤ DTE ≤ 60.
# 4. Moneyness: |S/K − 1| ≤ 10%.
# 5. Liquidity: premium ≥ 0.05; valid bid–ask and relative spread ≤ 50% when those columns exist; volume ≥ 1 when present.
#
# ### Metrics
# - Primary: RMSE%.
# - Secondary: MAE (dollars), Bias $ = mean(model − market), **Bias% = 100 × mean((model − market)/market)**, early-exercise fraction.
# - Ranking uses RMSE% only. The dollar bias column is kept; Bias% is the scale-free companion.
#
# ### Model-correctness adjustments
# - Heston / Heston–Merton: option-implied Fourier NLS for (κ, θ, ξ, ρ, v0). Not Method A.
# - Euler: stock return over [t, t+Δt] uses **current** v_t; then update v_{t+Δt}.
# - LSM never averages paths before stopping.
#
# ### Data limits
# Equity adj-close starts **2003-12-01**. Listed-option panels start **2008-01**. Estimators use all available history when the requested lookback is longer than the file.
#
# ### Re-run
# This notebook is a grouped companion. It loads stored cells and does **not** re-run LSM. To rebuild only this group's PDF/notebook, call `groups.write_group(...)`. Do not set RECOMPUTE on the six-model engine; that would overwrite the original study files.

# %%
import sys
from pathlib import Path
from IPython.display import display, HTML, Markdown, Image
ROOT = Path.cwd()
for cand in [ROOT, *ROOT.parents]:
    scripts = cand / 'V3-Models_result' / 'scripts'
    if scripts.exists():
        sys.path.insert(0, str(scripts))
        break
import run_v3_1p5y_10k_monthly_empirical_study_groups as groups
payload = groups.load_group('return_based')
print('cells', len(payload['cells']), 'models', payload['meta']['models'])
# Rebuild this group's PDF/notebook only (does not overwrite the six-model study):
# groups.write_group('return_based')
# Out:
# <pre>cells 80 models ['GBM', 'Modified GBM', 'GARCH', 'Merton', 'GARCH–Merton']</pre>

# %% [markdown]
# ## 1. Shared evaluation sample

# %%
from IPython.display import HTML, display
rows = ['<h4>n contracts (identical across models)</h4>']
display(HTML(''.join(study._html_table(payload['tables'][k]) if False else '')))
meta = payload['shared_contracts']
import pandas as pd
df = pd.DataFrame([{ 'regime': r, **meta[r]['n'], 'start': meta[r]['period_start'], 'end': meta[r]['period_end']} for r in study.REGIME_ORDER])
display(df)
# Out:
# <h2>1. Shared evaluation sample</h2><p>One Monday ATM listed-call sample per company × regime. Copied to all five models in this report.</p><table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;'><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;'>Regime</th><th style='background:#1F3A5F;color:white;padding:6px 8px;'>Window</th><th style='background:#1F3A5F;color:white;padding:6px 8px;'>SPY</th><th style='background:#1F3A5F;color:white;padding:6px 8px;'>AAPL</th><th style='background:#1F3A5F;color:white;padding:6px 8px;'>MSFT</th><th style='background:#1F3A5F;color:white;padding:6px 8px;'>AMZN</th></tr><tr><td style='padding:5px 8px;border:1px solid #D0D5DD;'>2008-2009 Crisis</td><td style='padding:5px 8px;border:1px solid #D0D5DD;'>2008-08-01 → 2009-07-31</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td></tr><tr><td style='padding:5px 8px;border:1px solid #D0D5DD;'>2013-2014 Normal</td><td style='padding:5px 8px;border:1px solid #D0D5DD;'>2014-01-01 → 2014-12-31</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td></tr><tr><td style='padding:5px 8px;border:1px solid #D0D5DD;'>2018-2019 Late-cycle</td><td style='padding:5px 8px;border:1px solid #D0D5DD;'>2018-10-01 → 2019-09-30</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>51</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>51</td></tr><tr><td style='padding:5px 8px;border:1px solid #D0D5DD;'>2019-2020 COVID</td><td style='padding:5px 8px;border:1px solid #D0D5DD;'>2019-09-01 → 2020-08-31</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td></tr></table>

# %% [markdown]
# ## 2.1 Detailed tables — `SPY`

# %% [markdown]
# ### Table SPY-1. SPY · 2008-2009 · Crisis
#
# 2008-08-01 → 2009-07-31 · n = 50 contracts · **BEST = GARCH–Merton** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['SPY|2008-2009'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>39.85</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.5118</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-1.3570</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-29.27</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>25.5%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>43.13</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.6255</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-1.5635</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-35.30</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>26.1%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>5</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>35.72</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.3442</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.8523</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-14.47</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>21.6%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>39.86</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.5142</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-1.3598</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-29.38</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>24.3%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4</td></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH–Merton</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>35.69</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:cente ...

# %% [markdown]
# ### Table SPY-2. SPY · 2013-2014 · Normal
#
# 2014-01-01 → 2014-12-31 · n = 50 contracts · **BEST = Merton** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['SPY|2013-2014'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>40.10</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.7145</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.5358</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+27.51</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>26.2%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>41.67</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.7464</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.5698</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+29.03</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>26.1%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>40.43</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.7184</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.5469</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+27.93</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.4%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3</td></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>39.30</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.7016</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.5143</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+26.61</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>24.2%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH–Merton</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>45.88</td><td style='background:white ...

# %% [markdown]
# ### Table SPY-3. SPY · 2018-2019 · Late-cycle
#
# 2018-10-01 → 2019-09-30 · n = 50 contracts · **BEST = GARCH–Merton** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['SPY|2018-2019'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.62</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.8840</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.1277</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+1.81</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>20.8%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.03</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.8902</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2283</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.59</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>22.2%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>25.80</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.0497</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.8867</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-16.54</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>17.2%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>5</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.41</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.8884</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.1839</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.37</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>14.3%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3</td></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH–Merton</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>22.86</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;' ...

# %% [markdown]
# ### Table SPY-4. SPY · 2019-2020 · COVID
#
# 2019-09-01 → 2020-08-31 · n = 50 contracts · **BEST = Merton** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['SPY|2019-2020'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>57.52</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2.9208</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.5111</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+18.64</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>24.3%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>59.99</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2.9847</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.3345</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+21.88</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.9%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>63.77</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3.0315</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0942</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+26.41</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>21.2%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4</td></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>56.08</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2.9267</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.6252</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+16.46</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>20.8%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH–Merton</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>70.25</td><td style='background:white ...

# %% [markdown]
# ## 2.2 Detailed tables — `AAPL`

# %% [markdown]
# ### Table AAPL-1. AAPL · 2008-2009 · Crisis
#
# 2008-08-01 → 2009-07-31 · n = 50 contracts · **BEST = Modified GBM** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['AAPL|2008-2009'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>34.70</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.7325</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2012</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+2.49</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.4%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3</td></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>32.72</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.6706</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.6554</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-4.84</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>24.4%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>40.04</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.9147</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.4172</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+12.21</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>17.2%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>34.26</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.7225</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2873</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.95</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>21.0%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH–Merton</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>43.53</td><td style='background:white;pa ...

# %% [markdown]
# ### Table AAPL-2. AAPL · 2013-2014 · Normal
#
# 2014-01-01 → 2014-12-31 · n = 50 contracts · **BEST = GARCH** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['AAPL|2013-2014'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>57.70</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3.8194</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+3.8194</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+51.38</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>24.4%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>51.10</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3.3484</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+3.3484</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+44.85</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>25.7%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>45.96</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2.9301</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+2.9021</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+39.06</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>20.4%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>52.75</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3.5099</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+3.5099</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+46.69</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>20.4%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH–Merton</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>67.13</td><td style='ba ...

# %% [markdown]
# ### Table AAPL-3. AAPL · 2018-2019 · Late-cycle
#
# 2018-10-01 → 2019-09-30 · n = 51 contracts · **BEST = GARCH** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['AAPL|2018-2019'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>16.77</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.8809</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.5584</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-7.11</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.8%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>16.88</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.8919</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.5478</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-6.91</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>24.5%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3</td></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>16.17</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.8273</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.3825</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-4.32</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>19.9%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>17.13</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.9184</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.6295</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-8.25</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>21.1%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH–Merton</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>17.34</td><td style='backgr ...

# %% [markdown]
# ### Table AAPL-4. AAPL · 2019-2020 · COVID
#
# 2019-09-01 → 2020-08-31 · n = 50 contracts · **BEST = Merton** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['AAPL|2019-2020'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>41.39</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3.1111</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.6446</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+18.83</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>24.0%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>43.50</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3.2399</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.9173</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+21.54</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>24.2%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>54.11</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3.9481</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+2.2445</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+34.15</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>20.1%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4</td></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>39.55</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3.0542</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.3844</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+16.28</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>20.1%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH–Merton</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>68.46</td><td style='background:white ...

# %% [markdown]
# ## 2.3 Detailed tables — `MSFT`

# %% [markdown]
# ### Table MSFT-1. MSFT · 2008-2009 · Crisis
#
# 2008-08-01 → 2009-07-31 · n = 50 contracts · **BEST = Modified GBM** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['MSFT|2008-2009'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>29.17</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.3120</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2729</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-19.88</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>25.5%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>28.96</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.3119</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2681</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-19.42</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>26.3%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>29.41</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.2879</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.0218</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+8.10</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>19.6%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>30.20</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.3213</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2903</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-21.66</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.7%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH–Merton</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>32.88</td><td style='background:white; ...

# %% [markdown]
# ### Table MSFT-2. MSFT · 2013-2014 · Normal
#
# 2014-01-01 → 2014-12-31 · n = 50 contracts · **BEST = Merton** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['MSFT|2013-2014'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>62.49</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.4284</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.4262</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+52.88</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>24.7%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>60.58</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.4138</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.4100</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+51.07</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>26.0%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>73.22</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.5232</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.5232</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+63.91</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>21.0%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4</td></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>55.05</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.3688</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.3615</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+45.40</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>17.6%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH–Merton</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>96.85</td><td style='background:white ...

# %% [markdown]
# ### Table MSFT-3. MSFT · 2018-2019 · Late-cycle
#
# 2018-10-01 → 2019-09-30 · n = 50 contracts · **BEST = Modified GBM** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['MSFT|2018-2019'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>21.68</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.5626</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.0129</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+3.25</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.0%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4</td></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>19.94</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.5524</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2155</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-3.65</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>25.4%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>20.87</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.5485</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0844</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.24</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>18.6%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>21.14</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.5548</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0675</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.85</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>17.2%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH–Merton</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>25.36</td><td style='background:white;pad ...

# %% [markdown]
# ### Table MSFT-4. MSFT · 2019-2020 · COVID
#
# 2019-09-01 → 2020-08-31 · n = 50 contracts · **BEST = Modified GBM** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['MSFT|2019-2020'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>45.98</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.7242</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.0264</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+16.93</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>24.8%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4</td></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>41.04</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.7043</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.3996</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+8.84</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>25.5%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>45.83</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.7300</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.0064</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+16.56</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>20.1%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>45.04</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.7309</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0492</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+15.51</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>21.8%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH–Merton</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>53.39</td><td style='background:white; ...

# %% [markdown]
# ## 2.4 Detailed tables — `AMZN`

# %% [markdown]
# ### Table AMZN-1. AMZN · 2008-2009 · Crisis
#
# 2008-08-01 → 2009-07-31 · n = 50 contracts · **BEST = Modified GBM** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['AMZN|2008-2009'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>32.38</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.2336</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0334</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+3.64</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>22.9%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>29.85</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.2017</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.4075</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-4.77</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>25.2%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>38.93</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.3651</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.4984</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+15.15</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>15.9%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>32.42</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.2247</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0467</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+3.32</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>17.7%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH–Merton</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>53.16</td><td style='background:white;pa ...

# %% [markdown]
# ### Table AMZN-2. AMZN · 2013-2014 · Normal
#
# 2014-01-01 → 2014-12-31 · n = 50 contracts · **BEST = Merton** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['AMZN|2013-2014'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.09</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2.4183</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.0489</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+5.54</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>24.8%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>22.52</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2.3818</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0168</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+4.90</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>25.5%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>25.31</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2.4409</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.5868</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+10.13</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>19.9%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4</td></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>22.03</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2.3804</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.1930</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+3.35</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>19.9%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH–Merton</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>35.61</td><td style='background:white;pa ...

# %% [markdown]
# ### Table AMZN-3. AMZN · 2018-2019 · Late-cycle
#
# 2018-10-01 → 2019-09-30 · n = 51 contracts · **BEST = GBM** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['AMZN|2018-2019'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>22.97</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>12.4353</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-5.5218</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-4.77</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>22.9%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.72</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>12.4787</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-3.3465</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-1.02</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>21.5%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.59</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>12.6060</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-2.9523</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.74</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>18.5%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.70</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>12.7887</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-8.1593</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-9.42</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>15.5%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH–Merton</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>28.66</td><td style='ba ...

# %% [markdown]
# ### Table AMZN-4. AMZN · 2019-2020 · COVID
#
# 2019-09-01 → 2020-08-31 · n = 50 contracts · **BEST = GARCH** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['AMZN|2019-2020'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>56.86</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>26.5091</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+13.6258</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+35.54</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.7%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>60.74</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>27.6000</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+16.4384</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+39.62</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>22.9%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>5</td></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>41.58</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.0490</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.2550</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+16.22</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>21.4%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>55.02</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>26.1281</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+12.4842</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+33.71</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>21.1%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH–Merton</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>44.57</td><td st ...

# %% [markdown]
# ## 3. Summary tables

# %% [markdown]
# ### Table S1 — Overall ranking

# %%
display(HTML('overall ranking table is rendered from payload["summary_overall"]'))
# Out:
# <h3>Table S1 · Overall ranking (mean RMSE% over 16 cells)</h3><table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;'><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;'>Rank</th><th style='background:#1F3A5F;color:white;padding:6px 8px;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;'>Mean RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;'>Median RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;'># cells best</th></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton BEST</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>36.68</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>36.78</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>5</td></tr><tr><td style='background:#F4F7FB;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td><td style='background:#F4F7FB;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#F4F7FB;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>37.46</td><td style='background:#F4F7FB;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>36.88</td><td style='background:#F4F7FB;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>5</td></tr><tr><td style='background:white;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3</td><td style='background:white;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:white;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>37.89</td><td style='background:white;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>37.28</td><td style='background:white;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:#F4F7FB;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4</td><td style='background:#F4F7FB;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:#F4F7FB;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>38.80</td><td style='background:#F4F7FB;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>39.48</td><td style='background:#F4F7FB;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3</td></tr><tr><td style='background:white;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>5</td><td style='background:white;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH–Merton</td><td style='background:white;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>46.35</td><td style='background:white;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>44.05</td><td style='background:white;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr></table>

# %% [markdown]
# ## 4. Figures

# %% [markdown]
# ### Figure 1 — RMSE% by regime (mean of four companies)

# %%
pass  # figure embedded from the same payload used for the PDF

# %% [markdown]
# ### Figure 2 — RMSE% by company

# %%
pass

# %% [markdown]
# ### Figure 3 — Rank heatmap

# %%
pass

# %% [markdown]
# ## 5. Final analysis
#
# - On mean percentage RMSE across the 16 company×regime cells, Merton is the best overall model (mean RMSE% = 36.68; 5 of 16 cells).
#
# - Second overall is Modified GBM (mean RMSE% = 37.46; 5 cells).
#
# - The ranking is not stable. Best-in-cell models across the 16 tables: GARCH, GARCH–Merton, GBM, Merton, Modified GBM.
#
# - SPY: lowest mean RMSE% is Merton (39.66); wins 2 of 4 regimes.
#
# - AAPL: lowest mean RMSE% is Merton (35.92); wins 1 of 4 regimes.
#
# - MSFT: lowest mean RMSE% is Modified GBM (37.63); wins 3 of 4 regimes.
#
# - AMZN: lowest mean RMSE% is GARCH (32.35); wins 1 of 4 regimes.
#
# - 2008-2009 (Crisis): best mean RMSE% is Modified GBM (33.66).
#
# - 2013-2014 (Normal): best mean RMSE% is Merton (42.28).
#
# - 2018-2019 (Late-cycle): best mean RMSE% is Modified GBM (20.89).
#
# - 2019-2020 (COVID): best mean RMSE% is Merton (48.92).
#
# - No-jump models as a group have lower mean RMSE% (38.05) than the jump models in this report (41.52).
#
# - For the overall winner (Merton), crisis RMSE% is 34.18 vs 42.28 in the 2014 normal year — absolute pricing error is regime-dependent even when the ranking is not.
#
# - These conclusions are conditional on the V3 filters, 1.5-year fixed calibration, Monday ATM sample, LSM with 10,000 paths, and American-call quotes only. They are not a statement about European options or other tenors.

# %% [markdown]
# ## 6. Reproducibility
#
# This grouped report is assembled from the frozen 10,000-path cells. No new calibration or LSM.
#
# ```python
# import run_v3_1p5y_10k_monthly_empirical_study_groups as groups
# payload = groups.load_group('return_based')
# groups.write_group('return_based')
# ```
#
# The original six-model files `V3_1p5y_monthly_empirical_study.pdf` / `.ipynb` are not rewritten.
# Partial results remain in `V3-Models_result/results/empirical_study_1p5y_fixed_10000/partial/`.
# Shared contracts are frozen in `shared_contracts.json`.
