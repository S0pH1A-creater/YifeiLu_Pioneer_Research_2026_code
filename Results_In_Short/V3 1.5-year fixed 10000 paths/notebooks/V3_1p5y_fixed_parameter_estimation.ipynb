# %% [markdown]
# # V3 parameter estimation — 1.5-year fixed calibration
#
# **This notebook is the computational source of truth.** The matching PDF is written from the same payload.
#
# `calibrate_ticker` paths for `V3 1.5-year fixed 10000 paths`. **No LSM.**
#
# | Item | Setting |
# |------|---------|
# | Lookback | 18 months ending at each update |
# | Rolling | `none` |
# | Names | SPY, AAPL, MSFT, AMZN |
# | Windows | R1 Crisis, R2 Normal, R3 Late-cycle, R4 COVID |
# | Cell | Mean, SD, Min, Max of the estimates inside that regime |

# %% [markdown]
# ## Table P1. GBM

# %%
from IPython.display import display, HTML
display(HTML(pe._html_table('GBM', payload)))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:12px;width:100%;'><thead><tr><th rowspan='2' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;text-align:left;'>Regime / param</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SPY</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AAPL</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MSFT</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AMZN</th></tr><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:wh
# ...

# %% [markdown]
# Notes: This table reports Mean, SD, Min, and Max of the none GBM estimates for SPY, AAPL, MSFT, AMZN. Parameters are μ, σ. Each company×regime cell is one estimate: 18-month lookback ending on the first session of the window, held for the year. n is 1. SD is undefined with a single update (shown as —). This is parameter estimation only; it is not an LSM pricing table.

# %% [markdown]
# ## Table P2. Modified GBM

# %%
from IPython.display import display, HTML
display(HTML(pe._html_table('Modified GBM', payload)))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:12px;width:100%;'><thead><tr><th rowspan='2' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;text-align:left;'>Regime / param</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SPY</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AAPL</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MSFT</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AMZN</th></tr><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:wh
# ...

# %% [markdown]
# Notes: This table reports Mean, SD, Min, and Max of the none Modified GBM estimates for SPY, AAPL, MSFT, AMZN. Parameters are P(U|U), P(D|D), P(U|D), P(D|U), μ_U, σ_U, μ_D, σ_D. Each company×regime cell is one estimate: 18-month lookback ending on the first session of the window, held for the year. n is 1. SD is undefined with a single update (shown as —). This is parameter estimation only; it is not an LSM pricing table.

# %% [markdown]
# ## Table P3. GARCH

# %%
from IPython.display import display, HTML
display(HTML(pe._html_table('GARCH', payload)))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:12px;width:100%;'><thead><tr><th rowspan='2' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;text-align:left;'>Regime / param</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SPY</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AAPL</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MSFT</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AMZN</th></tr><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:wh
# ...

# %% [markdown]
# Notes: This table reports Mean, SD, Min, and Max of the none GARCH estimates for SPY, AAPL, MSFT, AMZN. Parameters are μ, ω, α, β, σ₀. Each company×regime cell is one estimate: 18-month lookback ending on the first session of the window, held for the year. n is 1. SD is undefined with a single update (shown as —). This is parameter estimation only; it is not an LSM pricing table.

# %% [markdown]
# ## Table P4. Heston

# %%
from IPython.display import display, HTML
display(HTML(pe._html_table('Heston', payload)))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:12px;width:100%;'><thead><tr><th rowspan='2' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;text-align:left;'>Regime / param</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SPY</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AAPL</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MSFT</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AMZN</th></tr><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:wh
# ...

# %% [markdown]
# Notes: This table reports Mean, SD, Min, and Max of the none Heston estimates for SPY, AAPL, MSFT, AMZN. Parameters are μ, κ, θ, ξ, ρ, v₀. Each company×regime cell is one estimate: 18-month lookback ending on the first session of the window, held for the year. n is 1. SD is undefined with a single update (shown as —). This is parameter estimation only; it is not an LSM pricing table.

# %% [markdown]
# ## Table P5. Merton

# %%
from IPython.display import display, HTML
display(HTML(pe._html_table('Merton', payload)))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:12px;width:100%;'><thead><tr><th rowspan='2' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;text-align:left;'>Regime / param</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SPY</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AAPL</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MSFT</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AMZN</th></tr><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:wh
# ...

# %% [markdown]
# Notes: This table reports Mean, SD, Min, and Max of the none Merton estimates for SPY, AAPL, MSFT, AMZN. Parameters are μ, σ, λ, μ_J, σ_J, κ. Each company×regime cell is one estimate: 18-month lookback ending on the first session of the window, held for the year. n is 1. SD is undefined with a single update (shown as —). This is parameter estimation only; it is not an LSM pricing table.

# %% [markdown]
# ## Table P6. GARCH–Merton

# %%
from IPython.display import display, HTML
display(HTML(pe._html_table('GARCH–Merton', payload)))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:12px;width:100%;'><thead><tr><th rowspan='2' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;text-align:left;'>Regime / param</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SPY</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AAPL</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MSFT</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AMZN</th></tr><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:wh
# ...

# %% [markdown]
# Notes: This table reports Mean, SD, Min, and Max of the none GARCH–Merton estimates for SPY, AAPL, MSFT, AMZN. Parameters are μ, ω, α, β, σ₀, λ, μ_J, σ_J, κ. Each company×regime cell is one estimate: 18-month lookback ending on the first session of the window, held for the year. n is 1. SD is undefined with a single update (shown as —). This is parameter estimation only; it is not an LSM pricing table.

# %% [markdown]
# ## Table P7. Heston–Merton

# %%
from IPython.display import display, HTML
display(HTML(pe._html_table('Heston–Merton', payload)))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:12px;width:100%;'><thead><tr><th rowspan='2' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;text-align:left;'>Regime / param</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SPY</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AAPL</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MSFT</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AMZN</th></tr><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:wh
# ...

# %% [markdown]
# Notes: This table reports Mean, SD, Min, and Max of the none Heston–Merton estimates for SPY, AAPL, MSFT, AMZN. Parameters are μ, κ, θ, ξ, ρ, v₀, λ, μ_J, σ_J, κ_J. Each company×regime cell is one estimate: 18-month lookback ending on the first session of the window, held for the year. n is 1. SD is undefined with a single update (shown as —). This is parameter estimation only; it is not an LSM pricing table.

# %% [markdown]
# ## Re-run
#
# ```python
# import run_v3_1p5y_10k_monthly_parameter_estimation as pe
# payload = pe.run()
# ```
