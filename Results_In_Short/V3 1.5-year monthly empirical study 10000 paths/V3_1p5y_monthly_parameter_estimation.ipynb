# %% [markdown]
# # V3 parameter estimation — 1.5-year monthly rolling
#
# **This notebook is the computational source of truth.** The matching PDF is written from the same payload.
#
# Monthly `calibrate_ticker` paths for `V3 1.5-year monthly empirical study 10000 paths`. **No LSM.**
#
# | Item | Setting |
# |------|---------|
# | Lookback | 18 months ending at each update |
# | Rolling | monthly (month-ends plus the first session of the regime) |
# | Names | SPY, AAPL, MSFT |
# | Windows | R1 Crisis, R2 Normal, R3 Late-cycle, R4 COVID |
# | Cell | Mean, SD, Min, Max of the monthly estimates inside that regime |

# %% [markdown]
# ## Table P1. GBM

# %%
from IPython.display import display, HTML
display(HTML(pe._html_table('GBM', payload)))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:12px;width:100%;'><thead><tr><th rowspan='2' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;text-align:left;'>Regime / param</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SPY</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AAPL</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MSFT</th></tr><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th></tr></thead><tbody><tr><td colspan='13' style='background:#D9E2EC;color:#1F3A5F;font-weight:700;padding:6px 8px;border:1px solid #D0D5DD;'>R1  Crisis  (n = 13)</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:left;'>μ</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2873</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.1250</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.4424</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0608</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0499</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.2597</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2648</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.4609</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2249</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.1181</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.3572</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0067</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:left;'>σ</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.3262</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0777</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.1852</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.3895</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.5106</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0533</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.4040</td><td style='backg ...

# %% [markdown]
# Notes: This table reports Mean, SD, Min, and Max of the monthly rolling GBM estimates for SPY, AAPL, and MSFT. Parameters are μ, σ. Each month-end update uses an 18-month lookback ending on that date, with no look-ahead. R1–R4 are Crisis, Normal, Late-cycle, and COVID. n is the number of monthly updates in that regime. SD is the sample standard deviation across those monthly estimates. This is parameter estimation only; it is not an LSM pricing table.

# %% [markdown]
# ## Table P2. GARCH

# %%
from IPython.display import display, HTML
display(HTML(pe._html_table('GARCH', payload)))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:12px;width:100%;'><thead><tr><th rowspan='2' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;text-align:left;'>Regime / param</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SPY</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AAPL</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MSFT</th></tr><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th></tr></thead><tbody><tr><td colspan='13' style='background:#D9E2EC;color:#1F3A5F;font-weight:700;padding:6px 8px;border:1px solid #D0D5DD;'>R1  Crisis  (n = 13)</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:left;'>μ</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.1456</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0959</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2885</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0217</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.4332</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.2065</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.2063</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.7693</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.1228</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0870</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2561</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0147</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:left;'>ω</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>5.787e-06</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.579e-06</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2.695e-06</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>7.491e-06</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4.737e-05</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.436e-05</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.423e-05</td ...

# %% [markdown]
# Notes: This table reports Mean, SD, Min, and Max of the monthly rolling GARCH estimates for SPY, AAPL, and MSFT. Parameters are μ, ω, α, β, σ₀. Each month-end update uses an 18-month lookback ending on that date, with no look-ahead. R1–R4 are Crisis, Normal, Late-cycle, and COVID. n is the number of monthly updates in that regime. SD is the sample standard deviation across those monthly estimates. This is parameter estimation only; it is not an LSM pricing table.

# %% [markdown]
# ## Table P3. Heston

# %%
from IPython.display import display, HTML
display(HTML(pe._html_table('Heston', payload)))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:12px;width:100%;'><thead><tr><th rowspan='2' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;text-align:left;'>Regime / param</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SPY</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AAPL</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MSFT</th></tr><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th></tr></thead><tbody><tr><td colspan='13' style='background:#D9E2EC;color:#1F3A5F;font-weight:700;padding:6px 8px;border:1px solid #D0D5DD;'>R1  Crisis  (n = 13)</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:left;'>μ</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2873</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.1250</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.4424</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0608</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0499</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.2597</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2648</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.4609</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2249</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.1181</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.3572</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0067</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:left;'>κ</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>12.0625</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>6.0476</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4.8057</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>20.0000</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>8.5388</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>7.2924</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.7342</td><td style='bac ...

# %% [markdown]
# Notes: This table reports Mean, SD, Min, and Max of the monthly rolling Heston estimates for SPY, AAPL, and MSFT. Parameters are μ, κ, θ, ξ, ρ, v₀. Each month-end update uses an 18-month lookback ending on that date, with no look-ahead. R1–R4 are Crisis, Normal, Late-cycle, and COVID. n is the number of monthly updates in that regime. SD is the sample standard deviation across those monthly estimates. This is parameter estimation only; it is not an LSM pricing table.

# %% [markdown]
# ## Table P4. Merton

# %%
from IPython.display import display, HTML
display(HTML(pe._html_table('Merton', payload)))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:12px;width:100%;'><thead><tr><th rowspan='2' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;text-align:left;'>Regime / param</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SPY</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AAPL</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MSFT</th></tr><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th></tr></thead><tbody><tr><td colspan='13' style='background:#D9E2EC;color:#1F3A5F;font-weight:700;padding:6px 8px;border:1px solid #D0D5DD;'>R1  Crisis  (n = 13)</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:left;'>μ</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2184</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0900</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.3501</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0707</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0013</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.2783</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2261</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.5259</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.3118</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.2108</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.5198</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0731</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:left;'>σ</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.2709</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0606</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.1725</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.3288</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.4442</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0414</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.3678</td><td style='backgro ...

# %% [markdown]
# Notes: This table reports Mean, SD, Min, and Max of the monthly rolling Merton estimates for SPY, AAPL, and MSFT. Parameters are μ, σ, λ, μ_J, σ_J, κ. Each month-end update uses an 18-month lookback ending on that date, with no look-ahead. R1–R4 are Crisis, Normal, Late-cycle, and COVID. n is the number of monthly updates in that regime. SD is the sample standard deviation across those monthly estimates. This is parameter estimation only; it is not an LSM pricing table.

# %% [markdown]
# ## Table P5. GARCH–Merton

# %%
from IPython.display import display, HTML
display(HTML(pe._html_table('GARCH–Merton', payload)))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:12px;width:100%;'><thead><tr><th rowspan='2' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;text-align:left;'>Regime / param</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SPY</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AAPL</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MSFT</th></tr><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th></tr></thead><tbody><tr><td colspan='13' style='background:#D9E2EC;color:#1F3A5F;font-weight:700;padding:6px 8px;border:1px solid #D0D5DD;'>R1  Crisis  (n = 13)</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:left;'>μ</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.1456</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0959</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2885</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0217</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.4332</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.2065</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.2063</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.7693</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.1228</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0870</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2561</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0147</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:left;'>ω</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>5.787e-06</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.579e-06</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2.695e-06</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>7.491e-06</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4.737e-05</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.436e-05</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.423e-05</td ...

# %% [markdown]
# Notes: This table reports Mean, SD, Min, and Max of the monthly rolling GARCH–Merton estimates for SPY, AAPL, and MSFT. Parameters are μ, ω, α, β, σ₀, λ, μ_J, σ_J, κ. Each month-end update uses an 18-month lookback ending on that date, with no look-ahead. R1–R4 are Crisis, Normal, Late-cycle, and COVID. n is the number of monthly updates in that regime. SD is the sample standard deviation across those monthly estimates. This is parameter estimation only; it is not an LSM pricing table.

# %% [markdown]
# ## Table P6. Heston–Merton

# %%
from IPython.display import display, HTML
display(HTML(pe._html_table('Heston–Merton', payload)))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:12px;width:100%;'><thead><tr><th rowspan='2' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;text-align:left;'>Regime / param</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SPY</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AAPL</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MSFT</th></tr><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th></tr></thead><tbody><tr><td colspan='13' style='background:#D9E2EC;color:#1F3A5F;font-weight:700;padding:6px 8px;border:1px solid #D0D5DD;'>R1  Crisis  (n = 13)</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:left;'>μ</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2873</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.1250</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.4424</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0608</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0499</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.2597</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2648</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.4609</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2249</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.1181</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.3572</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0067</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:left;'>κ</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>7.6185</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>6.2638</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.9153</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>20.0000</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>9.1102</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>7.4299</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.4376</td><td style='back ...

# %% [markdown]
# Notes: This table reports Mean, SD, Min, and Max of the monthly rolling Heston–Merton estimates for SPY, AAPL, and MSFT. Parameters are μ, κ, θ, ξ, ρ, v₀, λ, μ_J, σ_J, κ_J. Each month-end update uses an 18-month lookback ending on that date, with no look-ahead. R1–R4 are Crisis, Normal, Late-cycle, and COVID. n is the number of monthly updates in that regime. SD is the sample standard deviation across those monthly estimates. This is parameter estimation only; it is not an LSM pricing table.

# %% [markdown]
# ## Re-run
#
# ```python
# import run_v3_1p5y_10k_monthly_parameter_estimation as pe
# payload = pe.run()
# ```
