# %% [markdown]
# # V3 stock-price study — 7-day hourly calibration
#
# **This notebook is the computational source of truth.** The PDF is written from the same payload.
#
# P-measure rolling clouds vs realized S_t. Reported path = **p50**. `n_paths = 10000`, Δt = 5 min, seed 42. Horizon = window Friday 15:59.

# %%
import sys
from pathlib import Path
from IPython.display import display, HTML
ROOT = Path.cwd()
for cand in [ROOT, *ROOT.parents]:
    scripts = cand / 'V3-Models_result' / 'scripts'
    if scripts.exists():
        sys.path.insert(0, str(scripts))
        break
import run_v3_7d_hourly_stock_study as study
payload = study.run_or_load(recompute=False)
print('cells', len(payload['cells']), 'failures', payload['meta']['failures'])
# Out:
# <pre>cells 216 failures []</pre>

# %% [markdown]
# ## SPY

# %% [markdown]
# ### Table SPY-1  ·  Oct 2022  ·  n = 391  ·  BEST = Heston–Merton

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td>
# ...

# %% [markdown]
# ### Table SPY-2  ·  Nov 2022  ·  n = 391  ·  BEST = GARCH

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td>
# ...

# %% [markdown]
# ### Table SPY-3  ·  Dec 2022  ·  n = 391  ·  BEST = GARCH

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td>
# ...

# %% [markdown]
# ### Table SPY-4  ·  Jan 2023  ·  n = 391  ·  BEST = Heston

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td>
# ...

# %% [markdown]
# ### Table SPY-5  ·  Feb 2023  ·  n = 391  ·  BEST = GARCH–Merton

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td>
# ...

# %% [markdown]
# ### Table SPY-6  ·  Mar 2023  ·  n = 391  ·  BEST = GARCH–Merton

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td>
# ...

# %% [markdown]
# ### Table SPY-7  ·  Apr 2023  ·  n = 391  ·  BEST = Heston

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td>
# ...

# %% [markdown]
# ### Table SPY-8  ·  May 2023  ·  n = 391  ·  BEST = GBM

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align
# ...

# %% [markdown]
# ### Table SPY-9  ·  Jun 2023  ·  n = 390  ·  BEST = GBM

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align
# ...

# %% [markdown]
# ### Table SPY-10  ·  Jul 2023  ·  n = 391  ·  BEST = Merton

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td>
# ...

# %% [markdown]
# ### Table SPY-11  ·  Aug 2023  ·  n = 391  ·  BEST = GBM

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align
# ...

# %% [markdown]
# ### Table SPY-12  ·  Sep 2023  ·  n = 391  ·  BEST = GBM

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align
# ...

# %% [markdown]
# ## AAPL

# %% [markdown]
# ### Table AAPL-1  ·  Oct 2022  ·  n = 391  ·  BEST = Heston–Merton

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td>
# ...

# %% [markdown]
# ### Table AAPL-2  ·  Nov 2022  ·  n = 391  ·  BEST = GARCH

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td>
# ...

# %% [markdown]
# ### Table AAPL-3  ·  Dec 2022  ·  n = 391  ·  BEST = Merton

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td>
# ...

# %% [markdown]
# ### Table AAPL-4  ·  Jan 2023  ·  n = 391  ·  BEST = Heston

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td>
# ...

# %% [markdown]
# ### Table AAPL-5  ·  Feb 2023  ·  n = 391  ·  BEST = GARCH

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td>
# ...

# %% [markdown]
# ### Table AAPL-6  ·  Mar 2023  ·  n = 391  ·  BEST = GARCH–Merton

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td>
# ...

# %% [markdown]
# ### Table AAPL-7  ·  Apr 2023  ·  n = 391  ·  BEST = Merton

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td>
# ...

# %% [markdown]
# ### Table AAPL-8  ·  May 2023  ·  n = 391  ·  BEST = Merton

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td>
# ...

# %% [markdown]
# ### Table AAPL-9  ·  Jun 2023  ·  n = 390  ·  BEST = GARCH

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td>
# ...

# %% [markdown]
# ### Table AAPL-10  ·  Jul 2023  ·  n = 391  ·  BEST = GBM

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align
# ...

# %% [markdown]
# ### Table AAPL-11  ·  Aug 2023  ·  n = 391  ·  BEST = GBM

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align
# ...

# %% [markdown]
# ### Table AAPL-12  ·  Sep 2023  ·  n = 391  ·  BEST = GBM

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align
# ...

# %% [markdown]
# ## MSFT

# %% [markdown]
# ### Table MSFT-1  ·  Oct 2022  ·  n = 391  ·  BEST = Heston–Merton

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td>
# ...

# %% [markdown]
# ### Table MSFT-2  ·  Nov 2022  ·  n = 391  ·  BEST = GARCH

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td>
# ...

# %% [markdown]
# ### Table MSFT-3  ·  Dec 2022  ·  n = 391  ·  BEST = Merton

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td>
# ...

# %% [markdown]
# ### Table MSFT-4  ·  Jan 2023  ·  n = 391  ·  BEST = GARCH

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td>
# ...

# %% [markdown]
# ### Table MSFT-5  ·  Feb 2023  ·  n = 391  ·  BEST = GARCH–Merton

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td>
# ...

# %% [markdown]
# ### Table MSFT-6  ·  Mar 2023  ·  n = 391  ·  BEST = GARCH

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td>
# ...

# %% [markdown]
# ### Table MSFT-7  ·  Apr 2023  ·  n = 391  ·  BEST = GBM

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align
# ...

# %% [markdown]
# ### Table MSFT-8  ·  May 2023  ·  n = 391  ·  BEST = Merton

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td>
# ...

# %% [markdown]
# ### Table MSFT-9  ·  Jun 2023  ·  n = 390  ·  BEST = GBM

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align
# ...

# %% [markdown]
# ### Table MSFT-10  ·  Jul 2023  ·  n = 391  ·  BEST = Heston–Merton

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td>
# ...

# %% [markdown]
# ### Table MSFT-11  ·  Aug 2023  ·  n = 391  ·  BEST = GBM

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align
# ...

# %% [markdown]
# ### Table MSFT-12  ·  Sep 2023  ·  n = 391  ·  BEST = Heston

# %%
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ICP 25–75</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>ABW</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td>
# ...
