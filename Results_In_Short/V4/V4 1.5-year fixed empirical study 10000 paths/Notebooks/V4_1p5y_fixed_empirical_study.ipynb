# %% [markdown]
# # V3 empirical study — 1.5-year fixed calibration
#
# **This notebook is the computational source of truth.** The PDF in this folder is written from the same `payload` dict, so every table number matches.
#
# | Item | Setting |
# |------|---------|
# | Models | GBM, Modified GBM, GARCH, Heston, Merton, GARCH–Merton, Heston–Merton |
# | Companies | SPY (primary), AAPL, MSFT, AMZN |
# | Regimes | Crisis 2008-08-01→2009-07-31 · Normal 2014-01-01→2014-12-31 · Late-cycle 2018-10-01→2019-09-30 · COVID 2019-09-01→2020-08-31 |
# | Calibration | **1.5-year** lookback, **none** recalibration |
# | Primary metric | Percentage RMSE |
# | Secondary | MAE, Bias $ (model − market), Bias%, Early-exercise fraction |
# | Paths | LSM American calls, `n_paths=10000`, `seed=42` |
# | Code | V3 notebooks + `option_filters.py` + Euler-corrected Heston step |
#
# In every table the **BEST** model is the lowest RMSE%. That row is **bold and green**.

# %% [markdown]
# ## 0. Methodology and conditions
#
# ### No look-ahead
# At the first session t0 of each 1-year evaluation window, parameters use only returns and listed quotes with `trading_date ≤ t0`. Those parameters are held for every Monday contract in the window. LSM prices each contract with that single calibration row. Option quotes are as-of the grid timestamp (same session, else the prior session).
#
# ### Shared sample (no model-specific data selection)
# For each company × regime the Monday nearest-ATM listed-call sample is drawn **once** and passed to all seven models in this report. Filters, testing dates, simulation settings, and the market benchmark are therefore identical.
#
# ### Filters (applied in this order)
# 1. Calls only; finite S, K, C.
# 2. No-arbitrage: C ≥ max(0, S−K).
# 3. Maturity: 7 ≤ DTE ≤ 60.
# 4. Moneyness: |S/K − 1| ≤ 10%.
# 5. Liquidity: premium ≥ 0.05; valid bid–ask and relative spread ≤ 50% when those columns exist; volume ≥ 1 when present.
#
# ### Metrics
# - Primary: RMSE%.
# - Secondary: MAE (dollars), Bias $ = mean(model − market), **Bias% = 100 × mean((model − market)/market)**, early-exercise fraction.
# - Ranking uses RMSE% only. The dollar bias column is kept; Bias% is the scale-free companion.
#
# ### Model-correctness adjustments
# - Heston / Heston–Merton: option-implied Fourier NLS for (κ, θ, ξ, ρ, v0). Not Method A.
# - Euler: stock return over [t, t+Δt] uses **current** v_t; then update v_{t+Δt}.
# - LSM never averages paths before stopping.
#
# ### Data limits
# Equity adj-close starts **2003-12-01**. Listed-option panels start **2008-01**. Estimators use all available history when the requested lookback is longer than the file.
#
# ### Re-run
# Set `RECOMPUTE = True` in the next cell and Run All. Default loads `payload.json` if the company×regime×model cells are already complete, then rewrites the PDF from that payload.

# %%
import sys
from pathlib import Path
from IPython.display import display, HTML, Markdown, Image
ROOT = Path.cwd()
for cand in [ROOT, *ROOT.parents]:
    scripts = cand / 'V4-Models_result' / 'scripts'
    if scripts.exists():
        sys.path.insert(0, str(scripts))
        break
import run_v4_1p5y_10k_fixed_empirical_study as study
RECOMPUTE = False  # True to re-run all calibrations + LSM
payload = study.run_or_load(recompute=RECOMPUTE)
print('cells', len(payload['cells']), 'failures', payload['meta']['failures'])
pdf_path = study.write_pdf(payload)
print('PDF', pdf_path)
# Out:
# <pre>cells 112 failures []</pre>

# %% [markdown]
# ## 1. Shared evaluation sample

# %%
from IPython.display import HTML, display
rows = ['<h4>n contracts (identical across models)</h4>']
display(HTML(''.join(study._html_table(payload['tables'][k]) if False else '')))
meta = payload['shared_contracts']
import pandas as pd
df = pd.DataFrame([{ 'regime': r, **meta[r]['n'], 'start': meta[r]['period_start'], 'end': meta[r]['period_end']} for r in study.REGIME_ORDER])
display(df)
# Out:
# <h2>1. Shared evaluation sample</h2><p>One Monday ATM listed-call sample per company × regime. Copied to all seven models in this report.</p><table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;'><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;'>Regime</th><th style='background:#1F3A5F;color:white;padding:6px 8px;'>Window</th><th style='background:#1F3A5F;color:white;padding:6px 8px;'>SPY</th><th style='background:#1F3A5F;color:white;padding:6px 8px;'>AAPL</th><th style='background:#1F3A5F;color:white;padding:6px 8px;'>MSFT</th><th style='background:#1F3A5F;color:white;padding:6px 8px;'>AMZN</th></tr><tr><td style='padding:5px 8px;border:1px solid #D0D5DD;'>2008-2009 Crisis</td><td style='padding:5px 8px;border:1px solid #D0D5DD;'>2008-08-01 → 2009-07-31</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td></tr><tr><td style='padding:5px 8px;border:1px solid #D0D5DD;'>2013-2014 Normal</td><td style='padding:5px 8px;border:1px solid #D0D5DD;'>2014-01-01 → 2014-12-31</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td></tr><tr><td style='padding:5px 8px;border:1px solid #D0D5DD;'>2018-2019 Late-cycle</td><td style='padding:5px 8px;border:1px solid #D0D5DD;'>2018-10-01 → 2019-09-30</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>51</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>51</td></tr><tr><td style='padding:5px 8px;border:1px solid #D0D5DD;'>2019-2020 COVID</td><td style='padding:5px 8px;border:1px solid #D0D5DD;'>2019-09-01 → 2020-08-31</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td><td style='padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>50</td></tr></table>

# %% [markdown]
# ## 2.1 Detailed tables — `SPY`

# %% [markdown]
# ### Table SPY-1. SPY · 2008-2009 · Crisis
#
# 2008-08-01 → 2009-07-31 · n = 50 contracts · **BEST = GARCH–Merton** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['SPY|2008-2009'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>39.85</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.5118</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-1.3570</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-29.27</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>25.5%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>5</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>43.13</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.6255</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-1.5635</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-35.30</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>26.1%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>7</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>36.15</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.3736</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.9849</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-18.26</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.5%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>39.13</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.4774</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-1.2428</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-26.22</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>18.1%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>40.12</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.5229</td><td style='background:white;padding:5px 8px;b ...

# %% [markdown]
# ### Table SPY-2. SPY · 2013-2014 · Normal
#
# 2014-01-01 → 2014-12-31 · n = 50 contracts · **BEST = GARCH** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['SPY|2013-2014'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>40.10</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.7145</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.5358</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+27.51</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>26.2%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>41.67</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.7464</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.5698</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+29.03</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>26.1%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4</td></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>38.23</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.6786</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.4831</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+25.30</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>24.6%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>45.98</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.8231</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.6985</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+34.22</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>19.2%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>6</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>40.53</td><td style='backgrou ...

# %% [markdown]
# ### Table SPY-3. SPY · 2018-2019 · Late-cycle
#
# 2018-10-01 → 2019-09-30 · n = 50 contracts · **BEST = Merton** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['SPY|2018-2019'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.62</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.8840</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.1277</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+1.81</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>20.8%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.03</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.8902</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2283</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.59</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>22.2%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>25.60</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.0389</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.8655</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-16.06</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>18.9%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>5</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>27.91</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.9468</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.2281</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+10.44</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>16.2%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>6</td></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>22.81</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.90 ...

# %% [markdown]
# ### Table SPY-4. SPY · 2019-2020 · COVID
#
# 2019-09-01 → 2020-08-31 · n = 50 contracts · **BEST = Heston** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['SPY|2019-2020'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>57.52</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2.9208</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.5111</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+18.64</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>24.3%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>59.99</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2.9847</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.3345</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+21.88</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.9%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>60.68</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2.9733</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.3077</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+22.51</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>22.9%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>5</td></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>53.99</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2.9171</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.9629</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+11.31</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>19.5%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>56.81</td><td style='background:white;paddi ...

# %% [markdown]
# ## 2.2 Detailed tables — `AAPL`

# %% [markdown]
# ### Table AAPL-1. AAPL · 2008-2009 · Crisis
#
# 2008-08-01 → 2009-07-31 · n = 50 contracts · **BEST = Modified GBM** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['AAPL|2008-2009'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>34.70</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.7325</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2012</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+2.49</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.4%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4</td></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>32.72</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.6706</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.6554</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-4.84</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>24.4%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>35.04</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.7531</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.1784</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+2.83</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>21.8%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>6</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>33.29</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.7314</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.4465</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-1.87</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>18.9%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>34.57</td><td style='background:white;padding:5 ...

# %% [markdown]
# ### Table AAPL-2. AAPL · 2013-2014 · Normal
#
# 2014-01-01 → 2014-12-31 · n = 50 contracts · **BEST = GARCH** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['AAPL|2013-2014'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>57.70</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3.8194</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+3.8194</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+51.38</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>24.4%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>51.10</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3.3484</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+3.3484</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+44.85</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>25.7%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>39.62</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2.4884</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+2.3946</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+32.33</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.1%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>70.88</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4.8769</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+4.8769</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+64.15</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>19.2%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>6</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>57.50</td><td style='backgrou ...

# %% [markdown]
# ### Table AAPL-3. AAPL · 2018-2019 · Late-cycle
#
# 2018-10-01 → 2019-09-30 · n = 51 contracts · **BEST = GBM** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['AAPL|2018-2019'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>16.77</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.8809</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.5584</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-7.11</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.8%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>16.88</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.8919</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.5478</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-6.91</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>24.5%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>17.11</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.9076</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.6227</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-8.15</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>22.6%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>19.55</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.9559</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.3612</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+7.54</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>14.6%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>6</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>18.08</td><td style='background:w ...

# %% [markdown]
# ### Table AAPL-4. AAPL · 2019-2020 · COVID
#
# 2019-09-01 → 2020-08-31 · n = 50 contracts · **BEST = GBM** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['AAPL|2019-2020'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>41.39</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3.1111</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.6446</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+18.83</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>24.0%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>43.50</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3.2399</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.9173</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+21.54</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>24.2%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>45.91</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3.3764</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+1.2410</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+24.56</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>22.0%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>5</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>44.31</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3.2876</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+1.0658</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+22.80</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>19.5%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>43.70</td><td style='backgrou ...

# %% [markdown]
# ## 2.3 Detailed tables — `MSFT`

# %% [markdown]
# ### Table MSFT-1. MSFT · 2008-2009 · Crisis
#
# 2008-08-01 → 2009-07-31 · n = 50 contracts · **BEST = Heston–Merton** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['MSFT|2008-2009'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>29.17</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.3120</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2729</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-19.88</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>25.5%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>6</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>28.96</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.3119</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2681</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-19.42</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>26.3%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>5</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>26.24</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.2848</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0629</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.36</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.1%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>26.56</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.2969</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2098</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-13.71</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>20.8%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>26.16</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.2932</td><td style='background:white;padding:5px 8px;bo ...

# %% [markdown]
# ### Table MSFT-2. MSFT · 2013-2014 · Normal
#
# 2014-01-01 → 2014-12-31 · n = 50 contracts · **BEST = Merton** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['MSFT|2013-2014'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>62.49</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.4284</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.4262</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+52.88</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>24.7%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>60.58</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.4138</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.4100</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+51.07</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>26.0%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>64.23</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.4441</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.4431</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+54.76</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.9%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>76.15</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.5487</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.5487</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+66.83</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>18.7%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>5</td></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>55.50</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0. ...

# %% [markdown]
# ### Table MSFT-3. MSFT · 2018-2019 · Late-cycle
#
# 2018-10-01 → 2019-09-30 · n = 50 contracts · **BEST = Modified GBM** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['MSFT|2018-2019'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>21.68</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.5626</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.0129</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+3.25</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.0%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3</td></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>19.94</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.5524</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2155</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-3.65</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>25.4%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>20.42</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.5496</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.1917</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-2.97</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>21.3%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.91</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.5954</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.1129</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+6.13</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>14.7%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>25.35</td><td style='background:white;padding:5 ...

# %% [markdown]
# ### Table MSFT-4. MSFT · 2019-2020 · COVID
#
# 2019-09-01 → 2020-08-31 · n = 50 contracts · **BEST = Modified GBM** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['MSFT|2019-2020'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>45.98</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.7242</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.0264</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+16.93</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>24.8%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4</td></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>41.04</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.7043</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.3996</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+8.84</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>25.5%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>42.17</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.6816</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2778</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+11.08</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>22.6%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>42.53</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.7172</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2236</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+12.09</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>18.0%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>46.60</td><td style='background:white;paddin ...

# %% [markdown]
# ## 2.4 Detailed tables — `AMZN`

# %% [markdown]
# ### Table AMZN-1. AMZN · 2008-2009 · Crisis
#
# 2008-08-01 → 2009-07-31 · n = 50 contracts · **BEST = Heston–Merton** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['AMZN|2008-2009'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>32.38</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.2336</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0334</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+3.64</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>22.9%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>6</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>29.85</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.2017</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.4075</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-4.77</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>25.2%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>32.34</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.2318</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0435</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+3.42</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>22.3%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>5</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>29.76</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.2209</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.6136</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-9.76</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>17.8%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>29.53</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1.2007</td><td style='background:white;padding:5px 8px;borde ...

# %% [markdown]
# ### Table AMZN-2. AMZN · 2013-2014 · Normal
#
# 2014-01-01 → 2014-12-31 · n = 50 contracts · **BEST = Merton** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['AMZN|2013-2014'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.09</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2.4183</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+0.0489</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+5.54</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>24.8%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>22.52</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2.3818</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0168</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+4.90</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>25.5%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>22.58</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2.3967</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0514</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+4.59</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>22.8%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>41.35</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3.4101</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+2.9636</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+30.50</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>16.0%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>6</td></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>22.30</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2.382 ...

# %% [markdown]
# ### Table AMZN-3. AMZN · 2018-2019 · Late-cycle
#
# 2018-10-01 → 2019-09-30 · n = 51 contracts · **BEST = GBM** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['AMZN|2018-2019'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>22.97</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>12.4353</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-5.5218</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-4.77</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>22.9%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.72</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>12.4787</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-3.3465</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-1.02</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>21.5%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.04</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>12.4406</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-5.4598</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-4.84</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>21.5%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>32.20</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>15.3154</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+6.3787</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+13.43</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>14.0%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>6</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.53</td><td style='backgro ...

# %% [markdown]
# ### Table AMZN-4. AMZN · 2019-2020 · COVID
#
# 2019-09-01 → 2020-08-31 · n = 50 contracts · **BEST = Heston** (lowest RMSE%).

# %%
display(HTML(study._html_table(payload['tables']['AMZN|2019-2020'])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias $</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Early-ex. frac.</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mark</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>56.86</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>26.5091</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+13.6258</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+35.54</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.7%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>5</td></tr><tr><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>60.74</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>27.6000</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+16.4384</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+39.62</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>22.9%</td><td style='background:#F4F7FB;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>7</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>37.53</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>22.7400</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-4.0628</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+10.43</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>22.5%</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>37.33</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>22.8307</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-4.3221</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>+9.37</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>16.5%</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>58.57</td><td style='background:white; ...

# %% [markdown]
# ## 3. Summary tables

# %% [markdown]
# ### Table S1 — Overall ranking

# %%
display(HTML('overall ranking table is rendered from payload["summary_overall"]'))
# Out:
# <h3>Table S1 · Overall ranking (mean RMSE% over 16 cells)</h3><table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;'><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;'>Rank</th><th style='background:#1F3A5F;color:white;padding:6px 8px;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;'>Mean RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;'>Median RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;'># cells best</th></tr><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>1</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH BEST</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>35.43</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>35.59</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:#F4F7FB;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td><td style='background:#F4F7FB;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Modified GBM</td><td style='background:#F4F7FB;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>37.46</td><td style='background:#F4F7FB;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>36.88</td><td style='background:#F4F7FB;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3</td></tr><tr><td style='background:white;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3</td><td style='background:white;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Merton</td><td style='background:white;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>37.60</td><td style='background:white;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>37.34</td><td style='background:white;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3</td></tr><tr><td style='background:#F4F7FB;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4</td><td style='background:#F4F7FB;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GBM</td><td style='background:#F4F7FB;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>37.89</td><td style='background:#F4F7FB;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>37.28</td><td style='background:#F4F7FB;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3</td></tr><tr><td style='background:white;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>5</td><td style='background:white;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:white;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>40.30</td><td style='background:white;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>38.23</td><td style='background:white;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>2</td></tr><tr><td style='background:#F4F7FB;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>6</td><td style='background:#F4F7FB;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>GARCH–Merton</td><td style='background:#F4F7FB;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>46.35</td><td style='background:#F4F7FB;font-weight:400;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>44.05</td><td style='background:#F4F7FB;font-weight:400;padding:5px 8px;border: ...

# %% [markdown]
# ## 4. Figures

# %% [markdown]
# ### Figure 1 — RMSE% by regime (mean of four companies)

# %%
pass  # figure embedded from the same payload used for the PDF

# %% [markdown]
# ### Figure 2 — RMSE% by company

# %%
pass

# %% [markdown]
# ### Figure 3 — Rank heatmap

# %%
pass

# %% [markdown]
# ## 5. Final analysis
#
# - On mean percentage RMSE across the 16 company×regime cells, GARCH is the best overall model (mean RMSE% = 35.43; 2 of 16 cells).
#
# - Second overall is Modified GBM (mean RMSE% = 37.46; 3 cells).
#
# - The ranking is not stable. Best-in-cell models across the 16 tables: GARCH, GARCH–Merton, GBM, Heston, Heston–Merton, Merton, Modified GBM.
#
# - SPY: lowest mean RMSE% is Merton (40.07); wins 1 of 4 regimes.
#
# - AAPL: lowest mean RMSE% is GARCH (34.42); wins 1 of 4 regimes.
#
# - MSFT: lowest mean RMSE% is Modified GBM (37.63); wins 2 of 4 regimes.
#
# - AMZN: lowest mean RMSE% is GARCH (28.87); wins 0 of 4 regimes.
#
# - 2008-2009 (Crisis): best mean RMSE% is Heston–Merton (31.42).
#
# - 2013-2014 (Normal): best mean RMSE% is GARCH (41.17).
#
# - 2018-2019 (Late-cycle): best mean RMSE% is Modified GBM (20.89).
#
# - 2019-2020 (COVID): best mean RMSE% is Heston (44.54).
#
# - No-jump models as a group have lower mean RMSE% (37.77) than the jump models in this report (44.68).
#
# - For the overall winner (GARCH), crisis RMSE% is 32.44 vs 41.17 in the 2014 normal year — absolute pricing error is regime-dependent even when the ranking is not.
#
# - These conclusions are conditional on the V3 filters, 1.5-year fixed calibration, Monday ATM sample, LSM with 10,000 paths, and American-call quotes only. They are not a statement about European options or other tenors.

# %% [markdown]
# ## 6. Reproducibility
#
# ```python
# RECOMPUTE = True
# payload = study.run_or_load(recompute=True)
# study.write_pdf(payload)
# study.build_notebook(payload)
# ```
#
# Partial results resume from `V4-Models_result/results/empirical_study_1p5y_fixed_10000/partial/`.
# Shared contracts are frozen in `shared_contracts.json` so a resumed run cannot silently change the sample.
