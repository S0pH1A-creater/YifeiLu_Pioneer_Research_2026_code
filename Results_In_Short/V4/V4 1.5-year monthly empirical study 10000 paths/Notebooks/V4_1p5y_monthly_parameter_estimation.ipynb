# %% [markdown]
# # V4 parameter estimation — 1.5-year monthly calibration
#
# **This notebook is the computational source of truth.** The matching PDF is written from the same payload.
#
# `calibrate_ticker` paths for `V4 1.5-year monthly empirical study 10000 paths`. **No LSM.**
#
# | Item | Setting |
# |------|---------|
# | Lookback | 18 months ending at each update |
# | Rolling | `monthly` |
# | Names | SPY, AAPL, MSFT, AMZN |
# | Windows | R1 Crisis, R2 Normal, R3 Late-cycle, R4 COVID |
# | Cell | Mean, SD, Min, Max of the estimates inside that regime |

# %% [markdown]
# ## Table P1. GBM

# %%
from IPython.display import display, HTML
display(HTML(pe._html_table('GBM', payload)))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:12px;width:100%;'><thead><tr><th rowspan='2' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;text-align:left;'>Regime / param</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SPY</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AAPL</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MSFT</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AMZN</th></tr><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th></tr></thead><tbody><tr><td colspan='17' style='background:#D9E2EC;color:#1F3A5F;font-weight:700;padding:6px 8px;border:1px solid #D0D5DD;'>R1  Crisis  (n = 13)</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:left;'>μ (P)</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2873</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.1250</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.4424</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0608</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0499</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.2597</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2648</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.4609</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2249</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.1181</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.3572</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0067</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0101</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.2638</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.3265</td><td style='background:white;padding:5px 8px;border: ...

# %% [markdown]
# Notes: This table reports Mean, SD, Min, and Max of the monthly GBM estimates for SPY, AAPL, MSFT, AMZN. Parameters are μ (P), σ. Each month-end update uses an 18-month lookback ending on that date, with no look-ahead. R1–R4 are Crisis, Normal, Late-cycle, and COVID. n is the number of monthly updates in that regime. SD is the sample standard deviation across those monthly estimates.  This is parameter estimation only; it is not an LSM pricing table.

# %% [markdown]
# ## Table P2. MD-GBM

# %%
from IPython.display import display, HTML
display(HTML(pe._html_table('MD-GBM', payload)))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:12px;width:100%;'><thead><tr><th rowspan='2' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;text-align:left;'>Regime / param</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SPY</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AAPL</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MSFT</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AMZN</th></tr><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th></tr></thead><tbody><tr><td colspan='17' style='background:#D9E2EC;color:#1F3A5F;font-weight:700;padding:6px 8px;border:1px solid #D0D5DD;'>R1  Crisis  (n = 13)</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:left;'>P(U|U)</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.4394</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0177</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.4176</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.4707</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.4833</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0208</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.4605</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.5123</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.4593</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0227</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.4315</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.5027</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.4115</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0124</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.3866</td><td style='background:white;padding:5px 8px;border:1px soli ...

# %% [markdown]
# Notes: This table reports Mean, SD, Min, and Max of the monthly MD-GBM estimates for SPY, AAPL, MSFT, AMZN. Parameters are P(U|U), P(D|D), P(U|D), P(D|U), μ_U, σ_U, μ_D, σ_D. Each month-end update uses an 18-month lookback ending on that date, with no look-ahead. R1–R4 are Crisis, Normal, Late-cycle, and COVID. n is the number of monthly updates in that regime. SD is the sample standard deviation across those monthly estimates.  This is parameter estimation only; it is not an LSM pricing table.

# %% [markdown]
# ## Table P3. GARCH

# %%
from IPython.display import display, HTML
display(HTML(pe._html_table('GARCH', payload)))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:12px;width:100%;'><thead><tr><th rowspan='2' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;text-align:left;'>Regime / param</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SPY</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AAPL</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MSFT</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AMZN</th></tr><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th></tr></thead><tbody><tr><td colspan='17' style='background:#D9E2EC;color:#1F3A5F;font-weight:700;padding:6px 8px;border:1px solid #D0D5DD;'>R1  Crisis  (n = 13)</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:left;'>λ</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0247</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0178</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0470</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0104</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0718</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0302</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0442</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.1274</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0162</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0123</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0340</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0058</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0415</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0234</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0056</td><td style='background:white;padding:5px 8px;border:1px solid ...

# %% [markdown]
# Notes: This table reports Mean, SD, Min, and Max of the monthly GARCH estimates for SPY, AAPL, MSFT, AMZN. Parameters are λ, ω, α, β, σ₀, persist P, persist Q. Each month-end update uses an 18-month lookback ending on that date, with no look-ahead. R1–R4 are Crisis, Normal, Late-cycle, and COVID. n is the number of monthly updates in that regime. SD is the sample standard deviation across those monthly estimates.  This is parameter estimation only; it is not an LSM pricing table.

# %% [markdown]
# ## Table P4. Heston

# %%
from IPython.display import display, HTML
display(HTML(pe._html_table('Heston', payload)))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:12px;width:100%;'><thead><tr><th rowspan='2' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;text-align:left;'>Regime / param</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SPY</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AAPL</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MSFT</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AMZN</th></tr><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th></tr></thead><tbody><tr><td colspan='17' style='background:#D9E2EC;color:#1F3A5F;font-weight:700;padding:6px 8px;border:1px solid #D0D5DD;'>R1  Crisis  (n = 13)</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:left;'>μ (P)</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2873</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.1250</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.4424</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0608</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0499</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.2597</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2648</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.4609</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2249</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.1181</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.3572</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0067</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0101</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.2638</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.3265</td><td style='background:white;padding:5px 8px;border: ...

# %% [markdown]
# Notes: This table reports Mean, SD, Min, and Max of the monthly Heston estimates for SPY, AAPL, MSFT, AMZN. Parameters are μ (P), κ (P), θ (P), ξ, ρ, v₀ (P), η_v (premium), κ* (Q), θ* (Q), v₀^Q, n quotes. Each month-end update uses an 18-month lookback ending on that date, with no look-ahead. R1–R4 are Crisis, Normal, Late-cycle, and COVID. n is the number of monthly updates in that regime. SD is the sample standard deviation across those monthly estimates.  This is parameter estimation only; it is not an LSM pricing table.

# %% [markdown]
# ## Table P5. Merton

# %%
from IPython.display import display, HTML
display(HTML(pe._html_table('Merton', payload)))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:12px;width:100%;'><thead><tr><th rowspan='2' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;text-align:left;'>Regime / param</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SPY</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AAPL</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MSFT</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AMZN</th></tr><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th></tr></thead><tbody><tr><td colspan='17' style='background:#D9E2EC;color:#1F3A5F;font-weight:700;padding:6px 8px;border:1px solid #D0D5DD;'>R1  Crisis  (n = 13)</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:left;'>μ (P)</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2184</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0900</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.3501</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0707</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0013</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.2783</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2261</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.5259</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.3118</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.2108</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.5198</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0731</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.1561</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.1577</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.4766</td><td style='background:white;padding:5px 8px;border:1 ...

# %% [markdown]
# Notes: This table reports Mean, SD, Min, and Max of the monthly Merton estimates for SPY, AAPL, MSFT, AMZN. Parameters are μ (P), σ, λ* = λ, μ_J (P), σ_J, κ (P), μ_J* (Q), κ^Q, n quotes. Each month-end update uses an 18-month lookback ending on that date, with no look-ahead. R1–R4 are Crisis, Normal, Late-cycle, and COVID. n is the number of monthly updates in that regime. SD is the sample standard deviation across those monthly estimates.  This is parameter estimation only; it is not an LSM pricing table.

# %% [markdown]
# ## Table P6. GARCH–Merton

# %%
from IPython.display import display, HTML
display(HTML(pe._html_table('GARCH–Merton', payload)))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:12px;width:100%;'><thead><tr><th rowspan='2' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;text-align:left;'>Regime / param</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SPY</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AAPL</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MSFT</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AMZN</th></tr><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th></tr></thead><tbody><tr><td colspan='17' style='background:#D9E2EC;color:#1F3A5F;font-weight:700;padding:6px 8px;border:1px solid #D0D5DD;'>R1  Crisis  (n = 13)</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:left;'>μ</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.1720</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0672</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2382</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0912</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.4934</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.2142</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.2381</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.8472</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.1502</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0471</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.1991</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.1082</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.3362</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.1151</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.2088</td><td style='background:white;padding:5px 8px;border:1px sol ...

# %% [markdown]
# Notes: This table reports Mean, SD, Min, and Max of the monthly GARCH–Merton estimates for SPY, AAPL, MSFT, AMZN. Parameters are μ, ω, α, β, σ₀, λ, μ_J, σ_J, κ. Each month-end update uses an 18-month lookback ending on that date, with no look-ahead. R1–R4 are Crisis, Normal, Late-cycle, and COVID. n is the number of monthly updates in that regime. SD is the sample standard deviation across those monthly estimates.  This is parameter estimation only; it is not an LSM pricing table.

# %% [markdown]
# ## Table P7. Heston–Merton

# %%
from IPython.display import display, HTML
display(HTML(pe._html_table('Heston–Merton', payload)))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:12px;width:100%;'><thead><tr><th rowspan='2' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;text-align:left;'>Regime / param</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SPY</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AAPL</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MSFT</th><th colspan='4' style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AMZN</th></tr><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Mean</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SD</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Min</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Max</th></tr></thead><tbody><tr><td colspan='17' style='background:#D9E2EC;color:#1F3A5F;font-weight:700;padding:6px 8px;border:1px solid #D0D5DD;'>R1  Crisis  (n = 13)</td></tr><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:left;'>μ (P)</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2873</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.1250</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.4424</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0608</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0499</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.2597</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2648</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.4609</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.2249</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.1181</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.3572</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.0067</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.0101</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>0.2638</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>-0.3265</td><td style='background:white;padding:5px 8px;border: ...

# %% [markdown]
# Notes: This table reports Mean, SD, Min, and Max of the monthly Heston–Merton estimates for SPY, AAPL, MSFT, AMZN. Parameters are μ (P), κ (P), θ (P), ξ, ρ, v₀ (P), λ* = λ, μ_J (P), σ_J, κ_J (P), η_v (premium), κ* (Q), θ* (Q), v₀^Q, μ_J* (Q), κ_J^Q, n quotes. Each month-end update uses an 18-month lookback ending on that date, with no look-ahead. R1–R4 are Crisis, Normal, Late-cycle, and COVID. n is the number of monthly updates in that regime. SD is the sample standard deviation across those monthly estimates.  This is parameter estimation only; it is not an LSM pricing table.

# %% [markdown]
# ## Re-run
#
# ```python
# import run_v3_1p5y_10k_monthly_parameter_estimation as pe
# payload = pe.run()
# ```
