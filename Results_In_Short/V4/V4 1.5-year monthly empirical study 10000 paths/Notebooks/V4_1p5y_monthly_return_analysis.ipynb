# %% [markdown]
# # V4 return analysis — 1.5-year monthly study
#
# **This notebook is the computational source of truth.** The matching PDF is written from the same payload.
#
# Realized equity returns in the four windows of `V4 1.5-year monthly empirical study 10000 paths`. This report does not price options and does not resimulate LSM paths.
#
# | Item | Setting |
# |------|---------|
# | Names | SPY, AAPL, MSFT, AMZN |
# | Windows | Crisis, Normal, Late-cycle, COVID (same bounds as the option study) |
# | Return | $R_t = \ln(S_t / S_{t-1})$ from `research/data/equity/prices_clean.csv` |
# | Table | Mean, Std dev., Skewness statistic, Ex. kurt. statistic, Normality statistics (JB) |
# | Brackets | t-test p-values vs Normal for skewness and excess kurtosis; t-version Jarque–Bera p-value |
# | Figures | Annualized continuously compounded returns $252 \times R_t$, in percent |

# %% [markdown]
# ## 2008-2009  ·  Crisis
#
# 2008-08-01 → 2009-07-31  ·  n = 252 daily observations.

# %% [markdown]
# ### Table R1. Return statistics

# %%
from IPython.display import display, HTML
display(HTML(ra._html_table(payload['periods'][0])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Statistic</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SPY</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AAPL</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MSFT</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AMZN</th></tr></thead><tbody><tr><td style='background:white;padding:6px 8px;border:1px solid #D0D5DD;text-align:left;font-weight:600;'>Mean</td><td style='background:white;padding:6px 8px;border:1px solid #D0D5DD;text-align:center;font-weight:400;'>-0.0987</td><td style='background:white;padding:6px 8px;border:1px solid #D0D5DD;text-align:center;font-weight:400;'>0.0109</td><td style='background:white;padding:6p
# ...

# %% [markdown]
# Notes: This table shows sample statistics for the continuously compounded returns, R_t = ln(S_t / S_{t-1}), for SPY, AAPL, MSFT, and AMZN. The sample period is August 1, 2008 to July 31, 2009, for a total of 252 daily observations. Mean return and standard deviation are in percent per trading day. For the skewness and excess kurtosis statistics, the brackets next to the statistics report the p-values from testing the significance of the difference between the empirical values and the theoretical values from the Normal distribution using a t-test. For the normality statistic the p-value of a t-version of the well known Jarque–Bera test for normality is reported in brackets next to the statistics.

# %% [markdown]
# ### Figure R1. Annualized continuously compounded returns

# %%
fig = ra._draw_return_figure(payload['periods'][0], 1, for_pdf=False)
fig

# %% [markdown]
# Notes: This figure plots the annualized continuously compounded returns 252 × R_t for SPY, AAPL, MSFT, and AMZN. Date is on the x-axis and the annualized return, in percent, is on the y-axis. Each panel is one name. The shaded band is the evaluation window August 1, 2008 to July 31, 2009 (252 trading days); six months of returns are shown on each side so that band is visible. Large spikes are one-day moves scaled by 252, not cumulative performance.

# %% [markdown]
# ## 2013-2014  ·  Normal
#
# 2014-01-01 → 2014-12-31  ·  n = 253 daily observations.

# %% [markdown]
# ### Table R2. Return statistics

# %%
from IPython.display import display, HTML
display(HTML(ra._html_table(payload['periods'][1])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Statistic</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SPY</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AAPL</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MSFT</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AMZN</th></tr></thead><tbody><tr><td style='background:white;padding:6px 8px;border:1px solid #D0D5DD;text-align:left;font-weight:600;'>Mean</td><td style='background:white;padding:6px 8px;border:1px solid #D0D5DD;text-align:center;font-weight:400;'>0.0425</td><td style='background:white;padding:6px 8px;border:1px solid #D0D5DD;text-align:center;font-weight:400;'>0.1347</td><td style='background:white;padding:6px
# ...

# %% [markdown]
# Notes: This table shows sample statistics for the continuously compounded returns, R_t = ln(S_t / S_{t-1}), for SPY, AAPL, MSFT, and AMZN. The sample period is January 1, 2014 to December 31, 2014, for a total of 253 daily observations. Mean return and standard deviation are in percent per trading day. For the skewness and excess kurtosis statistics, the brackets next to the statistics report the p-values from testing the significance of the difference between the empirical values and the theoretical values from the Normal distribution using a t-test. For the normality statistic the p-value of a t-version of the well known Jarque–Bera test for normality is reported in brackets next to the statistics.

# %% [markdown]
# ### Figure R2. Annualized continuously compounded returns

# %%
fig = ra._draw_return_figure(payload['periods'][1], 2, for_pdf=False)
fig

# %% [markdown]
# Notes: This figure plots the annualized continuously compounded returns 252 × R_t for SPY, AAPL, MSFT, and AMZN. Date is on the x-axis and the annualized return, in percent, is on the y-axis. Each panel is one name. The shaded band is the evaluation window January 1, 2014 to December 31, 2014 (253 trading days); six months of returns are shown on each side so that band is visible. Large spikes are one-day moves scaled by 252, not cumulative performance.

# %% [markdown]
# ## 2018-2019  ·  Late-cycle
#
# 2018-10-01 → 2019-09-30  ·  n = 251 daily observations.

# %% [markdown]
# ### Table R3. Return statistics

# %%
from IPython.display import display, HTML
display(HTML(ra._html_table(payload['periods'][2])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Statistic</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SPY</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AAPL</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MSFT</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AMZN</th></tr></thead><tbody><tr><td style='background:white;padding:6px 8px;border:1px solid #D0D5DD;text-align:left;font-weight:600;'>Mean</td><td style='background:white;padding:6px 8px;border:1px solid #D0D5DD;text-align:center;font-weight:400;'>0.0084</td><td style='background:white;padding:6px 8px;border:1px solid #D0D5DD;text-align:center;font-weight:400;'>0.0030</td><td style='background:white;padding:6px
# ...

# %% [markdown]
# Notes: This table shows sample statistics for the continuously compounded returns, R_t = ln(S_t / S_{t-1}), for SPY, AAPL, MSFT, and AMZN. The sample period is October 1, 2018 to September 30, 2019, for a total of 251 daily observations. Mean return and standard deviation are in percent per trading day. For the skewness and excess kurtosis statistics, the brackets next to the statistics report the p-values from testing the significance of the difference between the empirical values and the theoretical values from the Normal distribution using a t-test. For the normality statistic the p-value of a t-version of the well known Jarque–Bera test for normality is reported in brackets next to the statistics.

# %% [markdown]
# ### Figure R3. Annualized continuously compounded returns

# %%
fig = ra._draw_return_figure(payload['periods'][2], 3, for_pdf=False)
fig

# %% [markdown]
# Notes: This figure plots the annualized continuously compounded returns 252 × R_t for SPY, AAPL, MSFT, and AMZN. Date is on the x-axis and the annualized return, in percent, is on the y-axis. Each panel is one name. The shaded band is the evaluation window October 1, 2018 to September 30, 2019 (251 trading days); six months of returns are shown on each side so that band is visible. Large spikes are one-day moves scaled by 252, not cumulative performance.

# %% [markdown]
# ## 2019-2020  ·  COVID
#
# 2019-09-01 → 2020-08-31  ·  n = 252 daily observations.

# %% [markdown]
# ### Table R4. Return statistics

# %%
from IPython.display import display, HTML
display(HTML(ra._html_table(payload['periods'][3])))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Statistic</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>SPY</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AAPL</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MSFT</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>AMZN</th></tr></thead><tbody><tr><td style='background:white;padding:6px 8px;border:1px solid #D0D5DD;text-align:left;font-weight:600;'>Mean</td><td style='background:white;padding:6px 8px;border:1px solid #D0D5DD;text-align:center;font-weight:400;'>0.0707</td><td style='background:white;padding:6px 8px;border:1px solid #D0D5DD;text-align:center;font-weight:400;'>0.3632</td><td style='background:white;padding:6px
# ...

# %% [markdown]
# Notes: This table shows sample statistics for the continuously compounded returns, R_t = ln(S_t / S_{t-1}), for SPY, AAPL, MSFT, and AMZN. The sample period is September 1, 2019 to August 31, 2020, for a total of 252 daily observations. Mean return and standard deviation are in percent per trading day. For the skewness and excess kurtosis statistics, the brackets next to the statistics report the p-values from testing the significance of the difference between the empirical values and the theoretical values from the Normal distribution using a t-test. For the normality statistic the p-value of a t-version of the well known Jarque–Bera test for normality is reported in brackets next to the statistics.

# %% [markdown]
# ### Figure R4. Annualized continuously compounded returns

# %%
fig = ra._draw_return_figure(payload['periods'][3], 4, for_pdf=False)
fig

# %% [markdown]
# Notes: This figure plots the annualized continuously compounded returns 252 × R_t for SPY, AAPL, MSFT, and AMZN. Date is on the x-axis and the annualized return, in percent, is on the y-axis. Each panel is one name. The shaded band is the evaluation window September 1, 2019 to August 31, 2020 (252 trading days); six months of returns are shown on each side so that band is visible. Large spikes are one-day moves scaled by 252, not cumulative performance.

# %% [markdown]
# ## Re-run
#
# ```python
# import run_v3_1p5y_10k_monthly_return_analysis as ra
# payload = ra.run()
# ```
