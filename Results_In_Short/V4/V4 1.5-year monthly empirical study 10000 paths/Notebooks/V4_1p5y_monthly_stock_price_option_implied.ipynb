# %% [markdown]
# # V3 stock-price study — 1.5-year monthly calibration — option-implied Heston family
#
# P-measure daily clouds vs realized S_t. Reported path = **p50**. `n_paths = 10000`, seed 42.

# %% [markdown]
# ## SPY

# %% [markdown]
# ### Table SPY-1  ·  Crisis  ·  BEST = Heston–Merton

# %%
from IPython.display import display, HTML
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Ranking</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>26.46</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>20.99</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:cen
# ...

# %% [markdown]
# ### Table SPY-2  ·  Normal  ·  BEST = Heston–Merton

# %%
from IPython.display import display, HTML
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Ranking</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4.48</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3.72</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:cente
# ...

# %% [markdown]
# ### Table SPY-3  ·  Late-cycle  ·  BEST = Heston–Merton

# %%
from IPython.display import display, HTML
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Ranking</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>9.68</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>8.49</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:cente
# ...

# %% [markdown]
# ### Table SPY-4  ·  COVID  ·  BEST = Heston

# %%
from IPython.display import display, HTML
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Ranking</th></tr></thead><tbody><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>8.41</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>6.40</td><td style='background:#E4EED8;f
# ...

# %% [markdown]
# ## Company summary

# %% [markdown]
# Same four-regime layout as SPY. Each value is the arithmetic mean of **AAPL, MSFT, AMZN**. Ranking uses mean RMSE% of p50 vs realized S_t.

# %% [markdown]
# ### Table Co-1  ·  Crisis  ·  mean of AAPL, MSFT, AMZN  ·  BEST = Heston–Merton

# %%
from IPython.display import display, HTML
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Ranking</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>36.24</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>28.22</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:cen
# ...

# %% [markdown]
# ### Table Co-2  ·  Normal  ·  mean of AAPL, MSFT, AMZN  ·  BEST = Heston

# %%
from IPython.display import display, HTML
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Ranking</th></tr></thead><tbody><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>19.03</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>16.95</td><td style='background:#E4EED8
# ...

# %% [markdown]
# ### Table Co-3  ·  Late-cycle  ·  mean of AAPL, MSFT, AMZN  ·  BEST = Heston–Merton

# %%
from IPython.display import display, HTML
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Ranking</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>26.10</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>23.89</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:cen
# ...

# %% [markdown]
# ### Table Co-4  ·  COVID  ·  mean of AAPL, MSFT, AMZN  ·  BEST = Heston

# %%
from IPython.display import display, HTML
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Ranking</th></tr></thead><tbody><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>18.80</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>15.40</td><td style='background:#E4EED8
# ...

# %% [markdown]
# ## AAPL

# %% [markdown]
# ### Table AAPL-1  ·  Crisis  ·  BEST = Heston–Merton

# %%
from IPython.display import display, HTML
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Ranking</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>53.57</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>42.24</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:cen
# ...

# %% [markdown]
# ### Table AAPL-2  ·  Normal  ·  BEST = Heston

# %%
from IPython.display import display, HTML
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Ranking</th></tr></thead><tbody><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>17.48</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>14.90</td><td style='background:#E4EED8
# ...

# %% [markdown]
# ### Table AAPL-3  ·  Late-cycle  ·  BEST = Heston–Merton

# %%
from IPython.display import display, HTML
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Ranking</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>30.62</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>27.11</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:cen
# ...

# %% [markdown]
# ### Table AAPL-4  ·  COVID  ·  BEST = Heston

# %%
from IPython.display import display, HTML
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Ranking</th></tr></thead><tbody><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>25.43</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>22.72</td><td style='background:#E4EED8
# ...

# %% [markdown]
# ## MSFT

# %% [markdown]
# ### Table MSFT-1  ·  Crisis  ·  BEST = Heston–Merton

# %%
from IPython.display import display, HTML
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Ranking</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>17.91</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>15.09</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:cen
# ...

# %% [markdown]
# ### Table MSFT-2  ·  Normal  ·  BEST = Heston

# %%
from IPython.display import display, HTML
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Ranking</th></tr></thead><tbody><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>4.06</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>3.42</td><td style='background:#E4EED8;f
# ...

# %% [markdown]
# ### Table MSFT-3  ·  Late-cycle  ·  BEST = Heston–Merton

# %%
from IPython.display import display, HTML
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Ranking</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>12.11</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>10.39</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:cen
# ...

# %% [markdown]
# ### Table MSFT-4  ·  COVID  ·  BEST = Heston

# %%
from IPython.display import display, HTML
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Ranking</th></tr></thead><tbody><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>10.50</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>8.63</td><td style='background:#E4EED8;
# ...

# %% [markdown]
# ## AMZN

# %% [markdown]
# ### Table AMZN-1  ·  Crisis  ·  BEST = Heston–Merton

# %%
from IPython.display import display, HTML
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Ranking</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>37.25</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>27.34</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:cen
# ...

# %% [markdown]
# ### Table AMZN-2  ·  Normal  ·  BEST = Heston–Merton

# %%
from IPython.display import display, HTML
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Ranking</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>35.55</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>32.51</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:cen
# ...

# %% [markdown]
# ### Table AMZN-3  ·  Late-cycle  ·  BEST = Heston–Merton

# %%
from IPython.display import display, HTML
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Ranking</th></tr></thead><tbody><tr><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>35.57</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>34.18</td><td style='background:white;padding:5px 8px;border:1px solid #D0D5DD;text-align:cen
# ...

# %% [markdown]
# ### Table AMZN-4  ·  COVID  ·  BEST = Heston

# %%
from IPython.display import display, HTML
display(HTML('tab'))
# Out:
# <table style='border-collapse:collapse;font-family:Helvetica,Arial,sans-serif;font-size:13px;width:100%;'><thead><tr><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Model</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>RMSE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>MAE%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Bias%</th><th style='background:#1F3A5F;color:white;padding:6px 8px;border:1px solid #D0D5DD;'>Ranking</th></tr></thead><tbody><tr><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>Heston</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>20.48</td><td style='background:#E4EED8;font-weight:700;padding:5px 8px;border:1px solid #D0D5DD;text-align:center;'>14.84</td><td style='background:#E4EED8
# ...
