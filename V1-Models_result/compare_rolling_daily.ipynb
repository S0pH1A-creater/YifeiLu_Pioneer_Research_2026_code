# %% [markdown]
# # Optimal stopping comparison — rolling = `daily`
#
# **What this notebook is:** a paste-together of existing study outputs for **one** rolling mode.
# Nothing was re-calibrated or re-priced here.
#
# | Fixed across all 16 blocks | Value |
# |----------------------------|-------|
# | Lookback | **6 months** |
# | Rolling calibration | **`daily`** |
# | Pricing | LSM American calls on SPY (24 contracts, n_paths=2000, seed=42) |
#
# ## How to read each block
#
# Each of the **16 studies** has:
#
# | Piece | Meaning |
# |-------|---------|
# | Heading | **Model · Regime** (and study index 1–16) |
# | Metrics table | **RMSE** (primary), MAE, bias, early-exercise — for **this** model, **this** regime, rolling=`daily` |
# | Three-panel figure | §6 LSM graph for that same group: **left** model vs market · **middle** mean option value · **right** exercise timing |
#
# **Order:** regimes `2008-2009` → `2013-2014` → `2018-2019` → `2019-2020`; within each regime: GBM → Merton → Heston–Merton → GARCH–Merton.
#
# Sibling notebooks (same 16 studies, different rolling only):
#
# - `compare_rolling_none.ipynb`
# - `compare_rolling_monthly.ipynb`
# - `compare_rolling_daily.ipynb`

# %% [markdown]
# ## Quick RMSE table — rolling = `daily` only
#
# | # | Regime | Model | RMSE | MAE | Bias (model−mkt) |
# |---|--------|-------|-----:|----:|-----------------:|
# | 1 | 2008-2009 | GBM | **0.6678** | 0.5253 | 0.3093 |
# | 2 | 2008-2009 | Merton | **0.6597** | 0.5367 | 0.3461 |
# | 3 | 2008-2009 | Heston–Merton | **1.4352** | 1.1503 | 0.5439 |
# | 4 | 2008-2009 | GARCH–Merton | **0.6990** | 0.4570 | 0.3876 |
# | 5 | 2013-2014 | GBM | **0.4021** | 0.3317 | 0.3199 |
# | 6 | 2013-2014 | Merton | **0.4398** | 0.3624 | 0.3438 |
# | 7 | 2013-2014 | Heston–Merton | **0.7332** | 0.5264 | 0.3724 |
# | 8 | 2013-2014 | GARCH–Merton | **0.5655** | 0.4460 | 0.4381 |
# | 9 | 2018-2019 | GBM | **1.5356** | 1.1325 | 0.9813 |
# | 10 | 2018-2019 | Merton | **1.5070** | 1.1418 | 1.0225 |
# | 11 | 2018-2019 | Heston–Merton | **1.7732** | 1.3327 | 0.4463 |
# | 12 | 2018-2019 | GARCH–Merton | **2.0580** | 1.5759 | 1.5733 |
# | 13 | 2019-2020 | GBM | **1.7976** | 1.4235 | 1.2793 |
# | 14 | 2019-2020 | Merton | **1.8986** | 1.5285 | 1.3688 |
# | 15 | 2019-2020 | Heston–Merton | **2.5020** | 1.8965 | 0.6315 |
# | 16 | 2019-2020 | GARCH–Merton | **2.6584** | 2.1964 | 2.1923 |

# %% [markdown]
# ---
#
# ## Study 1/16 — GBM · 2008-2009
#
# > **Placement key:** this block = **model=`GBM`** · **regime=`2008-2009`** · **rolling=`daily`** · lookback=`6 months`
#
# | Metric | Value | Applies to |
# |--------|------:|------------|
# | **RMSE** | **0.6678** | GBM / 2008-2009 / `daily` |
# | MAE | 0.5253 | same |
# | Bias (model − market) | 0.3093 | same |
# | Mean early-exercise frac | 0.299 | same |
#
# ### Three-panel graph — GBM · 2008-2009 · `daily`
#
# ![Study 1: GBM 2008-2009 daily panel](figures/2008-2009_gbm/daily_panel.png)
#
# *File:* `figures/2008-2009_gbm/daily_panel.png`

# %% [markdown]
# ---
#
# ## Study 2/16 — Merton · 2008-2009
#
# > **Placement key:** this block = **model=`Merton`** · **regime=`2008-2009`** · **rolling=`daily`** · lookback=`6 months`
#
# | Metric | Value | Applies to |
# |--------|------:|------------|
# | **RMSE** | **0.6597** | Merton / 2008-2009 / `daily` |
# | MAE | 0.5367 | same |
# | Bias (model − market) | 0.3461 | same |
# | Mean early-exercise frac | 0.285 | same |
#
# ### Three-panel graph — Merton · 2008-2009 · `daily`
#
# ![Study 2: Merton 2008-2009 daily panel](figures/2008-2009_merton/daily_panel.png)
#
# *File:* `figures/2008-2009_merton/daily_panel.png`

# %% [markdown]
# ---
#
# ## Study 3/16 — Heston–Merton · 2008-2009
#
# > **Placement key:** this block = **model=`Heston–Merton`** · **regime=`2008-2009`** · **rolling=`daily`** · lookback=`6 months`
#
# | Metric | Value | Applies to |
# |--------|------:|------------|
# | **RMSE** | **1.4352** | Heston–Merton / 2008-2009 / `daily` |
# | MAE | 1.1503 | same |
# | Bias (model − market) | 0.5439 | same |
# | Mean early-exercise frac | 0.327 | same |
#
# ### Three-panel graph — Heston–Merton · 2008-2009 · `daily`
#
# ![Study 3: Heston–Merton 2008-2009 daily panel](figures/2008-2009_heston_merton/daily_panel.png)
#
# *File:* `figures/2008-2009_heston_merton/daily_panel.png`

# %% [markdown]
# ---
#
# ## Study 4/16 — GARCH–Merton · 2008-2009
#
# > **Placement key:** this block = **model=`GARCH–Merton`** · **regime=`2008-2009`** · **rolling=`daily`** · lookback=`6 months`
#
# | Metric | Value | Applies to |
# |--------|------:|------------|
# | **RMSE** | **0.6990** | GARCH–Merton / 2008-2009 / `daily` |
# | MAE | 0.4570 | same |
# | Bias (model − market) | 0.3876 | same |
# | Mean early-exercise frac | 0.247 | same |
#
# ### Three-panel graph — GARCH–Merton · 2008-2009 · `daily`
#
# ![Study 4: GARCH–Merton 2008-2009 daily panel](figures/2008-2009_garch_merton/daily_panel.png)
#
# *File:* `figures/2008-2009_garch_merton/daily_panel.png`

# %% [markdown]
# ---
#
# ## Study 5/16 — GBM · 2013-2014
#
# > **Placement key:** this block = **model=`GBM`** · **regime=`2013-2014`** · **rolling=`daily`** · lookback=`6 months`
#
# | Metric | Value | Applies to |
# |--------|------:|------------|
# | **RMSE** | **0.4021** | GBM / 2013-2014 / `daily` |
# | MAE | 0.3317 | same |
# | Bias (model − market) | 0.3199 | same |
# | Mean early-exercise frac | 0.349 | same |
#
# ### Three-panel graph — GBM · 2013-2014 · `daily`
#
# ![Study 5: GBM 2013-2014 daily panel](figures/2013-2014_gbm/daily_panel.png)
#
# *File:* `figures/2013-2014_gbm/daily_panel.png`

# %% [markdown]
# ---
#
# ## Study 6/16 — Merton · 2013-2014
#
# > **Placement key:** this block = **model=`Merton`** · **regime=`2013-2014`** · **rolling=`daily`** · lookback=`6 months`
#
# | Metric | Value | Applies to |
# |--------|------:|------------|
# | **RMSE** | **0.4398** | Merton / 2013-2014 / `daily` |
# | MAE | 0.3624 | same |
# | Bias (model − market) | 0.3438 | same |
# | Mean early-exercise frac | 0.325 | same |
#
# ### Three-panel graph — Merton · 2013-2014 · `daily`
#
# ![Study 6: Merton 2013-2014 daily panel](figures/2013-2014_merton/daily_panel.png)
#
# *File:* `figures/2013-2014_merton/daily_panel.png`

# %% [markdown]
# ---
#
# ## Study 7/16 — Heston–Merton · 2013-2014
#
# > **Placement key:** this block = **model=`Heston–Merton`** · **regime=`2013-2014`** · **rolling=`daily`** · lookback=`6 months`
#
# | Metric | Value | Applies to |
# |--------|------:|------------|
# | **RMSE** | **0.7332** | Heston–Merton / 2013-2014 / `daily` |
# | MAE | 0.5264 | same |
# | Bias (model − market) | 0.3724 | same |
# | Mean early-exercise frac | 0.392 | same |
#
# ### Three-panel graph — Heston–Merton · 2013-2014 · `daily`
#
# ![Study 7: Heston–Merton 2013-2014 daily panel](figures/2013-2014_heston_merton/daily_panel.png)
#
# *File:* `figures/2013-2014_heston_merton/daily_panel.png`

# %% [markdown]
# ---
#
# ## Study 8/16 — GARCH–Merton · 2013-2014
#
# > **Placement key:** this block = **model=`GARCH–Merton`** · **regime=`2013-2014`** · **rolling=`daily`** · lookback=`6 months`
#
# | Metric | Value | Applies to |
# |--------|------:|------------|
# | **RMSE** | **0.5655** | GARCH–Merton / 2013-2014 / `daily` |
# | MAE | 0.4460 | same |
# | Bias (model − market) | 0.4381 | same |
# | Mean early-exercise frac | 0.315 | same |
#
# ### Three-panel graph — GARCH–Merton · 2013-2014 · `daily`
#
# ![Study 8: GARCH–Merton 2013-2014 daily panel](figures/2013-2014_garch_merton/daily_panel.png)
#
# *File:* `figures/2013-2014_garch_merton/daily_panel.png`

# %% [markdown]
# ---
#
# ## Study 9/16 — GBM · 2018-2019
#
# > **Placement key:** this block = **model=`GBM`** · **regime=`2018-2019`** · **rolling=`daily`** · lookback=`6 months`
#
# | Metric | Value | Applies to |
# |--------|------:|------------|
# | **RMSE** | **1.5356** | GBM / 2018-2019 / `daily` |
# | MAE | 1.1325 | same |
# | Bias (model − market) | 0.9813 | same |
# | Mean early-exercise frac | 0.257 | same |
#
# ### Three-panel graph — GBM · 2018-2019 · `daily`
#
# ![Study 9: GBM 2018-2019 daily panel](figures/2018-2019_gbm/daily_panel.png)
#
# *File:* `figures/2018-2019_gbm/daily_panel.png`

# %% [markdown]
# ---
#
# ## Study 10/16 — Merton · 2018-2019
#
# > **Placement key:** this block = **model=`Merton`** · **regime=`2018-2019`** · **rolling=`daily`** · lookback=`6 months`
#
# | Metric | Value | Applies to |
# |--------|------:|------------|
# | **RMSE** | **1.5070** | Merton / 2018-2019 / `daily` |
# | MAE | 1.1418 | same |
# | Bias (model − market) | 1.0225 | same |
# | Mean early-exercise frac | 0.240 | same |
#
# ### Three-panel graph — Merton · 2018-2019 · `daily`
#
# ![Study 10: Merton 2018-2019 daily panel](figures/2018-2019_merton/daily_panel.png)
#
# *File:* `figures/2018-2019_merton/daily_panel.png`

# %% [markdown]
# ---
#
# ## Study 11/16 — Heston–Merton · 2018-2019
#
# > **Placement key:** this block = **model=`Heston–Merton`** · **regime=`2018-2019`** · **rolling=`daily`** · lookback=`6 months`
#
# | Metric | Value | Applies to |
# |--------|------:|------------|
# | **RMSE** | **1.7732** | Heston–Merton / 2018-2019 / `daily` |
# | MAE | 1.3327 | same |
# | Bias (model − market) | 0.4463 | same |
# | Mean early-exercise frac | 0.361 | same |
#
# ### Three-panel graph — Heston–Merton · 2018-2019 · `daily`
#
# ![Study 11: Heston–Merton 2018-2019 daily panel](figures/2018-2019_heston_merton/daily_panel.png)
#
# *File:* `figures/2018-2019_heston_merton/daily_panel.png`

# %% [markdown]
# ---
#
# ## Study 12/16 — GARCH–Merton · 2018-2019
#
# > **Placement key:** this block = **model=`GARCH–Merton`** · **regime=`2018-2019`** · **rolling=`daily`** · lookback=`6 months`
#
# | Metric | Value | Applies to |
# |--------|------:|------------|
# | **RMSE** | **2.0580** | GARCH–Merton / 2018-2019 / `daily` |
# | MAE | 1.5759 | same |
# | Bias (model − market) | 1.5733 | same |
# | Mean early-exercise frac | 0.236 | same |
#
# ### Three-panel graph — GARCH–Merton · 2018-2019 · `daily`
#
# ![Study 12: GARCH–Merton 2018-2019 daily panel](figures/2018-2019_garch_merton/daily_panel.png)
#
# *File:* `figures/2018-2019_garch_merton/daily_panel.png`

# %% [markdown]
# ---
#
# ## Study 13/16 — GBM · 2019-2020
#
# > **Placement key:** this block = **model=`GBM`** · **regime=`2019-2020`** · **rolling=`daily`** · lookback=`6 months`
#
# | Metric | Value | Applies to |
# |--------|------:|------------|
# | **RMSE** | **1.7976** | GBM / 2019-2020 / `daily` |
# | MAE | 1.4235 | same |
# | Bias (model − market) | 1.2793 | same |
# | Mean early-exercise frac | 0.284 | same |
#
# ### Three-panel graph — GBM · 2019-2020 · `daily`
#
# ![Study 13: GBM 2019-2020 daily panel](figures/2019-2020_gbm/daily_panel.png)
#
# *File:* `figures/2019-2020_gbm/daily_panel.png`

# %% [markdown]
# ---
#
# ## Study 14/16 — Merton · 2019-2020
#
# > **Placement key:** this block = **model=`Merton`** · **regime=`2019-2020`** · **rolling=`daily`** · lookback=`6 months`
#
# | Metric | Value | Applies to |
# |--------|------:|------------|
# | **RMSE** | **1.8986** | Merton / 2019-2020 / `daily` |
# | MAE | 1.5285 | same |
# | Bias (model − market) | 1.3688 | same |
# | Mean early-exercise frac | 0.239 | same |
#
# ### Three-panel graph — Merton · 2019-2020 · `daily`
#
# ![Study 14: Merton 2019-2020 daily panel](figures/2019-2020_merton/daily_panel.png)
#
# *File:* `figures/2019-2020_merton/daily_panel.png`

# %% [markdown]
# ---
#
# ## Study 15/16 — Heston–Merton · 2019-2020
#
# > **Placement key:** this block = **model=`Heston–Merton`** · **regime=`2019-2020`** · **rolling=`daily`** · lookback=`6 months`
#
# | Metric | Value | Applies to |
# |--------|------:|------------|
# | **RMSE** | **2.5020** | Heston–Merton / 2019-2020 / `daily` |
# | MAE | 1.8965 | same |
# | Bias (model − market) | 0.6315 | same |
# | Mean early-exercise frac | 0.374 | same |
#
# ### Three-panel graph — Heston–Merton · 2019-2020 · `daily`
#
# ![Study 15: Heston–Merton 2019-2020 daily panel](figures/2019-2020_heston_merton/daily_panel.png)
#
# *File:* `figures/2019-2020_heston_merton/daily_panel.png`

# %% [markdown]
# ---
#
# ## Study 16/16 — GARCH–Merton · 2019-2020
#
# > **Placement key:** this block = **model=`GARCH–Merton`** · **regime=`2019-2020`** · **rolling=`daily`** · lookback=`6 months`
#
# | Metric | Value | Applies to |
# |--------|------:|------------|
# | **RMSE** | **2.6584** | GARCH–Merton / 2019-2020 / `daily` |
# | MAE | 2.1964 | same |
# | Bias (model − market) | 2.1923 | same |
# | Mean early-exercise frac | 0.191 | same |
#
# ### Three-panel graph — GARCH–Merton · 2019-2020 · `daily`
#
# ![Study 16: GARCH–Merton 2019-2020 daily panel](figures/2019-2020_garch_merton/daily_panel.png)
#
# *File:* `figures/2019-2020_garch_merton/daily_panel.png`
