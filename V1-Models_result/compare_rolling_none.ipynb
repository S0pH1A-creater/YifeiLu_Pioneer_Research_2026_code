# %% [markdown]
# # Optimal stopping comparison — rolling = `none`
#
# **What this notebook is:** a paste-together of existing study outputs for **one** rolling mode.
# Nothing was re-calibrated or re-priced here.
#
# | Fixed across all 16 blocks | Value |
# |----------------------------|-------|
# | Lookback | **6 months** |
# | Rolling calibration | **`none`** |
# | Pricing | LSM American calls on SPY (24 contracts, n_paths=2000, seed=42) |
#
# ## How to read each block
#
# Each of the **16 studies** has:
#
# | Piece | Meaning |
# |-------|---------|
# | Heading | **Model · Regime** (and study index 1–16) |
# | Metrics table | **RMSE** (primary), MAE, bias, early-exercise — for **this** model, **this** regime, rolling=`none` |
# | Three-panel figure | §6 LSM graph for that same group: **left** model vs market · **middle** mean option value · **right** exercise timing |
#
# **Order:** regimes `2008-2009` → `2013-2014` → `2018-2019` → `2019-2020`; within each regime: GBM → Merton → Heston–Merton → GARCH–Merton.
#
# Sibling notebooks (same 16 studies, different rolling only):
#
# - `compare_rolling_none.ipynb`
# - `compare_rolling_monthly.ipynb`
# - `compare_rolling_daily.ipynb`

# %% [markdown]
# ## Quick RMSE table — rolling = `none` only
#
# | # | Regime | Model | RMSE | MAE | Bias (model−mkt) |
# |---|--------|-------|-----:|----:|-----------------:|
# | 1 | 2008-2009 | GBM | **0.6200** | 0.4401 | 0.1531 |
# | 2 | 2008-2009 | Merton | **0.6200** | 0.4401 | 0.1531 |
# | 3 | 2008-2009 | Heston–Merton | **0.9793** | 0.6536 | -0.5699 |
# | 4 | 2008-2009 | GARCH–Merton | **0.6538** | 0.4773 | 0.2535 |
# | 5 | 2013-2014 | GBM | **0.7724** | 0.6020 | 0.6020 |
# | 6 | 2013-2014 | Merton | **0.7831** | 0.6031 | 0.5966 |
# | 7 | 2013-2014 | Heston–Merton | **3.8582** | 3.3421 | 3.3421 |
# | 8 | 2013-2014 | GARCH–Merton | **1.0072** | 0.8093 | 0.8093 |
# | 9 | 2018-2019 | GBM | **0.9143** | 0.6779 | -0.6169 |
# | 10 | 2018-2019 | Merton | **0.8815** | 0.6545 | -0.6065 |
# | 11 | 2018-2019 | Heston–Merton | **0.9086** | 0.7250 | 0.4286 |
# | 12 | 2018-2019 | GARCH–Merton | **0.7625** | 0.5523 | -0.4911 |
# | 13 | 2019-2020 | GBM | **2.0618** | 1.8741 | 1.8556 |
# | 14 | 2019-2020 | Merton | **2.1481** | 1.9226 | 1.9226 |
# | 15 | 2019-2020 | Heston–Merton | **2.5245** | 2.2362 | 2.2362 |
# | 16 | 2019-2020 | GARCH–Merton | **7.2019** | 6.7792 | 6.7792 |

# %% [markdown]
# ---
#
# ## Study 1/16 — GBM · 2008-2009
#
# > **Placement key:** this block = **model=`GBM`** · **regime=`2008-2009`** · **rolling=`none`** · lookback=`6 months`
#
# | Metric | Value | Applies to |
# |--------|------:|------------|
# | **RMSE** | **0.6200** | GBM / 2008-2009 / `none` |
# | MAE | 0.4401 | same |
# | Bias (model − market) | 0.1531 | same |
# | Mean early-exercise frac | 0.299 | same |
#
# ### Three-panel graph — GBM · 2008-2009 · `none`
#
# ![Study 1: GBM 2008-2009 none panel](figures/2008-2009_gbm/none_panel.png)
#
# *File:* `figures/2008-2009_gbm/none_panel.png`

# %% [markdown]
# ---
#
# ## Study 2/16 — Merton · 2008-2009
#
# > **Placement key:** this block = **model=`Merton`** · **regime=`2008-2009`** · **rolling=`none`** · lookback=`6 months`
#
# | Metric | Value | Applies to |
# |--------|------:|------------|
# | **RMSE** | **0.6200** | Merton / 2008-2009 / `none` |
# | MAE | 0.4401 | same |
# | Bias (model − market) | 0.1531 | same |
# | Mean early-exercise frac | 0.299 | same |
#
# ### Three-panel graph — Merton · 2008-2009 · `none`
#
# ![Study 2: Merton 2008-2009 none panel](figures/2008-2009_merton/none_panel.png)
#
# *File:* `figures/2008-2009_merton/none_panel.png`

# %% [markdown]
# ---
#
# ## Study 3/16 — Heston–Merton · 2008-2009
#
# > **Placement key:** this block = **model=`Heston–Merton`** · **regime=`2008-2009`** · **rolling=`none`** · lookback=`6 months`
#
# | Metric | Value | Applies to |
# |--------|------:|------------|
# | **RMSE** | **0.9793** | Heston–Merton / 2008-2009 / `none` |
# | MAE | 0.6536 | same |
# | Bias (model − market) | -0.5699 | same |
# | Mean early-exercise frac | 0.478 | same |
#
# ### Three-panel graph — Heston–Merton · 2008-2009 · `none`
#
# ![Study 3: Heston–Merton 2008-2009 none panel](figures/2008-2009_heston_merton/none_panel.png)
#
# *File:* `figures/2008-2009_heston_merton/none_panel.png`

# %% [markdown]
# ---
#
# ## Study 4/16 — GARCH–Merton · 2008-2009
#
# > **Placement key:** this block = **model=`GARCH–Merton`** · **regime=`2008-2009`** · **rolling=`none`** · lookback=`6 months`
#
# | Metric | Value | Applies to |
# |--------|------:|------------|
# | **RMSE** | **0.6538** | GARCH–Merton / 2008-2009 / `none` |
# | MAE | 0.4773 | same |
# | Bias (model − market) | 0.2535 | same |
# | Mean early-exercise frac | 0.241 | same |
#
# ### Three-panel graph — GARCH–Merton · 2008-2009 · `none`
#
# ![Study 4: GARCH–Merton 2008-2009 none panel](figures/2008-2009_garch_merton/none_panel.png)
#
# *File:* `figures/2008-2009_garch_merton/none_panel.png`

# %% [markdown]
# ---
#
# ## Study 5/16 — GBM · 2013-2014
#
# > **Placement key:** this block = **model=`GBM`** · **regime=`2013-2014`** · **rolling=`none`** · lookback=`6 months`
#
# | Metric | Value | Applies to |
# |--------|------:|------------|
# | **RMSE** | **0.7724** | GBM / 2013-2014 / `none` |
# | MAE | 0.6020 | same |
# | Bias (model − market) | 0.6020 | same |
# | Mean early-exercise frac | 0.346 | same |
#
# ### Three-panel graph — GBM · 2013-2014 · `none`
#
# ![Study 5: GBM 2013-2014 none panel](figures/2013-2014_gbm/none_panel.png)
#
# *File:* `figures/2013-2014_gbm/none_panel.png`

# %% [markdown]
# ---
#
# ## Study 6/16 — Merton · 2013-2014
#
# > **Placement key:** this block = **model=`Merton`** · **regime=`2013-2014`** · **rolling=`none`** · lookback=`6 months`
#
# | Metric | Value | Applies to |
# |--------|------:|------------|
# | **RMSE** | **0.7831** | Merton / 2013-2014 / `none` |
# | MAE | 0.6031 | same |
# | Bias (model − market) | 0.5966 | same |
# | Mean early-exercise frac | 0.345 | same |
#
# ### Three-panel graph — Merton · 2013-2014 · `none`
#
# ![Study 6: Merton 2013-2014 none panel](figures/2013-2014_merton/none_panel.png)
#
# *File:* `figures/2013-2014_merton/none_panel.png`

# %% [markdown]
# ---
#
# ## Study 7/16 — Heston–Merton · 2013-2014
#
# > **Placement key:** this block = **model=`Heston–Merton`** · **regime=`2013-2014`** · **rolling=`none`** · lookback=`6 months`
#
# | Metric | Value | Applies to |
# |--------|------:|------------|
# | **RMSE** | **3.8582** | Heston–Merton / 2013-2014 / `none` |
# | MAE | 3.3421 | same |
# | Bias (model − market) | 3.3421 | same |
# | Mean early-exercise frac | 0.107 | same |
#
# ### Three-panel graph — Heston–Merton · 2013-2014 · `none`
#
# ![Study 7: Heston–Merton 2013-2014 none panel](figures/2013-2014_heston_merton/none_panel.png)
#
# *File:* `figures/2013-2014_heston_merton/none_panel.png`

# %% [markdown]
# ---
#
# ## Study 8/16 — GARCH–Merton · 2013-2014
#
# > **Placement key:** this block = **model=`GARCH–Merton`** · **regime=`2013-2014`** · **rolling=`none`** · lookback=`6 months`
#
# | Metric | Value | Applies to |
# |--------|------:|------------|
# | **RMSE** | **1.0072** | GARCH–Merton / 2013-2014 / `none` |
# | MAE | 0.8093 | same |
# | Bias (model − market) | 0.8093 | same |
# | Mean early-exercise frac | 0.300 | same |
#
# ### Three-panel graph — GARCH–Merton · 2013-2014 · `none`
#
# ![Study 8: GARCH–Merton 2013-2014 none panel](figures/2013-2014_garch_merton/none_panel.png)
#
# *File:* `figures/2013-2014_garch_merton/none_panel.png`

# %% [markdown]
# ---
#
# ## Study 9/16 — GBM · 2018-2019
#
# > **Placement key:** this block = **model=`GBM`** · **regime=`2018-2019`** · **rolling=`none`** · lookback=`6 months`
#
# | Metric | Value | Applies to |
# |--------|------:|------------|
# | **RMSE** | **0.9143** | GBM / 2018-2019 / `none` |
# | MAE | 0.6779 | same |
# | Bias (model − market) | -0.6169 | same |
# | Mean early-exercise frac | 0.184 | same |
#
# ### Three-panel graph — GBM · 2018-2019 · `none`
#
# ![Study 9: GBM 2018-2019 none panel](figures/2018-2019_gbm/none_panel.png)
#
# *File:* `figures/2018-2019_gbm/none_panel.png`

# %% [markdown]
# ---
#
# ## Study 10/16 — Merton · 2018-2019
#
# > **Placement key:** this block = **model=`Merton`** · **regime=`2018-2019`** · **rolling=`none`** · lookback=`6 months`
#
# | Metric | Value | Applies to |
# |--------|------:|------------|
# | **RMSE** | **0.8815** | Merton / 2018-2019 / `none` |
# | MAE | 0.6545 | same |
# | Bias (model − market) | -0.6065 | same |
# | Mean early-exercise frac | 0.213 | same |
#
# ### Three-panel graph — Merton · 2018-2019 · `none`
#
# ![Study 10: Merton 2018-2019 none panel](figures/2018-2019_merton/none_panel.png)
#
# *File:* `figures/2018-2019_merton/none_panel.png`

# %% [markdown]
# ---
#
# ## Study 11/16 — Heston–Merton · 2018-2019
#
# > **Placement key:** this block = **model=`Heston–Merton`** · **regime=`2018-2019`** · **rolling=`none`** · lookback=`6 months`
#
# | Metric | Value | Applies to |
# |--------|------:|------------|
# | **RMSE** | **0.9086** | Heston–Merton / 2018-2019 / `none` |
# | MAE | 0.7250 | same |
# | Bias (model − market) | 0.4286 | same |
# | Mean early-exercise frac | 0.294 | same |
#
# ### Three-panel graph — Heston–Merton · 2018-2019 · `none`
#
# ![Study 11: Heston–Merton 2018-2019 none panel](figures/2018-2019_heston_merton/none_panel.png)
#
# *File:* `figures/2018-2019_heston_merton/none_panel.png`

# %% [markdown]
# ---
#
# ## Study 12/16 — GARCH–Merton · 2018-2019
#
# > **Placement key:** this block = **model=`GARCH–Merton`** · **regime=`2018-2019`** · **rolling=`none`** · lookback=`6 months`
#
# | Metric | Value | Applies to |
# |--------|------:|------------|
# | **RMSE** | **0.7625** | GARCH–Merton / 2018-2019 / `none` |
# | MAE | 0.5523 | same |
# | Bias (model − market) | -0.4911 | same |
# | Mean early-exercise frac | 0.210 | same |
#
# ### Three-panel graph — GARCH–Merton · 2018-2019 · `none`
#
# ![Study 12: GARCH–Merton 2018-2019 none panel](figures/2018-2019_garch_merton/none_panel.png)
#
# *File:* `figures/2018-2019_garch_merton/none_panel.png`

# %% [markdown]
# ---
#
# ## Study 13/16 — GBM · 2019-2020
#
# > **Placement key:** this block = **model=`GBM`** · **regime=`2019-2020`** · **rolling=`none`** · lookback=`6 months`
#
# | Metric | Value | Applies to |
# |--------|------:|------------|
# | **RMSE** | **2.0618** | GBM / 2019-2020 / `none` |
# | MAE | 1.8741 | same |
# | Bias (model − market) | 1.8556 | same |
# | Mean early-exercise frac | 0.285 | same |
#
# ### Three-panel graph — GBM · 2019-2020 · `none`
#
# ![Study 13: GBM 2019-2020 none panel](figures/2019-2020_gbm/none_panel.png)
#
# *File:* `figures/2019-2020_gbm/none_panel.png`

# %% [markdown]
# ---
#
# ## Study 14/16 — Merton · 2019-2020
#
# > **Placement key:** this block = **model=`Merton`** · **regime=`2019-2020`** · **rolling=`none`** · lookback=`6 months`
#
# | Metric | Value | Applies to |
# |--------|------:|------------|
# | **RMSE** | **2.1481** | Merton / 2019-2020 / `none` |
# | MAE | 1.9226 | same |
# | Bias (model − market) | 1.9226 | same |
# | Mean early-exercise frac | 0.196 | same |
#
# ### Three-panel graph — Merton · 2019-2020 · `none`
#
# ![Study 14: Merton 2019-2020 none panel](figures/2019-2020_merton/none_panel.png)
#
# *File:* `figures/2019-2020_merton/none_panel.png`

# %% [markdown]
# ---
#
# ## Study 15/16 — Heston–Merton · 2019-2020
#
# > **Placement key:** this block = **model=`Heston–Merton`** · **regime=`2019-2020`** · **rolling=`none`** · lookback=`6 months`
#
# | Metric | Value | Applies to |
# |--------|------:|------------|
# | **RMSE** | **2.5245** | Heston–Merton / 2019-2020 / `none` |
# | MAE | 2.2362 | same |
# | Bias (model − market) | 2.2362 | same |
# | Mean early-exercise frac | 0.339 | same |
#
# ### Three-panel graph — Heston–Merton · 2019-2020 · `none`
#
# ![Study 15: Heston–Merton 2019-2020 none panel](figures/2019-2020_heston_merton/none_panel.png)
#
# *File:* `figures/2019-2020_heston_merton/none_panel.png`

# %% [markdown]
# ---
#
# ## Study 16/16 — GARCH–Merton · 2019-2020
#
# > **Placement key:** this block = **model=`GARCH–Merton`** · **regime=`2019-2020`** · **rolling=`none`** · lookback=`6 months`
#
# | Metric | Value | Applies to |
# |--------|------:|------------|
# | **RMSE** | **7.2019** | GARCH–Merton / 2019-2020 / `none` |
# | MAE | 6.7792 | same |
# | Bias (model − market) | 6.7792 | same |
# | Mean early-exercise frac | 0.188 | same |
#
# ### Three-panel graph — GARCH–Merton · 2019-2020 · `none`
#
# ![Study 16: GARCH–Merton 2019-2020 none panel](figures/2019-2020_garch_merton/none_panel.png)
#
# *File:* `figures/2019-2020_garch_merton/none_panel.png`
