# %% [markdown]
# # V2 Optimal stopping comparison — rolling = `daily`
#
# **Source:** `V2-Models_result/results/` after methodological fixes (see `V2_CHANGES.md`).
# No re-tuning to beat GBM. Same contracts, \(S_0\), horizons, RN drift, seeds, RMSE as V1.
#
# | Fixed | Value |
# |-------|-------|
# | Lookback | 6 months |
# | Rolling | `daily` only |
#
# ## Layout
# 16 studies: regimes 2008-2009 → 2019-2020; within each GBM → Merton → Heston–Merton → GARCH–Merton.
# Each block: label + RMSE + three-panel graph.

# %% [markdown]
# ## Quick RMSE table — `daily`
#
# | # | Regime | Model | RMSE | MAE | Bias |
# |---|--------|-------|-----:|----:|-----:|
# | 1 | 2008-2009 | GBM | **0.6678** | 0.5253 | 0.3093 |
# | 2 | 2008-2009 | Merton | **0.6560** | 0.5329 | 0.3436 |
# | 3 | 2008-2009 | Heston–Merton | **0.6731** | 0.5142 | 0.3065 |
# | 4 | 2008-2009 | GARCH–Merton | **0.6990** | 0.4570 | 0.3876 |
# | 5 | 2013-2014 | GBM | **0.4021** | 0.3317 | 0.3199 |
# | 6 | 2013-2014 | Merton | **0.4155** | 0.3381 | 0.3065 |
# | 7 | 2013-2014 | Heston–Merton | **0.5309** | 0.4135 | 0.3819 |
# | 8 | 2013-2014 | GARCH–Merton | **0.5655** | 0.4460 | 0.4381 |
# | 9 | 2018-2019 | GBM | **1.5356** | 1.1325 | 0.9813 |
# | 10 | 2018-2019 | Merton | **1.4499** | 1.0616 | 0.9334 |
# | 11 | 2018-2019 | Heston–Merton | **2.3372** | 1.4655 | 1.0315 |
# | 12 | 2018-2019 | GARCH–Merton | **2.0580** | 1.5759 | 1.5733 |
# | 13 | 2019-2020 | GBM | **1.7976** | 1.4235 | 1.2793 |
# | 14 | 2019-2020 | Merton | **1.8588** | 1.4838 | 1.3243 |
# | 15 | 2019-2020 | Heston–Merton | **1.0636** | 0.8733 | 0.1333 |
# | 16 | 2019-2020 | GARCH–Merton | **2.6584** | 2.1964 | 2.1923 |

# %% [markdown]
# ---
#
# ## Study 1/16 — GBM · 2008-2009
#
# > **model=`GBM` · regime=`2008-2009` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.6678** |
# | MAE | 0.5253 |
# | Bias (model − market) | 0.3093 |
# | Mean early-exercise frac | 0.299 |
#
# ### Three-panel graph — GBM · 2008-2009 · `daily`
#
# ![Study 1](results/figures/2008-2009_gbm/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 2/16 — Merton · 2008-2009
#
# > **model=`Merton` · regime=`2008-2009` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.6560** |
# | MAE | 0.5329 |
# | Bias (model − market) | 0.3436 |
# | Mean early-exercise frac | 0.285 |
#
# ### Three-panel graph — Merton · 2008-2009 · `daily`
#
# ![Study 2](results/figures/2008-2009_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 3/16 — Heston–Merton · 2008-2009
#
# > **model=`Heston–Merton` · regime=`2008-2009` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.6731** |
# | MAE | 0.5142 |
# | Bias (model − market) | 0.3065 |
# | Mean early-exercise frac | 0.305 |
#
# ### Three-panel graph — Heston–Merton · 2008-2009 · `daily`
#
# ![Study 3](results/figures/2008-2009_heston_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 4/16 — GARCH–Merton · 2008-2009
#
# > **model=`GARCH–Merton` · regime=`2008-2009` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.6990** |
# | MAE | 0.4570 |
# | Bias (model − market) | 0.3876 |
# | Mean early-exercise frac | 0.247 |
#
# ### Three-panel graph — GARCH–Merton · 2008-2009 · `daily`
#
# ![Study 4](results/figures/2008-2009_garch_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 5/16 — GBM · 2013-2014
#
# > **model=`GBM` · regime=`2013-2014` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.4021** |
# | MAE | 0.3317 |
# | Bias (model − market) | 0.3199 |
# | Mean early-exercise frac | 0.349 |
#
# ### Three-panel graph — GBM · 2013-2014 · `daily`
#
# ![Study 5](results/figures/2013-2014_gbm/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 6/16 — Merton · 2013-2014
#
# > **model=`Merton` · regime=`2013-2014` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.4155** |
# | MAE | 0.3381 |
# | Bias (model − market) | 0.3065 |
# | Mean early-exercise frac | 0.331 |
#
# ### Three-panel graph — Merton · 2013-2014 · `daily`
#
# ![Study 6](results/figures/2013-2014_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 7/16 — Heston–Merton · 2013-2014
#
# > **model=`Heston–Merton` · regime=`2013-2014` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.5309** |
# | MAE | 0.4135 |
# | Bias (model − market) | 0.3819 |
# | Mean early-exercise frac | 0.359 |
#
# ### Three-panel graph — Heston–Merton · 2013-2014 · `daily`
#
# ![Study 7](results/figures/2013-2014_heston_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 8/16 — GARCH–Merton · 2013-2014
#
# > **model=`GARCH–Merton` · regime=`2013-2014` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.5655** |
# | MAE | 0.4460 |
# | Bias (model − market) | 0.4381 |
# | Mean early-exercise frac | 0.315 |
#
# ### Three-panel graph — GARCH–Merton · 2013-2014 · `daily`
#
# ![Study 8](results/figures/2013-2014_garch_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 9/16 — GBM · 2018-2019
#
# > **model=`GBM` · regime=`2018-2019` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.5356** |
# | MAE | 1.1325 |
# | Bias (model − market) | 0.9813 |
# | Mean early-exercise frac | 0.257 |
#
# ### Three-panel graph — GBM · 2018-2019 · `daily`
#
# ![Study 9](results/figures/2018-2019_gbm/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 10/16 — Merton · 2018-2019
#
# > **model=`Merton` · regime=`2018-2019` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.4499** |
# | MAE | 1.0616 |
# | Bias (model − market) | 0.9334 |
# | Mean early-exercise frac | 0.240 |
#
# ### Three-panel graph — Merton · 2018-2019 · `daily`
#
# ![Study 10](results/figures/2018-2019_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 11/16 — Heston–Merton · 2018-2019
#
# > **model=`Heston–Merton` · regime=`2018-2019` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.3372** |
# | MAE | 1.4655 |
# | Bias (model − market) | 1.0315 |
# | Mean early-exercise frac | 0.302 |
#
# ### Three-panel graph — Heston–Merton · 2018-2019 · `daily`
#
# ![Study 11](results/figures/2018-2019_heston_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 12/16 — GARCH–Merton · 2018-2019
#
# > **model=`GARCH–Merton` · regime=`2018-2019` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.0580** |
# | MAE | 1.5759 |
# | Bias (model − market) | 1.5733 |
# | Mean early-exercise frac | 0.236 |
#
# ### Three-panel graph — GARCH–Merton · 2018-2019 · `daily`
#
# ![Study 12](results/figures/2018-2019_garch_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 13/16 — GBM · 2019-2020
#
# > **model=`GBM` · regime=`2019-2020` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.7976** |
# | MAE | 1.4235 |
# | Bias (model − market) | 1.2793 |
# | Mean early-exercise frac | 0.284 |
#
# ### Three-panel graph — GBM · 2019-2020 · `daily`
#
# ![Study 13](results/figures/2019-2020_gbm/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 14/16 — Merton · 2019-2020
#
# > **model=`Merton` · regime=`2019-2020` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.8588** |
# | MAE | 1.4838 |
# | Bias (model − market) | 1.3243 |
# | Mean early-exercise frac | 0.240 |
#
# ### Three-panel graph — Merton · 2019-2020 · `daily`
#
# ![Study 14](results/figures/2019-2020_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 15/16 — Heston–Merton · 2019-2020
#
# > **model=`Heston–Merton` · regime=`2019-2020` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.0636** |
# | MAE | 0.8733 |
# | Bias (model − market) | 0.1333 |
# | Mean early-exercise frac | 0.390 |
#
# ### Three-panel graph — Heston–Merton · 2019-2020 · `daily`
#
# ![Study 15](results/figures/2019-2020_heston_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 16/16 — GARCH–Merton · 2019-2020
#
# > **model=`GARCH–Merton` · regime=`2019-2020` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.6584** |
# | MAE | 2.1964 |
# | Bias (model − market) | 2.1923 |
# | Mean early-exercise frac | 0.191 |
#
# ### Three-panel graph — GARCH–Merton · 2019-2020 · `daily`
#
# ![Study 16](results/figures/2019-2020_garch_merton/daily_panel.png)
