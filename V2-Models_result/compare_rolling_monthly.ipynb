# %% [markdown]
# # V2 Optimal stopping comparison — rolling = `monthly`
#
# **Source:** `V2-Models_result/results/` after methodological fixes (see `V2_CHANGES.md`).
# No re-tuning to beat GBM. Same contracts, \(S_0\), horizons, RN drift, seeds, RMSE as V1.
#
# | Fixed | Value |
# |-------|-------|
# | Lookback | 6 months |
# | Rolling | `monthly` only |
#
# ## Layout
# 16 studies: regimes 2008-2009 → 2019-2020; within each GBM → Merton → Heston–Merton → GARCH–Merton.
# Each block: label + RMSE + three-panel graph.

# %% [markdown]
# ## Quick RMSE table — `monthly`
#
# | # | Regime | Model | RMSE | MAE | Bias |
# |---|--------|-------|-----:|----:|-----:|
# | 1 | 2008-2009 | GBM | **0.8139** | 0.6378 | 0.4067 |
# | 2 | 2008-2009 | Merton | **0.8320** | 0.6569 | 0.4366 |
# | 3 | 2008-2009 | Heston–Merton | **0.8097** | 0.6424 | 0.4524 |
# | 4 | 2008-2009 | GARCH–Merton | **0.6302** | 0.4605 | 0.2650 |
# | 5 | 2013-2014 | GBM | **0.4572** | 0.3682 | 0.3536 |
# | 6 | 2013-2014 | Merton | **0.4786** | 0.3845 | 0.3642 |
# | 7 | 2013-2014 | Heston–Merton | **0.6535** | 0.4730 | 0.4366 |
# | 8 | 2013-2014 | GARCH–Merton | **0.6103** | 0.4818 | 0.4801 |
# | 9 | 2018-2019 | GBM | **1.6168** | 1.2303 | 1.0662 |
# | 10 | 2018-2019 | Merton | **1.5545** | 1.2042 | 1.0642 |
# | 11 | 2018-2019 | Heston–Merton | **1.3155** | 1.0910 | 0.6527 |
# | 12 | 2018-2019 | GARCH–Merton | **3.0739** | 2.1487 | 2.1487 |
# | 13 | 2019-2020 | GBM | **1.7747** | 1.4128 | 1.2189 |
# | 14 | 2019-2020 | Merton | **1.8482** | 1.4788 | 1.2675 |
# | 15 | 2019-2020 | Heston–Merton | **1.0868** | 0.8753 | 0.0601 |
# | 16 | 2019-2020 | GARCH–Merton | **3.2224** | 2.3905 | 2.2648 |

# %% [markdown]
# ---
#
# ## Study 1/16 — GBM · 2008-2009
#
# > **model=`GBM` · regime=`2008-2009` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.8139** |
# | MAE | 0.6378 |
# | Bias (model − market) | 0.4067 |
# | Mean early-exercise frac | 0.302 |
#
# ### Three-panel graph — GBM · 2008-2009 · `monthly`
#
# ![Study 1](results/figures/2008-2009_gbm/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 2/16 — Merton · 2008-2009
#
# > **model=`Merton` · regime=`2008-2009` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.8320** |
# | MAE | 0.6569 |
# | Bias (model − market) | 0.4366 |
# | Mean early-exercise frac | 0.297 |
#
# ### Three-panel graph — Merton · 2008-2009 · `monthly`
#
# ![Study 2](results/figures/2008-2009_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 3/16 — Heston–Merton · 2008-2009
#
# > **model=`Heston–Merton` · regime=`2008-2009` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.8097** |
# | MAE | 0.6424 |
# | Bias (model − market) | 0.4524 |
# | Mean early-exercise frac | 0.289 |
#
# ### Three-panel graph — Heston–Merton · 2008-2009 · `monthly`
#
# ![Study 3](results/figures/2008-2009_heston_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 4/16 — GARCH–Merton · 2008-2009
#
# > **model=`GARCH–Merton` · regime=`2008-2009` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.6302** |
# | MAE | 0.4605 |
# | Bias (model − market) | 0.2650 |
# | Mean early-exercise frac | 0.235 |
#
# ### Three-panel graph — GARCH–Merton · 2008-2009 · `monthly`
#
# ![Study 4](results/figures/2008-2009_garch_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 5/16 — GBM · 2013-2014
#
# > **model=`GBM` · regime=`2013-2014` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.4572** |
# | MAE | 0.3682 |
# | Bias (model − market) | 0.3536 |
# | Mean early-exercise frac | 0.354 |
#
# ### Three-panel graph — GBM · 2013-2014 · `monthly`
#
# ![Study 5](results/figures/2013-2014_gbm/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 6/16 — Merton · 2013-2014
#
# > **model=`Merton` · regime=`2013-2014` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.4786** |
# | MAE | 0.3845 |
# | Bias (model − market) | 0.3642 |
# | Mean early-exercise frac | 0.308 |
#
# ### Three-panel graph — Merton · 2013-2014 · `monthly`
#
# ![Study 6](results/figures/2013-2014_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 7/16 — Heston–Merton · 2013-2014
#
# > **model=`Heston–Merton` · regime=`2013-2014` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.6535** |
# | MAE | 0.4730 |
# | Bias (model − market) | 0.4366 |
# | Mean early-exercise frac | 0.311 |
#
# ### Three-panel graph — Heston–Merton · 2013-2014 · `monthly`
#
# ![Study 7](results/figures/2013-2014_heston_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 8/16 — GARCH–Merton · 2013-2014
#
# > **model=`GARCH–Merton` · regime=`2013-2014` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.6103** |
# | MAE | 0.4818 |
# | Bias (model − market) | 0.4801 |
# | Mean early-exercise frac | 0.306 |
#
# ### Three-panel graph — GARCH–Merton · 2013-2014 · `monthly`
#
# ![Study 8](results/figures/2013-2014_garch_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 9/16 — GBM · 2018-2019
#
# > **model=`GBM` · regime=`2018-2019` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.6168** |
# | MAE | 1.2303 |
# | Bias (model − market) | 1.0662 |
# | Mean early-exercise frac | 0.262 |
#
# ### Three-panel graph — GBM · 2018-2019 · `monthly`
#
# ![Study 9](results/figures/2018-2019_gbm/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 10/16 — Merton · 2018-2019
#
# > **model=`Merton` · regime=`2018-2019` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.5545** |
# | MAE | 1.2042 |
# | Bias (model − market) | 1.0642 |
# | Mean early-exercise frac | 0.225 |
#
# ### Three-panel graph — Merton · 2018-2019 · `monthly`
#
# ![Study 10](results/figures/2018-2019_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 11/16 — Heston–Merton · 2018-2019
#
# > **model=`Heston–Merton` · regime=`2018-2019` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.3155** |
# | MAE | 1.0910 |
# | Bias (model − market) | 0.6527 |
# | Mean early-exercise frac | 0.322 |
#
# ### Three-panel graph — Heston–Merton · 2018-2019 · `monthly`
#
# ![Study 11](results/figures/2018-2019_heston_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 12/16 — GARCH–Merton · 2018-2019
#
# > **model=`GARCH–Merton` · regime=`2018-2019` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **3.0739** |
# | MAE | 2.1487 |
# | Bias (model − market) | 2.1487 |
# | Mean early-exercise frac | 0.233 |
#
# ### Three-panel graph — GARCH–Merton · 2018-2019 · `monthly`
#
# ![Study 12](results/figures/2018-2019_garch_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 13/16 — GBM · 2019-2020
#
# > **model=`GBM` · regime=`2019-2020` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.7747** |
# | MAE | 1.4128 |
# | Bias (model − market) | 1.2189 |
# | Mean early-exercise frac | 0.286 |
#
# ### Three-panel graph — GBM · 2019-2020 · `monthly`
#
# ![Study 13](results/figures/2019-2020_gbm/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 14/16 — Merton · 2019-2020
#
# > **model=`Merton` · regime=`2019-2020` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.8482** |
# | MAE | 1.4788 |
# | Bias (model − market) | 1.2675 |
# | Mean early-exercise frac | 0.222 |
#
# ### Three-panel graph — Merton · 2019-2020 · `monthly`
#
# ![Study 14](results/figures/2019-2020_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 15/16 — Heston–Merton · 2019-2020
#
# > **model=`Heston–Merton` · regime=`2019-2020` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.0868** |
# | MAE | 0.8753 |
# | Bias (model − market) | 0.0601 |
# | Mean early-exercise frac | 0.383 |
#
# ### Three-panel graph — Heston–Merton · 2019-2020 · `monthly`
#
# ![Study 15](results/figures/2019-2020_heston_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 16/16 — GARCH–Merton · 2019-2020
#
# > **model=`GARCH–Merton` · regime=`2019-2020` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **3.2224** |
# | MAE | 2.3905 |
# | Bias (model − market) | 2.2648 |
# | Mean early-exercise frac | 0.197 |
#
# ### Three-panel graph — GARCH–Merton · 2019-2020 · `monthly`
#
# ![Study 16](results/figures/2019-2020_garch_merton/monthly_panel.png)
