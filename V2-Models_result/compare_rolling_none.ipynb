# %% [markdown]
# # V2 Optimal stopping comparison — rolling = `none`
#
# **Source:** `V2-Models_result/results/` after methodological fixes (see `V2_CHANGES.md`).
# No re-tuning to beat GBM. Same contracts, \(S_0\), horizons, RN drift, seeds, RMSE as V1.
#
# | Fixed | Value |
# |-------|-------|
# | Lookback | 6 months |
# | Rolling | `none` only |
#
# ## Layout
# 16 studies: regimes 2008-2009 → 2019-2020; within each GBM → Merton → Heston–Merton → GARCH–Merton.
# Each block: label + RMSE + three-panel graph.

# %% [markdown]
# ## Quick RMSE table — `none`
#
# | # | Regime | Model | RMSE | MAE | Bias |
# |---|--------|-------|-----:|----:|-----:|
# | 1 | 2008-2009 | GBM | **0.6200** | 0.4401 | 0.1531 |
# | 2 | 2008-2009 | Merton | **0.6200** | 0.4401 | 0.1531 |
# | 3 | 2008-2009 | Heston–Merton | **0.5686** | 0.4244 | 0.1315 |
# | 4 | 2008-2009 | GARCH–Merton | **0.6538** | 0.4773 | 0.2535 |
# | 5 | 2013-2014 | GBM | **0.7724** | 0.6020 | 0.6020 |
# | 6 | 2013-2014 | Merton | **0.7667** | 0.5874 | 0.5846 |
# | 7 | 2013-2014 | Heston–Merton | **2.5391** | 2.1449 | 2.1449 |
# | 8 | 2013-2014 | GARCH–Merton | **1.0072** | 0.8093 | 0.8093 |
# | 9 | 2018-2019 | GBM | **0.9143** | 0.6779 | -0.6169 |
# | 10 | 2018-2019 | Merton | **0.8772** | 0.6495 | -0.6022 |
# | 11 | 2018-2019 | Heston–Merton | **0.8801** | 0.6480 | -0.5967 |
# | 12 | 2018-2019 | GARCH–Merton | **0.7625** | 0.5523 | -0.4911 |
# | 13 | 2019-2020 | GBM | **2.0618** | 1.8741 | 1.8556 |
# | 14 | 2019-2020 | Merton | **2.1733** | 1.9500 | 1.9500 |
# | 15 | 2019-2020 | Heston–Merton | **1.4705** | 1.0153 | -0.7097 |
# | 16 | 2019-2020 | GARCH–Merton | **7.2019** | 6.7792 | 6.7792 |

# %% [markdown]
# ---
#
# ## Study 1/16 — GBM · 2008-2009
#
# > **model=`GBM` · regime=`2008-2009` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.6200** |
# | MAE | 0.4401 |
# | Bias (model − market) | 0.1531 |
# | Mean early-exercise frac | 0.299 |
#
# ### Three-panel graph — GBM · 2008-2009 · `none`
#
# ![Study 1](results/figures/2008-2009_gbm/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 2/16 — Merton · 2008-2009
#
# > **model=`Merton` · regime=`2008-2009` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.6200** |
# | MAE | 0.4401 |
# | Bias (model − market) | 0.1531 |
# | Mean early-exercise frac | 0.299 |
#
# ### Three-panel graph — Merton · 2008-2009 · `none`
#
# ![Study 2](results/figures/2008-2009_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 3/16 — Heston–Merton · 2008-2009
#
# > **model=`Heston–Merton` · regime=`2008-2009` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.5686** |
# | MAE | 0.4244 |
# | Bias (model − market) | 0.1315 |
# | Mean early-exercise frac | 0.339 |
#
# ### Three-panel graph — Heston–Merton · 2008-2009 · `none`
#
# ![Study 3](results/figures/2008-2009_heston_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 4/16 — GARCH–Merton · 2008-2009
#
# > **model=`GARCH–Merton` · regime=`2008-2009` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.6538** |
# | MAE | 0.4773 |
# | Bias (model − market) | 0.2535 |
# | Mean early-exercise frac | 0.241 |
#
# ### Three-panel graph — GARCH–Merton · 2008-2009 · `none`
#
# ![Study 4](results/figures/2008-2009_garch_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 5/16 — GBM · 2013-2014
#
# > **model=`GBM` · regime=`2013-2014` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.7724** |
# | MAE | 0.6020 |
# | Bias (model − market) | 0.6020 |
# | Mean early-exercise frac | 0.346 |
#
# ### Three-panel graph — GBM · 2013-2014 · `none`
#
# ![Study 5](results/figures/2013-2014_gbm/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 6/16 — Merton · 2013-2014
#
# > **model=`Merton` · regime=`2013-2014` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.7667** |
# | MAE | 0.5874 |
# | Bias (model − market) | 0.5846 |
# | Mean early-exercise frac | 0.336 |
#
# ### Three-panel graph — Merton · 2013-2014 · `none`
#
# ![Study 6](results/figures/2013-2014_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 7/16 — Heston–Merton · 2013-2014
#
# > **model=`Heston–Merton` · regime=`2013-2014` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.5391** |
# | MAE | 2.1449 |
# | Bias (model − market) | 2.1449 |
# | Mean early-exercise frac | 0.033 |
#
# ### Three-panel graph — Heston–Merton · 2013-2014 · `none`
#
# ![Study 7](results/figures/2013-2014_heston_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 8/16 — GARCH–Merton · 2013-2014
#
# > **model=`GARCH–Merton` · regime=`2013-2014` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.0072** |
# | MAE | 0.8093 |
# | Bias (model − market) | 0.8093 |
# | Mean early-exercise frac | 0.300 |
#
# ### Three-panel graph — GARCH–Merton · 2013-2014 · `none`
#
# ![Study 8](results/figures/2013-2014_garch_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 9/16 — GBM · 2018-2019
#
# > **model=`GBM` · regime=`2018-2019` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.9143** |
# | MAE | 0.6779 |
# | Bias (model − market) | -0.6169 |
# | Mean early-exercise frac | 0.184 |
#
# ### Three-panel graph — GBM · 2018-2019 · `none`
#
# ![Study 9](results/figures/2018-2019_gbm/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 10/16 — Merton · 2018-2019
#
# > **model=`Merton` · regime=`2018-2019` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.8772** |
# | MAE | 0.6495 |
# | Bias (model − market) | -0.6022 |
# | Mean early-exercise frac | 0.215 |
#
# ### Three-panel graph — Merton · 2018-2019 · `none`
#
# ![Study 10](results/figures/2018-2019_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 11/16 — Heston–Merton · 2018-2019
#
# > **model=`Heston–Merton` · regime=`2018-2019` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.8801** |
# | MAE | 0.6480 |
# | Bias (model − market) | -0.5967 |
# | Mean early-exercise frac | 0.213 |
#
# ### Three-panel graph — Heston–Merton · 2018-2019 · `none`
#
# ![Study 11](results/figures/2018-2019_heston_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 12/16 — GARCH–Merton · 2018-2019
#
# > **model=`GARCH–Merton` · regime=`2018-2019` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.7625** |
# | MAE | 0.5523 |
# | Bias (model − market) | -0.4911 |
# | Mean early-exercise frac | 0.210 |
#
# ### Three-panel graph — GARCH–Merton · 2018-2019 · `none`
#
# ![Study 12](results/figures/2018-2019_garch_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 13/16 — GBM · 2019-2020
#
# > **model=`GBM` · regime=`2019-2020` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.0618** |
# | MAE | 1.8741 |
# | Bias (model − market) | 1.8556 |
# | Mean early-exercise frac | 0.285 |
#
# ### Three-panel graph — GBM · 2019-2020 · `none`
#
# ![Study 13](results/figures/2019-2020_gbm/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 14/16 — Merton · 2019-2020
#
# > **model=`Merton` · regime=`2019-2020` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.1733** |
# | MAE | 1.9500 |
# | Bias (model − market) | 1.9500 |
# | Mean early-exercise frac | 0.190 |
#
# ### Three-panel graph — Merton · 2019-2020 · `none`
#
# ![Study 14](results/figures/2019-2020_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 15/16 — Heston–Merton · 2019-2020
#
# > **model=`Heston–Merton` · regime=`2019-2020` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.4705** |
# | MAE | 1.0153 |
# | Bias (model − market) | -0.7097 |
# | Mean early-exercise frac | 0.473 |
#
# ### Three-panel graph — Heston–Merton · 2019-2020 · `none`
#
# ![Study 15](results/figures/2019-2020_heston_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 16/16 — GARCH–Merton · 2019-2020
#
# > **model=`GARCH–Merton` · regime=`2019-2020` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **7.2019** |
# | MAE | 6.7792 |
# | Bias (model − market) | 6.7792 |
# | Mean early-exercise frac | 0.188 |
#
# ### Three-panel graph — GARCH–Merton · 2019-2020 · `none`
#
# ![Study 16](results/figures/2019-2020_garch_merton/none_panel.png)
