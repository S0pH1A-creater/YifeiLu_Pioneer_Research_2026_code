# %% [markdown]
# # V2 Optimal stopping comparison — rolling = `daily`
#
# **Source:** `V3-Models_result/results/{TICKER}/` after methodological fixes (see `V3_CHANGES.md`).
# Same contracts / seeds / LSM harness for **SPY**, **AAPL**, and **MSFT** (n=24, seed=42, n_paths=2000).
#
# | Fixed | Value |
# |-------|-------|
# | Lookback | 6 months |
# | Rolling | `daily` only |
# | Underlyings | SPY, AAPL, MSFT |
#
# ## Layout
# For each ticker: regimes 2008-2009 → 2019-2020; within each GBM → Merton → Heston → Heston–Merton → GARCH → GARCH–Merton.
# Each block: label + RMSE + three-panel graph.

# %% [markdown]
# # Underlying: `SPY`

# %% [markdown]
# ## Quick RMSE table — `SPY` · `daily`
#
# | # | Regime | Model | RMSE | MAE | Bias |
# |---|--------|-------|-----:|----:|-----:|
# | 1 | 2008-2009 | GBM | **0.6678** | 0.5253 | 0.3093 |
# | 2 | 2008-2009 | Merton | **0.6560** | 0.5329 | 0.3436 |
# | 3 | 2008-2009 | Heston–Merton | **0.6731** | 0.5142 | 0.3065 |
# | 4 | 2008-2009 | GARCH–Merton | **0.6990** | 0.4570 | 0.3876 |
# | 5 | 2013-2014 | GBM | **0.4021** | 0.3317 | 0.3199 |
# | 6 | 2013-2014 | Merton | **0.4155** | 0.3381 | 0.3065 |
# | 7 | 2013-2014 | Heston | **0.5244** | 0.4332 | 0.4332 |
# | 8 | 2013-2014 | Heston–Merton | **0.5010** | 0.3967 | 0.3967 |
# | 9 | 2013-2014 | GARCH–Merton | **0.5655** | 0.4460 | 0.4381 |
# | 10 | 2018-2019 | GBM | **1.5356** | 1.1325 | 0.9813 |
# | 11 | 2018-2019 | Merton | **1.4499** | 1.0616 | 0.9334 |
# | 12 | 2018-2019 | Heston | **1.5392** | 1.1894 | 1.1894 |
# | 13 | 2018-2019 | Heston–Merton | **1.1321** | 0.9110 | 0.7288 |
# | 14 | 2018-2019 | GARCH–Merton | **2.0580** | 1.5759 | 1.5733 |
# | 15 | 2019-2020 | GBM | **1.7976** | 1.4235 | 1.2793 |
# | 16 | 2019-2020 | Merton | **1.8588** | 1.4838 | 1.3243 |
# | 17 | 2019-2020 | Heston | **1.4268** | 1.1500 | 1.1500 |
# | 18 | 2019-2020 | Heston–Merton | **0.5782** | 0.4410 | 0.3718 |
# | 19 | 2019-2020 | GARCH–Merton | **2.6584** | 2.1964 | 2.1923 |

# %% [markdown]
# ---
#
# ## Study 1/19 — GBM · 2008-2009 · SPY
#
# > **underlying=`SPY` · model=`GBM` · regime=`2008-2009` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.6678** |
# | MAE | 0.5253 |
# | Bias (model − market) | 0.3093 |
# | Mean early-exercise frac | 0.299 |
#
# ### Three-panel graph — GBM · 2008-2009 · SPY · `daily`
#
# ![Study 1 SPY](results/SPY/figures/2008-2009_gbm/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 2/19 — Merton · 2008-2009 · SPY
#
# > **underlying=`SPY` · model=`Merton` · regime=`2008-2009` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.6560** |
# | MAE | 0.5329 |
# | Bias (model − market) | 0.3436 |
# | Mean early-exercise frac | 0.285 |
#
# ### Three-panel graph — Merton · 2008-2009 · SPY · `daily`
#
# ![Study 2 SPY](results/SPY/figures/2008-2009_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 3/19 — Heston–Merton · 2008-2009 · SPY
#
# > **underlying=`SPY` · model=`Heston–Merton` · regime=`2008-2009` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.6731** |
# | MAE | 0.5142 |
# | Bias (model − market) | 0.3065 |
# | Mean early-exercise frac | 0.305 |
#
# ### Three-panel graph — Heston–Merton · 2008-2009 · SPY · `daily`
#
# ![Study 3 SPY](results/SPY/figures/2008-2009_heston_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 4/19 — GARCH–Merton · 2008-2009 · SPY
#
# > **underlying=`SPY` · model=`GARCH–Merton` · regime=`2008-2009` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.6990** |
# | MAE | 0.4570 |
# | Bias (model − market) | 0.3876 |
# | Mean early-exercise frac | 0.247 |
#
# ### Three-panel graph — GARCH–Merton · 2008-2009 · SPY · `daily`
#
# ![Study 4 SPY](results/SPY/figures/2008-2009_garch_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 5/19 — GBM · 2013-2014 · SPY
#
# > **underlying=`SPY` · model=`GBM` · regime=`2013-2014` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.4021** |
# | MAE | 0.3317 |
# | Bias (model − market) | 0.3199 |
# | Mean early-exercise frac | 0.349 |
#
# ### Three-panel graph — GBM · 2013-2014 · SPY · `daily`
#
# ![Study 5 SPY](results/SPY/figures/2013-2014_gbm/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 6/19 — Merton · 2013-2014 · SPY
#
# > **underlying=`SPY` · model=`Merton` · regime=`2013-2014` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.4155** |
# | MAE | 0.3381 |
# | Bias (model − market) | 0.3065 |
# | Mean early-exercise frac | 0.331 |
#
# ### Three-panel graph — Merton · 2013-2014 · SPY · `daily`
#
# ![Study 6 SPY](results/SPY/figures/2013-2014_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 7/19 — Heston · 2013-2014 · SPY
#
# > **underlying=`SPY` · model=`Heston` · regime=`2013-2014` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.5244** |
# | MAE | 0.4332 |
# | Bias (model − market) | 0.4332 |
# | Mean early-exercise frac | 0.392 |
#
# ### Three-panel graph — Heston · 2013-2014 · SPY · `daily`
#
# ![Study 7 SPY](results/SPY/figures/2013-2014_heston/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 8/19 — Heston–Merton · 2013-2014 · SPY
#
# > **underlying=`SPY` · model=`Heston–Merton` · regime=`2013-2014` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.5010** |
# | MAE | 0.3967 |
# | Bias (model − market) | 0.3967 |
# | Mean early-exercise frac | 0.370 |
#
# ### Three-panel graph — Heston–Merton · 2013-2014 · SPY · `daily`
#
# ![Study 8 SPY](results/SPY/figures/2013-2014_heston_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 9/19 — GARCH–Merton · 2013-2014 · SPY
#
# > **underlying=`SPY` · model=`GARCH–Merton` · regime=`2013-2014` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.5655** |
# | MAE | 0.4460 |
# | Bias (model − market) | 0.4381 |
# | Mean early-exercise frac | 0.315 |
#
# ### Three-panel graph — GARCH–Merton · 2013-2014 · SPY · `daily`
#
# ![Study 9 SPY](results/SPY/figures/2013-2014_garch_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 10/19 — GBM · 2018-2019 · SPY
#
# > **underlying=`SPY` · model=`GBM` · regime=`2018-2019` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.5356** |
# | MAE | 1.1325 |
# | Bias (model − market) | 0.9813 |
# | Mean early-exercise frac | 0.257 |
#
# ### Three-panel graph — GBM · 2018-2019 · SPY · `daily`
#
# ![Study 10 SPY](results/SPY/figures/2018-2019_gbm/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 11/19 — Merton · 2018-2019 · SPY
#
# > **underlying=`SPY` · model=`Merton` · regime=`2018-2019` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.4499** |
# | MAE | 1.0616 |
# | Bias (model − market) | 0.9334 |
# | Mean early-exercise frac | 0.240 |
#
# ### Three-panel graph — Merton · 2018-2019 · SPY · `daily`
#
# ![Study 11 SPY](results/SPY/figures/2018-2019_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 12/19 — Heston · 2018-2019 · SPY
#
# > **underlying=`SPY` · model=`Heston` · regime=`2018-2019` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.5392** |
# | MAE | 1.1894 |
# | Bias (model − market) | 1.1894 |
# | Mean early-exercise frac | 0.293 |
#
# ### Three-panel graph — Heston · 2018-2019 · SPY · `daily`
#
# ![Study 12 SPY](results/SPY/figures/2018-2019_heston/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 13/19 — Heston–Merton · 2018-2019 · SPY
#
# > **underlying=`SPY` · model=`Heston–Merton` · regime=`2018-2019` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.1321** |
# | MAE | 0.9110 |
# | Bias (model − market) | 0.7288 |
# | Mean early-exercise frac | 0.324 |
#
# ### Three-panel graph — Heston–Merton · 2018-2019 · SPY · `daily`
#
# ![Study 13 SPY](results/SPY/figures/2018-2019_heston_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 14/19 — GARCH–Merton · 2018-2019 · SPY
#
# > **underlying=`SPY` · model=`GARCH–Merton` · regime=`2018-2019` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.0580** |
# | MAE | 1.5759 |
# | Bias (model − market) | 1.5733 |
# | Mean early-exercise frac | 0.236 |
#
# ### Three-panel graph — GARCH–Merton · 2018-2019 · SPY · `daily`
#
# ![Study 14 SPY](results/SPY/figures/2018-2019_garch_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 15/19 — GBM · 2019-2020 · SPY
#
# > **underlying=`SPY` · model=`GBM` · regime=`2019-2020` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.7976** |
# | MAE | 1.4235 |
# | Bias (model − market) | 1.2793 |
# | Mean early-exercise frac | 0.284 |
#
# ### Three-panel graph — GBM · 2019-2020 · SPY · `daily`
#
# ![Study 15 SPY](results/SPY/figures/2019-2020_gbm/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 16/19 — Merton · 2019-2020 · SPY
#
# > **underlying=`SPY` · model=`Merton` · regime=`2019-2020` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.8588** |
# | MAE | 1.4838 |
# | Bias (model − market) | 1.3243 |
# | Mean early-exercise frac | 0.240 |
#
# ### Three-panel graph — Merton · 2019-2020 · SPY · `daily`
#
# ![Study 16 SPY](results/SPY/figures/2019-2020_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 17/19 — Heston · 2019-2020 · SPY
#
# > **underlying=`SPY` · model=`Heston` · regime=`2019-2020` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.4268** |
# | MAE | 1.1500 |
# | Bias (model − market) | 1.1500 |
# | Mean early-exercise frac | 0.315 |
#
# ### Three-panel graph — Heston · 2019-2020 · SPY · `daily`
#
# ![Study 17 SPY](results/SPY/figures/2019-2020_heston/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 18/19 — Heston–Merton · 2019-2020 · SPY
#
# > **underlying=`SPY` · model=`Heston–Merton` · regime=`2019-2020` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.5782** |
# | MAE | 0.4410 |
# | Bias (model − market) | 0.3718 |
# | Mean early-exercise frac | 0.310 |
#
# ### Three-panel graph — Heston–Merton · 2019-2020 · SPY · `daily`
#
# ![Study 18 SPY](results/SPY/figures/2019-2020_heston_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 19/19 — GARCH–Merton · 2019-2020 · SPY
#
# > **underlying=`SPY` · model=`GARCH–Merton` · regime=`2019-2020` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.6584** |
# | MAE | 2.1964 |
# | Bias (model − market) | 2.1923 |
# | Mean early-exercise frac | 0.191 |
#
# ### Three-panel graph — GARCH–Merton · 2019-2020 · SPY · `daily`
#
# ![Study 19 SPY](results/SPY/figures/2019-2020_garch_merton/daily_panel.png)

# %% [markdown]
# # Underlying: `AAPL`

# %% [markdown]
# ## Quick RMSE table — `AAPL` · `daily`
#
# | # | Regime | Model | RMSE | MAE | Bias |
# |---|--------|-------|-----:|----:|-----:|
# | 1 | 2008-2009 | GBM | **2.1442** | 1.8399 | 1.5191 |
# | 2 | 2008-2009 | Merton | **2.0929** | 1.7377 | 1.4776 |
# | 3 | 2008-2009 | Heston–Merton | **4.9126** | 3.7769 | 3.4199 |
# | 4 | 2008-2009 | GARCH–Merton | **2.9586** | 2.2743 | 1.8845 |
# | 5 | 2013-2014 | GBM | **3.4746** | 2.5452 | 2.3226 |
# | 6 | 2013-2014 | Merton | **2.9473** | 2.1999 | 1.9768 |
# | 7 | 2013-2014 | Heston | **3.7261** | 2.8619 | 2.7603 |
# | 8 | 2013-2014 | Heston–Merton | **3.0865** | 2.3252 | 2.3252 |
# | 9 | 2013-2014 | GARCH–Merton | **7.2481** | 5.1280 | 5.1141 |
# | 10 | 2018-2019 | GBM | **1.8064** | 1.2107 | 0.8674 |
# | 11 | 2018-2019 | Merton | **1.7155** | 1.1588 | 0.8179 |
# | 12 | 2018-2019 | Heston | **0.8220** | 0.6793 | 0.2840 |
# | 13 | 2018-2019 | Heston–Merton | **1.6834** | 1.3173 | 1.2789 |
# | 14 | 2018-2019 | GARCH–Merton | **3.9754** | 2.9800 | 2.9246 |
# | 15 | 2019-2020 | GBM | **2.0972** | 1.6606 | 1.5730 |
# | 16 | 2019-2020 | Merton | **2.0578** | 1.6737 | 1.5688 |
# | 17 | 2019-2020 | Heston | **1.9124** | 1.6257 | 1.6257 |
# | 18 | 2019-2020 | Heston–Merton | **2.3699** | 1.8825 | 1.8698 |
# | 19 | 2019-2020 | GARCH–Merton | **4.1158** | 3.5165 | 3.4759 |

# %% [markdown]
# ---
#
# ## Study 1/19 — GBM · 2008-2009 · AAPL
#
# > **underlying=`AAPL` · model=`GBM` · regime=`2008-2009` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.1442** |
# | MAE | 1.8399 |
# | Bias (model − market) | 1.5191 |
# | Mean early-exercise frac | 0.247 |
#
# ### Three-panel graph — GBM · 2008-2009 · AAPL · `daily`
#
# ![Study 1 AAPL](results/AAPL/figures/2008-2009_gbm/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 2/19 — Merton · 2008-2009 · AAPL
#
# > **underlying=`AAPL` · model=`Merton` · regime=`2008-2009` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.0929** |
# | MAE | 1.7377 |
# | Bias (model − market) | 1.4776 |
# | Mean early-exercise frac | 0.228 |
#
# ### Three-panel graph — Merton · 2008-2009 · AAPL · `daily`
#
# ![Study 2 AAPL](results/AAPL/figures/2008-2009_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 3/19 — Heston–Merton · 2008-2009 · AAPL
#
# > **underlying=`AAPL` · model=`Heston–Merton` · regime=`2008-2009` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **4.9126** |
# | MAE | 3.7769 |
# | Bias (model − market) | 3.4199 |
# | Mean early-exercise frac | 0.166 |
#
# ### Three-panel graph — Heston–Merton · 2008-2009 · AAPL · `daily`
#
# ![Study 3 AAPL](results/AAPL/figures/2008-2009_heston_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 4/19 — GARCH–Merton · 2008-2009 · AAPL
#
# > **underlying=`AAPL` · model=`GARCH–Merton` · regime=`2008-2009` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.9586** |
# | MAE | 2.2743 |
# | Bias (model − market) | 1.8845 |
# | Mean early-exercise frac | 0.175 |
#
# ### Three-panel graph — GARCH–Merton · 2008-2009 · AAPL · `daily`
#
# ![Study 4 AAPL](results/AAPL/figures/2008-2009_garch_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 5/19 — GBM · 2013-2014 · AAPL
#
# > **underlying=`AAPL` · model=`GBM` · regime=`2013-2014` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **3.4746** |
# | MAE | 2.5452 |
# | Bias (model − market) | 2.3226 |
# | Mean early-exercise frac | 0.274 |
#
# ### Three-panel graph — GBM · 2013-2014 · AAPL · `daily`
#
# ![Study 5 AAPL](results/AAPL/figures/2013-2014_gbm/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 6/19 — Merton · 2013-2014 · AAPL
#
# > **underlying=`AAPL` · model=`Merton` · regime=`2013-2014` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.9473** |
# | MAE | 2.1999 |
# | Bias (model − market) | 1.9768 |
# | Mean early-exercise frac | 0.217 |
#
# ### Three-panel graph — Merton · 2013-2014 · AAPL · `daily`
#
# ![Study 6 AAPL](results/AAPL/figures/2013-2014_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 7/19 — Heston · 2013-2014 · AAPL
#
# > **underlying=`AAPL` · model=`Heston` · regime=`2013-2014` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **3.7261** |
# | MAE | 2.8619 |
# | Bias (model − market) | 2.7603 |
# | Mean early-exercise frac | 0.315 |
#
# ### Three-panel graph — Heston · 2013-2014 · AAPL · `daily`
#
# ![Study 7 AAPL](results/AAPL/figures/2013-2014_heston/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 8/19 — Heston–Merton · 2013-2014 · AAPL
#
# > **underlying=`AAPL` · model=`Heston–Merton` · regime=`2013-2014` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **3.0865** |
# | MAE | 2.3252 |
# | Bias (model − market) | 2.3252 |
# | Mean early-exercise frac | 0.232 |
#
# ### Three-panel graph — Heston–Merton · 2013-2014 · AAPL · `daily`
#
# ![Study 8 AAPL](results/AAPL/figures/2013-2014_heston_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 9/19 — GARCH–Merton · 2013-2014 · AAPL
#
# > **underlying=`AAPL` · model=`GARCH–Merton` · regime=`2013-2014` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **7.2481** |
# | MAE | 5.1280 |
# | Bias (model − market) | 5.1141 |
# | Mean early-exercise frac | 0.212 |
#
# ### Three-panel graph — GARCH–Merton · 2013-2014 · AAPL · `daily`
#
# ![Study 9 AAPL](results/AAPL/figures/2013-2014_garch_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 10/19 — GBM · 2018-2019 · AAPL
#
# > **underlying=`AAPL` · model=`GBM` · regime=`2018-2019` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.8064** |
# | MAE | 1.2107 |
# | Bias (model − market) | 0.8674 |
# | Mean early-exercise frac | 0.237 |
#
# ### Three-panel graph — GBM · 2018-2019 · AAPL · `daily`
#
# ![Study 10 AAPL](results/AAPL/figures/2018-2019_gbm/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 11/19 — Merton · 2018-2019 · AAPL
#
# > **underlying=`AAPL` · model=`Merton` · regime=`2018-2019` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.7155** |
# | MAE | 1.1588 |
# | Bias (model − market) | 0.8179 |
# | Mean early-exercise frac | 0.245 |
#
# ### Three-panel graph — Merton · 2018-2019 · AAPL · `daily`
#
# ![Study 11 AAPL](results/AAPL/figures/2018-2019_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 12/19 — Heston · 2018-2019 · AAPL
#
# > **underlying=`AAPL` · model=`Heston` · regime=`2018-2019` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.8220** |
# | MAE | 0.6793 |
# | Bias (model − market) | 0.2840 |
# | Mean early-exercise frac | 0.292 |
#
# ### Three-panel graph — Heston · 2018-2019 · AAPL · `daily`
#
# ![Study 12 AAPL](results/AAPL/figures/2018-2019_heston/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 13/19 — Heston–Merton · 2018-2019 · AAPL
#
# > **underlying=`AAPL` · model=`Heston–Merton` · regime=`2018-2019` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.6834** |
# | MAE | 1.3173 |
# | Bias (model − market) | 1.2789 |
# | Mean early-exercise frac | 0.268 |
#
# ### Three-panel graph — Heston–Merton · 2018-2019 · AAPL · `daily`
#
# ![Study 13 AAPL](results/AAPL/figures/2018-2019_heston_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 14/19 — GARCH–Merton · 2018-2019 · AAPL
#
# > **underlying=`AAPL` · model=`GARCH–Merton` · regime=`2018-2019` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **3.9754** |
# | MAE | 2.9800 |
# | Bias (model − market) | 2.9246 |
# | Mean early-exercise frac | 0.210 |
#
# ### Three-panel graph — GARCH–Merton · 2018-2019 · AAPL · `daily`
#
# ![Study 14 AAPL](results/AAPL/figures/2018-2019_garch_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 15/19 — GBM · 2019-2020 · AAPL
#
# > **underlying=`AAPL` · model=`GBM` · regime=`2019-2020` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.0972** |
# | MAE | 1.6606 |
# | Bias (model − market) | 1.5730 |
# | Mean early-exercise frac | 0.297 |
#
# ### Three-panel graph — GBM · 2019-2020 · AAPL · `daily`
#
# ![Study 15 AAPL](results/AAPL/figures/2019-2020_gbm/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 16/19 — Merton · 2019-2020 · AAPL
#
# > **underlying=`AAPL` · model=`Merton` · regime=`2019-2020` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.0578** |
# | MAE | 1.6737 |
# | Bias (model − market) | 1.5688 |
# | Mean early-exercise frac | 0.265 |
#
# ### Three-panel graph — Merton · 2019-2020 · AAPL · `daily`
#
# ![Study 16 AAPL](results/AAPL/figures/2019-2020_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 17/19 — Heston · 2019-2020 · AAPL
#
# > **underlying=`AAPL` · model=`Heston` · regime=`2019-2020` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.9124** |
# | MAE | 1.6257 |
# | Bias (model − market) | 1.6257 |
# | Mean early-exercise frac | 0.332 |
#
# ### Three-panel graph — Heston · 2019-2020 · AAPL · `daily`
#
# ![Study 17 AAPL](results/AAPL/figures/2019-2020_heston/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 18/19 — Heston–Merton · 2019-2020 · AAPL
#
# > **underlying=`AAPL` · model=`Heston–Merton` · regime=`2019-2020` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.3699** |
# | MAE | 1.8825 |
# | Bias (model − market) | 1.8698 |
# | Mean early-exercise frac | 0.280 |
#
# ### Three-panel graph — Heston–Merton · 2019-2020 · AAPL · `daily`
#
# ![Study 18 AAPL](results/AAPL/figures/2019-2020_heston_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 19/19 — GARCH–Merton · 2019-2020 · AAPL
#
# > **underlying=`AAPL` · model=`GARCH–Merton` · regime=`2019-2020` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **4.1158** |
# | MAE | 3.5165 |
# | Bias (model − market) | 3.4759 |
# | Mean early-exercise frac | 0.221 |
#
# ### Three-panel graph — GARCH–Merton · 2019-2020 · AAPL · `daily`
#
# ![Study 19 AAPL](results/AAPL/figures/2019-2020_garch_merton/daily_panel.png)

# %% [markdown]
# # Underlying: `MSFT`

# %% [markdown]
# ## Quick RMSE table — `MSFT` · `daily`
#
# | # | Regime | Model | RMSE | MAE | Bias |
# |---|--------|-------|-----:|----:|-----:|
# | 1 | 2008-2009 | GBM | **0.5076** | 0.3999 | 0.3276 |
# | 2 | 2008-2009 | Merton | **0.4913** | 0.4000 | 0.3111 |
# | 3 | 2008-2009 | Heston–Merton | **1.6848** | 1.0986 | 0.9606 |
# | 4 | 2008-2009 | GARCH–Merton | **1.0189** | 0.7611 | 0.7541 |
# | 5 | 2013-2014 | GBM | **0.2282** | 0.1660 | 0.1224 |
# | 6 | 2013-2014 | Merton | **0.2191** | 0.1629 | 0.1134 |
# | 7 | 2013-2014 | Heston | **0.1965** | 0.1562 | 0.1562 |
# | 8 | 2013-2014 | Heston–Merton | **0.2517** | 0.2097 | 0.2097 |
# | 9 | 2013-2014 | GARCH–Merton | **0.4488** | 0.3391 | 0.3034 |
# | 10 | 2018-2019 | GBM | **1.0192** | 0.6682 | 0.3543 |
# | 11 | 2018-2019 | Merton | **1.0099** | 0.6574 | 0.3690 |
# | 12 | 2018-2019 | Heston | **0.7160** | 0.5790 | 0.5583 |
# | 13 | 2018-2019 | Heston–Merton | **0.6319** | 0.5411 | 0.5355 |
# | 14 | 2018-2019 | GARCH–Merton | **1.3519** | 0.9245 | 0.8098 |
# | 15 | 2019-2020 | GBM | **0.9498** | 0.7194 | 0.4940 |
# | 16 | 2019-2020 | Merton | **0.9964** | 0.7450 | 0.5084 |
# | 17 | 2019-2020 | Heston | **0.8138** | 0.6681 | 0.6661 |
# | 18 | 2019-2020 | Heston–Merton | **0.7433** | 0.5928 | 0.5686 |
# | 19 | 2019-2020 | GARCH–Merton | **1.2630** | 0.9537 | 0.7982 |

# %% [markdown]
# ---
#
# ## Study 1/19 — GBM · 2008-2009 · MSFT
#
# > **underlying=`MSFT` · model=`GBM` · regime=`2008-2009` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.5076** |
# | MAE | 0.3999 |
# | Bias (model − market) | 0.3276 |
# | Mean early-exercise frac | 0.283 |
#
# ### Three-panel graph — GBM · 2008-2009 · MSFT · `daily`
#
# ![Study 1 MSFT](results/MSFT/figures/2008-2009_gbm/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 2/19 — Merton · 2008-2009 · MSFT
#
# > **underlying=`MSFT` · model=`Merton` · regime=`2008-2009` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.4913** |
# | MAE | 0.4000 |
# | Bias (model − market) | 0.3111 |
# | Mean early-exercise frac | 0.196 |
#
# ### Three-panel graph — Merton · 2008-2009 · MSFT · `daily`
#
# ![Study 2 MSFT](results/MSFT/figures/2008-2009_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 3/19 — Heston–Merton · 2008-2009 · MSFT
#
# > **underlying=`MSFT` · model=`Heston–Merton` · regime=`2008-2009` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.6848** |
# | MAE | 1.0986 |
# | Bias (model − market) | 0.9606 |
# | Mean early-exercise frac | 0.171 |
#
# ### Three-panel graph — Heston–Merton · 2008-2009 · MSFT · `daily`
#
# ![Study 3 MSFT](results/MSFT/figures/2008-2009_heston_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 4/19 — GARCH–Merton · 2008-2009 · MSFT
#
# > **underlying=`MSFT` · model=`GARCH–Merton` · regime=`2008-2009` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.0189** |
# | MAE | 0.7611 |
# | Bias (model − market) | 0.7541 |
# | Mean early-exercise frac | 0.208 |
#
# ### Three-panel graph — GARCH–Merton · 2008-2009 · MSFT · `daily`
#
# ![Study 4 MSFT](results/MSFT/figures/2008-2009_garch_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 5/19 — GBM · 2013-2014 · MSFT
#
# > **underlying=`MSFT` · model=`GBM` · regime=`2013-2014` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.2282** |
# | MAE | 0.1660 |
# | Bias (model − market) | 0.1224 |
# | Mean early-exercise frac | 0.287 |
#
# ### Three-panel graph — GBM · 2013-2014 · MSFT · `daily`
#
# ![Study 5 MSFT](results/MSFT/figures/2013-2014_gbm/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 6/19 — Merton · 2013-2014 · MSFT
#
# > **underlying=`MSFT` · model=`Merton` · regime=`2013-2014` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.2191** |
# | MAE | 0.1629 |
# | Bias (model − market) | 0.1134 |
# | Mean early-exercise frac | 0.230 |
#
# ### Three-panel graph — Merton · 2013-2014 · MSFT · `daily`
#
# ![Study 6 MSFT](results/MSFT/figures/2013-2014_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 7/19 — Heston · 2013-2014 · MSFT
#
# > **underlying=`MSFT` · model=`Heston` · regime=`2013-2014` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.1965** |
# | MAE | 0.1562 |
# | Bias (model − market) | 0.1562 |
# | Mean early-exercise frac | 0.347 |
#
# ### Three-panel graph — Heston · 2013-2014 · MSFT · `daily`
#
# ![Study 7 MSFT](results/MSFT/figures/2013-2014_heston/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 8/19 — Heston–Merton · 2013-2014 · MSFT
#
# > **underlying=`MSFT` · model=`Heston–Merton` · regime=`2013-2014` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.2517** |
# | MAE | 0.2097 |
# | Bias (model − market) | 0.2097 |
# | Mean early-exercise frac | 0.286 |
#
# ### Three-panel graph — Heston–Merton · 2013-2014 · MSFT · `daily`
#
# ![Study 8 MSFT](results/MSFT/figures/2013-2014_heston_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 9/19 — GARCH–Merton · 2013-2014 · MSFT
#
# > **underlying=`MSFT` · model=`GARCH–Merton` · regime=`2013-2014` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.4488** |
# | MAE | 0.3391 |
# | Bias (model − market) | 0.3034 |
# | Mean early-exercise frac | 0.227 |
#
# ### Three-panel graph — GARCH–Merton · 2013-2014 · MSFT · `daily`
#
# ![Study 9 MSFT](results/MSFT/figures/2013-2014_garch_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 10/19 — GBM · 2018-2019 · MSFT
#
# > **underlying=`MSFT` · model=`GBM` · regime=`2018-2019` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.0192** |
# | MAE | 0.6682 |
# | Bias (model − market) | 0.3543 |
# | Mean early-exercise frac | 0.275 |
#
# ### Three-panel graph — GBM · 2018-2019 · MSFT · `daily`
#
# ![Study 10 MSFT](results/MSFT/figures/2018-2019_gbm/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 11/19 — Merton · 2018-2019 · MSFT
#
# > **underlying=`MSFT` · model=`Merton` · regime=`2018-2019` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.0099** |
# | MAE | 0.6574 |
# | Bias (model − market) | 0.3690 |
# | Mean early-exercise frac | 0.272 |
#
# ### Three-panel graph — Merton · 2018-2019 · MSFT · `daily`
#
# ![Study 11 MSFT](results/MSFT/figures/2018-2019_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 12/19 — Heston · 2018-2019 · MSFT
#
# > **underlying=`MSFT` · model=`Heston` · regime=`2018-2019` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.7160** |
# | MAE | 0.5790 |
# | Bias (model − market) | 0.5583 |
# | Mean early-exercise frac | 0.301 |
#
# ### Three-panel graph — Heston · 2018-2019 · MSFT · `daily`
#
# ![Study 12 MSFT](results/MSFT/figures/2018-2019_heston/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 13/19 — Heston–Merton · 2018-2019 · MSFT
#
# > **underlying=`MSFT` · model=`Heston–Merton` · regime=`2018-2019` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.6319** |
# | MAE | 0.5411 |
# | Bias (model − market) | 0.5355 |
# | Mean early-exercise frac | 0.270 |
#
# ### Three-panel graph — Heston–Merton · 2018-2019 · MSFT · `daily`
#
# ![Study 13 MSFT](results/MSFT/figures/2018-2019_heston_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 14/19 — GARCH–Merton · 2018-2019 · MSFT
#
# > **underlying=`MSFT` · model=`GARCH–Merton` · regime=`2018-2019` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.3519** |
# | MAE | 0.9245 |
# | Bias (model − market) | 0.8098 |
# | Mean early-exercise frac | 0.223 |
#
# ### Three-panel graph — GARCH–Merton · 2018-2019 · MSFT · `daily`
#
# ![Study 14 MSFT](results/MSFT/figures/2018-2019_garch_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 15/19 — GBM · 2019-2020 · MSFT
#
# > **underlying=`MSFT` · model=`GBM` · regime=`2019-2020` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.9498** |
# | MAE | 0.7194 |
# | Bias (model − market) | 0.4940 |
# | Mean early-exercise frac | 0.275 |
#
# ### Three-panel graph — GBM · 2019-2020 · MSFT · `daily`
#
# ![Study 15 MSFT](results/MSFT/figures/2019-2020_gbm/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 16/19 — Merton · 2019-2020 · MSFT
#
# > **underlying=`MSFT` · model=`Merton` · regime=`2019-2020` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.9964** |
# | MAE | 0.7450 |
# | Bias (model − market) | 0.5084 |
# | Mean early-exercise frac | 0.270 |
#
# ### Three-panel graph — Merton · 2019-2020 · MSFT · `daily`
#
# ![Study 16 MSFT](results/MSFT/figures/2019-2020_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 17/19 — Heston · 2019-2020 · MSFT
#
# > **underlying=`MSFT` · model=`Heston` · regime=`2019-2020` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.8138** |
# | MAE | 0.6681 |
# | Bias (model − market) | 0.6661 |
# | Mean early-exercise frac | 0.273 |
#
# ### Three-panel graph — Heston · 2019-2020 · MSFT · `daily`
#
# ![Study 17 MSFT](results/MSFT/figures/2019-2020_heston/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 18/19 — Heston–Merton · 2019-2020 · MSFT
#
# > **underlying=`MSFT` · model=`Heston–Merton` · regime=`2019-2020` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.7433** |
# | MAE | 0.5928 |
# | Bias (model − market) | 0.5686 |
# | Mean early-exercise frac | 0.310 |
#
# ### Three-panel graph — Heston–Merton · 2019-2020 · MSFT · `daily`
#
# ![Study 18 MSFT](results/MSFT/figures/2019-2020_heston_merton/daily_panel.png)

# %% [markdown]
# ---
#
# ## Study 19/19 — GARCH–Merton · 2019-2020 · MSFT
#
# > **underlying=`MSFT` · model=`GARCH–Merton` · regime=`2019-2020` · rolling=`daily` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.2630** |
# | MAE | 0.9537 |
# | Bias (model − market) | 0.7982 |
# | Mean early-exercise frac | 0.254 |
#
# ### Three-panel graph — GARCH–Merton · 2019-2020 · MSFT · `daily`
#
# ![Study 19 MSFT](results/MSFT/figures/2019-2020_garch_merton/daily_panel.png)
