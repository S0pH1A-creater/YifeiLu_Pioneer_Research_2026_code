# %% [markdown]
# # V2 Optimal stopping comparison — rolling = `monthly`
#
# **Source:** `V3-Models_result/results/{TICKER}/` after methodological fixes (see `V3_CHANGES.md`).
# Same contracts / seeds / LSM harness for **SPY**, **AAPL**, and **MSFT** (n=24, seed=42, n_paths=2000).
#
# | Fixed | Value |
# |-------|-------|
# | Lookback | 6 months |
# | Rolling | `monthly` only |
# | Underlyings | SPY, AAPL, MSFT |
#
# ## Layout
# For each ticker: regimes 2008-2009 → 2019-2020; within each GBM → Merton → Heston → Heston–Merton → GARCH → GARCH–Merton.
# Each block: label + RMSE + three-panel graph.

# %% [markdown]
# # Underlying: `SPY`

# %% [markdown]
# ## Quick RMSE table — `SPY` · `monthly`
#
# | # | Regime | Model | RMSE | MAE | Bias |
# |---|--------|-------|-----:|----:|-----:|
# | 1 | 2008-2009 | GBM | **0.8139** | 0.6378 | 0.4067 |
# | 2 | 2008-2009 | Merton | **0.8320** | 0.6569 | 0.4366 |
# | 3 | 2008-2009 | Heston–Merton | **0.8097** | 0.6424 | 0.4524 |
# | 4 | 2008-2009 | GARCH–Merton | **0.6302** | 0.4605 | 0.2650 |
# | 5 | 2013-2014 | GBM | **0.4572** | 0.3682 | 0.3536 |
# | 6 | 2013-2014 | Merton | **0.4786** | 0.3845 | 0.3642 |
# | 7 | 2013-2014 | Heston | **0.6875** | 0.5181 | 0.5094 |
# | 8 | 2013-2014 | Heston–Merton | **0.5461** | 0.4037 | 0.4014 |
# | 9 | 2013-2014 | GARCH–Merton | **0.6103** | 0.4818 | 0.4801 |
# | 10 | 2018-2019 | GBM | **1.6168** | 1.2303 | 1.0662 |
# | 11 | 2018-2019 | Merton | **1.5545** | 1.2042 | 1.0642 |
# | 12 | 2018-2019 | Heston | **2.1207** | 1.6284 | 1.6284 |
# | 13 | 2018-2019 | Heston–Merton | **1.6964** | 1.2242 | 1.0677 |
# | 14 | 2018-2019 | GARCH–Merton | **3.0739** | 2.1487 | 2.1487 |
# | 15 | 2019-2020 | GBM | **1.7747** | 1.4128 | 1.2189 |
# | 16 | 2019-2020 | Merton | **1.8482** | 1.4788 | 1.2675 |
# | 17 | 2019-2020 | Heston | **2.1399** | 1.7009 | 1.6076 |
# | 18 | 2019-2020 | Heston–Merton | **1.9434** | 1.3476 | 1.1976 |
# | 19 | 2019-2020 | GARCH–Merton | **3.2224** | 2.3905 | 2.2648 |

# %% [markdown]
# ---
#
# ## Study 1/19 — GBM · 2008-2009 · SPY
#
# > **underlying=`SPY` · model=`GBM` · regime=`2008-2009` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.8139** |
# | MAE | 0.6378 |
# | Bias (model − market) | 0.4067 |
# | Mean early-exercise frac | 0.302 |
#
# ### Three-panel graph — GBM · 2008-2009 · SPY · `monthly`
#
# ![Study 1 SPY](results/SPY/figures/2008-2009_gbm/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 2/19 — Merton · 2008-2009 · SPY
#
# > **underlying=`SPY` · model=`Merton` · regime=`2008-2009` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.8320** |
# | MAE | 0.6569 |
# | Bias (model − market) | 0.4366 |
# | Mean early-exercise frac | 0.297 |
#
# ### Three-panel graph — Merton · 2008-2009 · SPY · `monthly`
#
# ![Study 2 SPY](results/SPY/figures/2008-2009_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 3/19 — Heston–Merton · 2008-2009 · SPY
#
# > **underlying=`SPY` · model=`Heston–Merton` · regime=`2008-2009` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.8097** |
# | MAE | 0.6424 |
# | Bias (model − market) | 0.4524 |
# | Mean early-exercise frac | 0.289 |
#
# ### Three-panel graph — Heston–Merton · 2008-2009 · SPY · `monthly`
#
# ![Study 3 SPY](results/SPY/figures/2008-2009_heston_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 4/19 — GARCH–Merton · 2008-2009 · SPY
#
# > **underlying=`SPY` · model=`GARCH–Merton` · regime=`2008-2009` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.6302** |
# | MAE | 0.4605 |
# | Bias (model − market) | 0.2650 |
# | Mean early-exercise frac | 0.235 |
#
# ### Three-panel graph — GARCH–Merton · 2008-2009 · SPY · `monthly`
#
# ![Study 4 SPY](results/SPY/figures/2008-2009_garch_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 5/19 — GBM · 2013-2014 · SPY
#
# > **underlying=`SPY` · model=`GBM` · regime=`2013-2014` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.4572** |
# | MAE | 0.3682 |
# | Bias (model − market) | 0.3536 |
# | Mean early-exercise frac | 0.354 |
#
# ### Three-panel graph — GBM · 2013-2014 · SPY · `monthly`
#
# ![Study 5 SPY](results/SPY/figures/2013-2014_gbm/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 6/19 — Merton · 2013-2014 · SPY
#
# > **underlying=`SPY` · model=`Merton` · regime=`2013-2014` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.4786** |
# | MAE | 0.3845 |
# | Bias (model − market) | 0.3642 |
# | Mean early-exercise frac | 0.308 |
#
# ### Three-panel graph — Merton · 2013-2014 · SPY · `monthly`
#
# ![Study 6 SPY](results/SPY/figures/2013-2014_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 7/19 — Heston · 2013-2014 · SPY
#
# > **underlying=`SPY` · model=`Heston` · regime=`2013-2014` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.6875** |
# | MAE | 0.5181 |
# | Bias (model − market) | 0.5094 |
# | Mean early-exercise frac | 0.385 |
#
# ### Three-panel graph — Heston · 2013-2014 · SPY · `monthly`
#
# ![Study 7 SPY](results/SPY/figures/2013-2014_heston/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 8/19 — Heston–Merton · 2013-2014 · SPY
#
# > **underlying=`SPY` · model=`Heston–Merton` · regime=`2013-2014` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.5461** |
# | MAE | 0.4037 |
# | Bias (model − market) | 0.4014 |
# | Mean early-exercise frac | 0.346 |
#
# ### Three-panel graph — Heston–Merton · 2013-2014 · SPY · `monthly`
#
# ![Study 8 SPY](results/SPY/figures/2013-2014_heston_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 9/19 — GARCH–Merton · 2013-2014 · SPY
#
# > **underlying=`SPY` · model=`GARCH–Merton` · regime=`2013-2014` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.6103** |
# | MAE | 0.4818 |
# | Bias (model − market) | 0.4801 |
# | Mean early-exercise frac | 0.306 |
#
# ### Three-panel graph — GARCH–Merton · 2013-2014 · SPY · `monthly`
#
# ![Study 9 SPY](results/SPY/figures/2013-2014_garch_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 10/19 — GBM · 2018-2019 · SPY
#
# > **underlying=`SPY` · model=`GBM` · regime=`2018-2019` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.6168** |
# | MAE | 1.2303 |
# | Bias (model − market) | 1.0662 |
# | Mean early-exercise frac | 0.262 |
#
# ### Three-panel graph — GBM · 2018-2019 · SPY · `monthly`
#
# ![Study 10 SPY](results/SPY/figures/2018-2019_gbm/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 11/19 — Merton · 2018-2019 · SPY
#
# > **underlying=`SPY` · model=`Merton` · regime=`2018-2019` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.5545** |
# | MAE | 1.2042 |
# | Bias (model − market) | 1.0642 |
# | Mean early-exercise frac | 0.225 |
#
# ### Three-panel graph — Merton · 2018-2019 · SPY · `monthly`
#
# ![Study 11 SPY](results/SPY/figures/2018-2019_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 12/19 — Heston · 2018-2019 · SPY
#
# > **underlying=`SPY` · model=`Heston` · regime=`2018-2019` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.1207** |
# | MAE | 1.6284 |
# | Bias (model − market) | 1.6284 |
# | Mean early-exercise frac | 0.296 |
#
# ### Three-panel graph — Heston · 2018-2019 · SPY · `monthly`
#
# ![Study 12 SPY](results/SPY/figures/2018-2019_heston/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 13/19 — Heston–Merton · 2018-2019 · SPY
#
# > **underlying=`SPY` · model=`Heston–Merton` · regime=`2018-2019` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.6964** |
# | MAE | 1.2242 |
# | Bias (model − market) | 1.0677 |
# | Mean early-exercise frac | 0.256 |
#
# ### Three-panel graph — Heston–Merton · 2018-2019 · SPY · `monthly`
#
# ![Study 13 SPY](results/SPY/figures/2018-2019_heston_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 14/19 — GARCH–Merton · 2018-2019 · SPY
#
# > **underlying=`SPY` · model=`GARCH–Merton` · regime=`2018-2019` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **3.0739** |
# | MAE | 2.1487 |
# | Bias (model − market) | 2.1487 |
# | Mean early-exercise frac | 0.233 |
#
# ### Three-panel graph — GARCH–Merton · 2018-2019 · SPY · `monthly`
#
# ![Study 14 SPY](results/SPY/figures/2018-2019_garch_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 15/19 — GBM · 2019-2020 · SPY
#
# > **underlying=`SPY` · model=`GBM` · regime=`2019-2020` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.7747** |
# | MAE | 1.4128 |
# | Bias (model − market) | 1.2189 |
# | Mean early-exercise frac | 0.286 |
#
# ### Three-panel graph — GBM · 2019-2020 · SPY · `monthly`
#
# ![Study 15 SPY](results/SPY/figures/2019-2020_gbm/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 16/19 — Merton · 2019-2020 · SPY
#
# > **underlying=`SPY` · model=`Merton` · regime=`2019-2020` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.8482** |
# | MAE | 1.4788 |
# | Bias (model − market) | 1.2675 |
# | Mean early-exercise frac | 0.222 |
#
# ### Three-panel graph — Merton · 2019-2020 · SPY · `monthly`
#
# ![Study 16 SPY](results/SPY/figures/2019-2020_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 17/19 — Heston · 2019-2020 · SPY
#
# > **underlying=`SPY` · model=`Heston` · regime=`2019-2020` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.1399** |
# | MAE | 1.7009 |
# | Bias (model − market) | 1.6076 |
# | Mean early-exercise frac | 0.316 |
#
# ### Three-panel graph — Heston · 2019-2020 · SPY · `monthly`
#
# ![Study 17 SPY](results/SPY/figures/2019-2020_heston/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 18/19 — Heston–Merton · 2019-2020 · SPY
#
# > **underlying=`SPY` · model=`Heston–Merton` · regime=`2019-2020` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.9434** |
# | MAE | 1.3476 |
# | Bias (model − market) | 1.1976 |
# | Mean early-exercise frac | 0.263 |
#
# ### Three-panel graph — Heston–Merton · 2019-2020 · SPY · `monthly`
#
# ![Study 18 SPY](results/SPY/figures/2019-2020_heston_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 19/19 — GARCH–Merton · 2019-2020 · SPY
#
# > **underlying=`SPY` · model=`GARCH–Merton` · regime=`2019-2020` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **3.2224** |
# | MAE | 2.3905 |
# | Bias (model − market) | 2.2648 |
# | Mean early-exercise frac | 0.197 |
#
# ### Three-panel graph — GARCH–Merton · 2019-2020 · SPY · `monthly`
#
# ![Study 19 SPY](results/SPY/figures/2019-2020_garch_merton/monthly_panel.png)

# %% [markdown]
# # Underlying: `AAPL`

# %% [markdown]
# ## Quick RMSE table — `AAPL` · `monthly`
#
# | # | Regime | Model | RMSE | MAE | Bias |
# |---|--------|-------|-----:|----:|-----:|
# | 1 | 2008-2009 | GBM | **2.2774** | 1.9362 | 1.6032 |
# | 2 | 2008-2009 | Merton | **2.2953** | 1.8750 | 1.5917 |
# | 3 | 2008-2009 | Heston–Merton | **4.8871** | 3.9083 | 3.5237 |
# | 4 | 2008-2009 | GARCH–Merton | **3.3749** | 2.4869 | 2.1342 |
# | 5 | 2013-2014 | GBM | **3.5486** | 2.6324 | 2.3981 |
# | 6 | 2013-2014 | Merton | **2.8581** | 2.2008 | 1.8925 |
# | 7 | 2013-2014 | Heston | **5.1793** | 3.7921 | 3.3986 |
# | 8 | 2013-2014 | Heston–Merton | **4.6153** | 3.3077 | 2.6565 |
# | 9 | 2013-2014 | GARCH–Merton | **7.4494** | 5.5961 | 5.5681 |
# | 10 | 2018-2019 | GBM | **2.0397** | 1.4420 | 0.9101 |
# | 11 | 2018-2019 | Merton | **1.9220** | 1.3646 | 0.8748 |
# | 12 | 2018-2019 | Heston | **1.9860** | 1.5933 | 1.5187 |
# | 13 | 2018-2019 | Heston–Merton | **2.0269** | 1.5306 | 1.4258 |
# | 14 | 2018-2019 | GARCH–Merton | **4.4022** | 2.7817 | 2.6328 |
# | 15 | 2019-2020 | GBM | **2.1914** | 1.7784 | 1.6347 |
# | 16 | 2019-2020 | Merton | **2.2049** | 1.8114 | 1.5987 |
# | 17 | 2019-2020 | Heston | **2.5283** | 2.3116 | 2.2867 |
# | 18 | 2019-2020 | Heston–Merton | **2.6207** | 2.2798 | 2.2506 |
# | 19 | 2019-2020 | GARCH–Merton | **4.1918** | 3.5054 | 3.4553 |

# %% [markdown]
# ---
#
# ## Study 1/19 — GBM · 2008-2009 · AAPL
#
# > **underlying=`AAPL` · model=`GBM` · regime=`2008-2009` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.2774** |
# | MAE | 1.9362 |
# | Bias (model − market) | 1.6032 |
# | Mean early-exercise frac | 0.250 |
#
# ### Three-panel graph — GBM · 2008-2009 · AAPL · `monthly`
#
# ![Study 1 AAPL](results/AAPL/figures/2008-2009_gbm/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 2/19 — Merton · 2008-2009 · AAPL
#
# > **underlying=`AAPL` · model=`Merton` · regime=`2008-2009` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.2953** |
# | MAE | 1.8750 |
# | Bias (model − market) | 1.5917 |
# | Mean early-exercise frac | 0.228 |
#
# ### Three-panel graph — Merton · 2008-2009 · AAPL · `monthly`
#
# ![Study 2 AAPL](results/AAPL/figures/2008-2009_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 3/19 — Heston–Merton · 2008-2009 · AAPL
#
# > **underlying=`AAPL` · model=`Heston–Merton` · regime=`2008-2009` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **4.8871** |
# | MAE | 3.9083 |
# | Bias (model − market) | 3.5237 |
# | Mean early-exercise frac | 0.159 |
#
# ### Three-panel graph — Heston–Merton · 2008-2009 · AAPL · `monthly`
#
# ![Study 3 AAPL](results/AAPL/figures/2008-2009_heston_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 4/19 — GARCH–Merton · 2008-2009 · AAPL
#
# > **underlying=`AAPL` · model=`GARCH–Merton` · regime=`2008-2009` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **3.3749** |
# | MAE | 2.4869 |
# | Bias (model − market) | 2.1342 |
# | Mean early-exercise frac | 0.184 |
#
# ### Three-panel graph — GARCH–Merton · 2008-2009 · AAPL · `monthly`
#
# ![Study 4 AAPL](results/AAPL/figures/2008-2009_garch_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 5/19 — GBM · 2013-2014 · AAPL
#
# > **underlying=`AAPL` · model=`GBM` · regime=`2013-2014` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **3.5486** |
# | MAE | 2.6324 |
# | Bias (model − market) | 2.3981 |
# | Mean early-exercise frac | 0.272 |
#
# ### Three-panel graph — GBM · 2013-2014 · AAPL · `monthly`
#
# ![Study 5 AAPL](results/AAPL/figures/2013-2014_gbm/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 6/19 — Merton · 2013-2014 · AAPL
#
# > **underlying=`AAPL` · model=`Merton` · regime=`2013-2014` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.8581** |
# | MAE | 2.2008 |
# | Bias (model − market) | 1.8925 |
# | Mean early-exercise frac | 0.232 |
#
# ### Three-panel graph — Merton · 2013-2014 · AAPL · `monthly`
#
# ![Study 6 AAPL](results/AAPL/figures/2013-2014_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 7/19 — Heston · 2013-2014 · AAPL
#
# > **underlying=`AAPL` · model=`Heston` · regime=`2013-2014` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **5.1793** |
# | MAE | 3.7921 |
# | Bias (model − market) | 3.3986 |
# | Mean early-exercise frac | 0.303 |
#
# ### Three-panel graph — Heston · 2013-2014 · AAPL · `monthly`
#
# ![Study 7 AAPL](results/AAPL/figures/2013-2014_heston/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 8/19 — Heston–Merton · 2013-2014 · AAPL
#
# > **underlying=`AAPL` · model=`Heston–Merton` · regime=`2013-2014` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **4.6153** |
# | MAE | 3.3077 |
# | Bias (model − market) | 2.6565 |
# | Mean early-exercise frac | 0.232 |
#
# ### Three-panel graph — Heston–Merton · 2013-2014 · AAPL · `monthly`
#
# ![Study 8 AAPL](results/AAPL/figures/2013-2014_heston_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 9/19 — GARCH–Merton · 2013-2014 · AAPL
#
# > **underlying=`AAPL` · model=`GARCH–Merton` · regime=`2013-2014` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **7.4494** |
# | MAE | 5.5961 |
# | Bias (model − market) | 5.5681 |
# | Mean early-exercise frac | 0.211 |
#
# ### Three-panel graph — GARCH–Merton · 2013-2014 · AAPL · `monthly`
#
# ![Study 9 AAPL](results/AAPL/figures/2013-2014_garch_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 10/19 — GBM · 2018-2019 · AAPL
#
# > **underlying=`AAPL` · model=`GBM` · regime=`2018-2019` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.0397** |
# | MAE | 1.4420 |
# | Bias (model − market) | 0.9101 |
# | Mean early-exercise frac | 0.233 |
#
# ### Three-panel graph — GBM · 2018-2019 · AAPL · `monthly`
#
# ![Study 10 AAPL](results/AAPL/figures/2018-2019_gbm/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 11/19 — Merton · 2018-2019 · AAPL
#
# > **underlying=`AAPL` · model=`Merton` · regime=`2018-2019` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.9220** |
# | MAE | 1.3646 |
# | Bias (model − market) | 0.8748 |
# | Mean early-exercise frac | 0.246 |
#
# ### Three-panel graph — Merton · 2018-2019 · AAPL · `monthly`
#
# ![Study 11 AAPL](results/AAPL/figures/2018-2019_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 12/19 — Heston · 2018-2019 · AAPL
#
# > **underlying=`AAPL` · model=`Heston` · regime=`2018-2019` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.9860** |
# | MAE | 1.5933 |
# | Bias (model − market) | 1.5187 |
# | Mean early-exercise frac | 0.308 |
#
# ### Three-panel graph — Heston · 2018-2019 · AAPL · `monthly`
#
# ![Study 12 AAPL](results/AAPL/figures/2018-2019_heston/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 13/19 — Heston–Merton · 2018-2019 · AAPL
#
# > **underlying=`AAPL` · model=`Heston–Merton` · regime=`2018-2019` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.0269** |
# | MAE | 1.5306 |
# | Bias (model − market) | 1.4258 |
# | Mean early-exercise frac | 0.244 |
#
# ### Three-panel graph — Heston–Merton · 2018-2019 · AAPL · `monthly`
#
# ![Study 13 AAPL](results/AAPL/figures/2018-2019_heston_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 14/19 — GARCH–Merton · 2018-2019 · AAPL
#
# > **underlying=`AAPL` · model=`GARCH–Merton` · regime=`2018-2019` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **4.4022** |
# | MAE | 2.7817 |
# | Bias (model − market) | 2.6328 |
# | Mean early-exercise frac | 0.222 |
#
# ### Three-panel graph — GARCH–Merton · 2018-2019 · AAPL · `monthly`
#
# ![Study 14 AAPL](results/AAPL/figures/2018-2019_garch_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 15/19 — GBM · 2019-2020 · AAPL
#
# > **underlying=`AAPL` · model=`GBM` · regime=`2019-2020` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.1914** |
# | MAE | 1.7784 |
# | Bias (model − market) | 1.6347 |
# | Mean early-exercise frac | 0.301 |
#
# ### Three-panel graph — GBM · 2019-2020 · AAPL · `monthly`
#
# ![Study 15 AAPL](results/AAPL/figures/2019-2020_gbm/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 16/19 — Merton · 2019-2020 · AAPL
#
# > **underlying=`AAPL` · model=`Merton` · regime=`2019-2020` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.2049** |
# | MAE | 1.8114 |
# | Bias (model − market) | 1.5987 |
# | Mean early-exercise frac | 0.274 |
#
# ### Three-panel graph — Merton · 2019-2020 · AAPL · `monthly`
#
# ![Study 16 AAPL](results/AAPL/figures/2019-2020_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 17/19 — Heston · 2019-2020 · AAPL
#
# > **underlying=`AAPL` · model=`Heston` · regime=`2019-2020` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.5283** |
# | MAE | 2.3116 |
# | Bias (model − market) | 2.2867 |
# | Mean early-exercise frac | 0.317 |
#
# ### Three-panel graph — Heston · 2019-2020 · AAPL · `monthly`
#
# ![Study 17 AAPL](results/AAPL/figures/2019-2020_heston/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 18/19 — Heston–Merton · 2019-2020 · AAPL
#
# > **underlying=`AAPL` · model=`Heston–Merton` · regime=`2019-2020` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.6207** |
# | MAE | 2.2798 |
# | Bias (model − market) | 2.2506 |
# | Mean early-exercise frac | 0.307 |
#
# ### Three-panel graph — Heston–Merton · 2019-2020 · AAPL · `monthly`
#
# ![Study 18 AAPL](results/AAPL/figures/2019-2020_heston_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 19/19 — GARCH–Merton · 2019-2020 · AAPL
#
# > **underlying=`AAPL` · model=`GARCH–Merton` · regime=`2019-2020` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **4.1918** |
# | MAE | 3.5054 |
# | Bias (model − market) | 3.4553 |
# | Mean early-exercise frac | 0.229 |
#
# ### Three-panel graph — GARCH–Merton · 2019-2020 · AAPL · `monthly`
#
# ![Study 19 AAPL](results/AAPL/figures/2019-2020_garch_merton/monthly_panel.png)

# %% [markdown]
# # Underlying: `MSFT`

# %% [markdown]
# ## Quick RMSE table — `MSFT` · `monthly`
#
# | # | Regime | Model | RMSE | MAE | Bias |
# |---|--------|-------|-----:|----:|-----:|
# | 1 | 2008-2009 | GBM | **0.5822** | 0.4708 | 0.3315 |
# | 2 | 2008-2009 | Merton | **0.5647** | 0.4665 | 0.3270 |
# | 3 | 2008-2009 | Heston–Merton | **1.4610** | 1.0351 | 0.8679 |
# | 4 | 2008-2009 | GARCH–Merton | **0.9186** | 0.7568 | 0.7402 |
# | 5 | 2013-2014 | GBM | **0.2378** | 0.1772 | 0.1415 |
# | 6 | 2013-2014 | Merton | **0.2305** | 0.1719 | 0.1344 |
# | 7 | 2013-2014 | Heston | **0.1601** | 0.1272 | 0.0984 |
# | 8 | 2013-2014 | Heston–Merton | **0.1684** | 0.1317 | 0.1023 |
# | 9 | 2013-2014 | GARCH–Merton | **0.4485** | 0.3563 | 0.3255 |
# | 10 | 2018-2019 | GBM | **1.0894** | 0.7308 | 0.3609 |
# | 11 | 2018-2019 | Merton | **1.0932** | 0.7454 | 0.3607 |
# | 12 | 2018-2019 | Heston | **0.8329** | 0.6957 | 0.1189 |
# | 13 | 2018-2019 | Heston–Merton | **0.7660** | 0.6293 | 0.3325 |
# | 14 | 2018-2019 | GARCH–Merton | **1.3586** | 0.9917 | 0.7258 |
# | 15 | 2019-2020 | GBM | **0.9960** | 0.7604 | 0.5521 |
# | 16 | 2019-2020 | Merton | **1.0564** | 0.7926 | 0.5889 |
# | 17 | 2019-2020 | Heston | **1.1264** | 0.8405 | 0.7737 |
# | 18 | 2019-2020 | Heston–Merton | **1.1295** | 0.7972 | 0.7242 |
# | 19 | 2019-2020 | GARCH–Merton | **1.5011** | 1.1000 | 0.9698 |

# %% [markdown]
# ---
#
# ## Study 1/19 — GBM · 2008-2009 · MSFT
#
# > **underlying=`MSFT` · model=`GBM` · regime=`2008-2009` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.5822** |
# | MAE | 0.4708 |
# | Bias (model − market) | 0.3315 |
# | Mean early-exercise frac | 0.283 |
#
# ### Three-panel graph — GBM · 2008-2009 · MSFT · `monthly`
#
# ![Study 1 MSFT](results/MSFT/figures/2008-2009_gbm/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 2/19 — Merton · 2008-2009 · MSFT
#
# > **underlying=`MSFT` · model=`Merton` · regime=`2008-2009` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.5647** |
# | MAE | 0.4665 |
# | Bias (model − market) | 0.3270 |
# | Mean early-exercise frac | 0.196 |
#
# ### Three-panel graph — Merton · 2008-2009 · MSFT · `monthly`
#
# ![Study 2 MSFT](results/MSFT/figures/2008-2009_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 3/19 — Heston–Merton · 2008-2009 · MSFT
#
# > **underlying=`MSFT` · model=`Heston–Merton` · regime=`2008-2009` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.4610** |
# | MAE | 1.0351 |
# | Bias (model − market) | 0.8679 |
# | Mean early-exercise frac | 0.192 |
#
# ### Three-panel graph — Heston–Merton · 2008-2009 · MSFT · `monthly`
#
# ![Study 3 MSFT](results/MSFT/figures/2008-2009_heston_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 4/19 — GARCH–Merton · 2008-2009 · MSFT
#
# > **underlying=`MSFT` · model=`GARCH–Merton` · regime=`2008-2009` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.9186** |
# | MAE | 0.7568 |
# | Bias (model − market) | 0.7402 |
# | Mean early-exercise frac | 0.206 |
#
# ### Three-panel graph — GARCH–Merton · 2008-2009 · MSFT · `monthly`
#
# ![Study 4 MSFT](results/MSFT/figures/2008-2009_garch_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 5/19 — GBM · 2013-2014 · MSFT
#
# > **underlying=`MSFT` · model=`GBM` · regime=`2013-2014` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.2378** |
# | MAE | 0.1772 |
# | Bias (model − market) | 0.1415 |
# | Mean early-exercise frac | 0.282 |
#
# ### Three-panel graph — GBM · 2013-2014 · MSFT · `monthly`
#
# ![Study 5 MSFT](results/MSFT/figures/2013-2014_gbm/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 6/19 — Merton · 2013-2014 · MSFT
#
# > **underlying=`MSFT` · model=`Merton` · regime=`2013-2014` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.2305** |
# | MAE | 0.1719 |
# | Bias (model − market) | 0.1344 |
# | Mean early-exercise frac | 0.232 |
#
# ### Three-panel graph — Merton · 2013-2014 · MSFT · `monthly`
#
# ![Study 6 MSFT](results/MSFT/figures/2013-2014_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 7/19 — Heston · 2013-2014 · MSFT
#
# > **underlying=`MSFT` · model=`Heston` · regime=`2013-2014` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.1601** |
# | MAE | 0.1272 |
# | Bias (model − market) | 0.0984 |
# | Mean early-exercise frac | 0.343 |
#
# ### Three-panel graph — Heston · 2013-2014 · MSFT · `monthly`
#
# ![Study 7 MSFT](results/MSFT/figures/2013-2014_heston/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 8/19 — Heston–Merton · 2013-2014 · MSFT
#
# > **underlying=`MSFT` · model=`Heston–Merton` · regime=`2013-2014` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.1684** |
# | MAE | 0.1317 |
# | Bias (model − market) | 0.1023 |
# | Mean early-exercise frac | 0.258 |
#
# ### Three-panel graph — Heston–Merton · 2013-2014 · MSFT · `monthly`
#
# ![Study 8 MSFT](results/MSFT/figures/2013-2014_heston_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 9/19 — GARCH–Merton · 2013-2014 · MSFT
#
# > **underlying=`MSFT` · model=`GARCH–Merton` · regime=`2013-2014` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.4485** |
# | MAE | 0.3563 |
# | Bias (model − market) | 0.3255 |
# | Mean early-exercise frac | 0.231 |
#
# ### Three-panel graph — GARCH–Merton · 2013-2014 · MSFT · `monthly`
#
# ![Study 9 MSFT](results/MSFT/figures/2013-2014_garch_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 10/19 — GBM · 2018-2019 · MSFT
#
# > **underlying=`MSFT` · model=`GBM` · regime=`2018-2019` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.0894** |
# | MAE | 0.7308 |
# | Bias (model − market) | 0.3609 |
# | Mean early-exercise frac | 0.277 |
#
# ### Three-panel graph — GBM · 2018-2019 · MSFT · `monthly`
#
# ![Study 10 MSFT](results/MSFT/figures/2018-2019_gbm/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 11/19 — Merton · 2018-2019 · MSFT
#
# > **underlying=`MSFT` · model=`Merton` · regime=`2018-2019` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.0932** |
# | MAE | 0.7454 |
# | Bias (model − market) | 0.3607 |
# | Mean early-exercise frac | 0.241 |
#
# ### Three-panel graph — Merton · 2018-2019 · MSFT · `monthly`
#
# ![Study 11 MSFT](results/MSFT/figures/2018-2019_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 12/19 — Heston · 2018-2019 · MSFT
#
# > **underlying=`MSFT` · model=`Heston` · regime=`2018-2019` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.8329** |
# | MAE | 0.6957 |
# | Bias (model − market) | 0.1189 |
# | Mean early-exercise frac | 0.318 |
#
# ### Three-panel graph — Heston · 2018-2019 · MSFT · `monthly`
#
# ![Study 12 MSFT](results/MSFT/figures/2018-2019_heston/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 13/19 — Heston–Merton · 2018-2019 · MSFT
#
# > **underlying=`MSFT` · model=`Heston–Merton` · regime=`2018-2019` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.7660** |
# | MAE | 0.6293 |
# | Bias (model − market) | 0.3325 |
# | Mean early-exercise frac | 0.280 |
#
# ### Three-panel graph — Heston–Merton · 2018-2019 · MSFT · `monthly`
#
# ![Study 13 MSFT](results/MSFT/figures/2018-2019_heston_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 14/19 — GARCH–Merton · 2018-2019 · MSFT
#
# > **underlying=`MSFT` · model=`GARCH–Merton` · regime=`2018-2019` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.3586** |
# | MAE | 0.9917 |
# | Bias (model − market) | 0.7258 |
# | Mean early-exercise frac | 0.227 |
#
# ### Three-panel graph — GARCH–Merton · 2018-2019 · MSFT · `monthly`
#
# ![Study 14 MSFT](results/MSFT/figures/2018-2019_garch_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 15/19 — GBM · 2019-2020 · MSFT
#
# > **underlying=`MSFT` · model=`GBM` · regime=`2019-2020` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.9960** |
# | MAE | 0.7604 |
# | Bias (model − market) | 0.5521 |
# | Mean early-exercise frac | 0.272 |
#
# ### Three-panel graph — GBM · 2019-2020 · MSFT · `monthly`
#
# ![Study 15 MSFT](results/MSFT/figures/2019-2020_gbm/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 16/19 — Merton · 2019-2020 · MSFT
#
# > **underlying=`MSFT` · model=`Merton` · regime=`2019-2020` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.0564** |
# | MAE | 0.7926 |
# | Bias (model − market) | 0.5889 |
# | Mean early-exercise frac | 0.271 |
#
# ### Three-panel graph — Merton · 2019-2020 · MSFT · `monthly`
#
# ![Study 16 MSFT](results/MSFT/figures/2019-2020_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 17/19 — Heston · 2019-2020 · MSFT
#
# > **underlying=`MSFT` · model=`Heston` · regime=`2019-2020` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.1264** |
# | MAE | 0.8405 |
# | Bias (model − market) | 0.7737 |
# | Mean early-exercise frac | 0.278 |
#
# ### Three-panel graph — Heston · 2019-2020 · MSFT · `monthly`
#
# ![Study 17 MSFT](results/MSFT/figures/2019-2020_heston/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 18/19 — Heston–Merton · 2019-2020 · MSFT
#
# > **underlying=`MSFT` · model=`Heston–Merton` · regime=`2019-2020` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.1295** |
# | MAE | 0.7972 |
# | Bias (model − market) | 0.7242 |
# | Mean early-exercise frac | 0.310 |
#
# ### Three-panel graph — Heston–Merton · 2019-2020 · MSFT · `monthly`
#
# ![Study 18 MSFT](results/MSFT/figures/2019-2020_heston_merton/monthly_panel.png)

# %% [markdown]
# ---
#
# ## Study 19/19 — GARCH–Merton · 2019-2020 · MSFT
#
# > **underlying=`MSFT` · model=`GARCH–Merton` · regime=`2019-2020` · rolling=`monthly` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.5011** |
# | MAE | 1.1000 |
# | Bias (model − market) | 0.9698 |
# | Mean early-exercise frac | 0.234 |
#
# ### Three-panel graph — GARCH–Merton · 2019-2020 · MSFT · `monthly`
#
# ![Study 19 MSFT](results/MSFT/figures/2019-2020_garch_merton/monthly_panel.png)
