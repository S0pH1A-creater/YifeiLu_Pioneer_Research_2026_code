# %% [markdown]
# # V2 Optimal stopping comparison — rolling = `none`
#
# **Source:** `V3-Models_result/results/{TICKER}/` after methodological fixes (see `V3_CHANGES.md`).
# Same contracts / seeds / LSM harness for **SPY**, **AAPL**, and **MSFT** (n=24, seed=42, n_paths=2000).
#
# | Fixed | Value |
# |-------|-------|
# | Lookback | 6 months |
# | Rolling | `none` only |
# | Underlyings | SPY, AAPL, MSFT |
#
# ## Layout
# For each ticker: regimes 2008-2009 → 2019-2020; within each GBM → Merton → Heston → Heston–Merton → GARCH → GARCH–Merton.
# Each block: label + RMSE + three-panel graph.

# %% [markdown]
# # Underlying: `SPY`

# %% [markdown]
# ## Quick RMSE table — `SPY` · `none`
#
# | # | Regime | Model | RMSE | MAE | Bias |
# |---|--------|-------|-----:|----:|-----:|
# | 1 | 2008-2009 | GBM | **0.6200** | 0.4401 | 0.1531 |
# | 2 | 2008-2009 | Merton | **0.6200** | 0.4401 | 0.1531 |
# | 3 | 2008-2009 | Heston–Merton | **0.5686** | 0.4244 | 0.1315 |
# | 4 | 2008-2009 | GARCH–Merton | **0.6538** | 0.4773 | 0.2535 |
# | 5 | 2013-2014 | GBM | **0.7724** | 0.6020 | 0.6020 |
# | 6 | 2013-2014 | Merton | **0.7667** | 0.5874 | 0.5846 |
# | 7 | 2013-2014 | Heston | **1.5771** | 1.2939 | 1.2939 |
# | 8 | 2013-2014 | Heston–Merton | **1.6189** | 1.3237 | 1.3237 |
# | 9 | 2013-2014 | GARCH–Merton | **1.0072** | 0.8093 | 0.8093 |
# | 10 | 2018-2019 | GBM | **0.9143** | 0.6779 | -0.6169 |
# | 11 | 2018-2019 | Merton | **0.8772** | 0.6495 | -0.6022 |
# | 12 | 2018-2019 | Heston | **1.8999** | 1.5289 | 1.5185 |
# | 13 | 2018-2019 | Heston–Merton | **1.9380** | 1.5526 | 1.5434 |
# | 14 | 2018-2019 | GARCH–Merton | **0.7625** | 0.5523 | -0.4911 |
# | 15 | 2019-2020 | GBM | **2.0618** | 1.8741 | 1.8556 |
# | 16 | 2019-2020 | Merton | **2.1733** | 1.9500 | 1.9500 |
# | 17 | 2019-2020 | Heston | **3.8858** | 3.5975 | 3.5975 |
# | 18 | 2019-2020 | Heston–Merton | **3.7852** | 3.4568 | 3.4568 |
# | 19 | 2019-2020 | GARCH–Merton | **7.2019** | 6.7792 | 6.7792 |

# %% [markdown]
# ---
#
# ## Study 1/19 — GBM · 2008-2009 · SPY
#
# > **underlying=`SPY` · model=`GBM` · regime=`2008-2009` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.6200** |
# | MAE | 0.4401 |
# | Bias (model − market) | 0.1531 |
# | Mean early-exercise frac | 0.299 |
#
# ### Three-panel graph — GBM · 2008-2009 · SPY · `none`
#
# ![Study 1 SPY](results/SPY/figures/2008-2009_gbm/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 2/19 — Merton · 2008-2009 · SPY
#
# > **underlying=`SPY` · model=`Merton` · regime=`2008-2009` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.6200** |
# | MAE | 0.4401 |
# | Bias (model − market) | 0.1531 |
# | Mean early-exercise frac | 0.299 |
#
# ### Three-panel graph — Merton · 2008-2009 · SPY · `none`
#
# ![Study 2 SPY](results/SPY/figures/2008-2009_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 3/19 — Heston–Merton · 2008-2009 · SPY
#
# > **underlying=`SPY` · model=`Heston–Merton` · regime=`2008-2009` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.5686** |
# | MAE | 0.4244 |
# | Bias (model − market) | 0.1315 |
# | Mean early-exercise frac | 0.339 |
#
# ### Three-panel graph — Heston–Merton · 2008-2009 · SPY · `none`
#
# ![Study 3 SPY](results/SPY/figures/2008-2009_heston_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 4/19 — GARCH–Merton · 2008-2009 · SPY
#
# > **underlying=`SPY` · model=`GARCH–Merton` · regime=`2008-2009` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.6538** |
# | MAE | 0.4773 |
# | Bias (model − market) | 0.2535 |
# | Mean early-exercise frac | 0.241 |
#
# ### Three-panel graph — GARCH–Merton · 2008-2009 · SPY · `none`
#
# ![Study 4 SPY](results/SPY/figures/2008-2009_garch_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 5/19 — GBM · 2013-2014 · SPY
#
# > **underlying=`SPY` · model=`GBM` · regime=`2013-2014` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.7724** |
# | MAE | 0.6020 |
# | Bias (model − market) | 0.6020 |
# | Mean early-exercise frac | 0.346 |
#
# ### Three-panel graph — GBM · 2013-2014 · SPY · `none`
#
# ![Study 5 SPY](results/SPY/figures/2013-2014_gbm/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 6/19 — Merton · 2013-2014 · SPY
#
# > **underlying=`SPY` · model=`Merton` · regime=`2013-2014` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.7667** |
# | MAE | 0.5874 |
# | Bias (model − market) | 0.5846 |
# | Mean early-exercise frac | 0.336 |
#
# ### Three-panel graph — Merton · 2013-2014 · SPY · `none`
#
# ![Study 6 SPY](results/SPY/figures/2013-2014_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 7/19 — Heston · 2013-2014 · SPY
#
# > **underlying=`SPY` · model=`Heston` · regime=`2013-2014` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.5771** |
# | MAE | 1.2939 |
# | Bias (model − market) | 1.2939 |
# | Mean early-exercise frac | 0.371 |
#
# ### Three-panel graph — Heston · 2013-2014 · SPY · `none`
#
# ![Study 7 SPY](results/SPY/figures/2013-2014_heston/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 8/19 — Heston–Merton · 2013-2014 · SPY
#
# > **underlying=`SPY` · model=`Heston–Merton` · regime=`2013-2014` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.6189** |
# | MAE | 1.3237 |
# | Bias (model − market) | 1.3237 |
# | Mean early-exercise frac | 0.354 |
#
# ### Three-panel graph — Heston–Merton · 2013-2014 · SPY · `none`
#
# ![Study 8 SPY](results/SPY/figures/2013-2014_heston_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 9/19 — GARCH–Merton · 2013-2014 · SPY
#
# > **underlying=`SPY` · model=`GARCH–Merton` · regime=`2013-2014` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.0072** |
# | MAE | 0.8093 |
# | Bias (model − market) | 0.8093 |
# | Mean early-exercise frac | 0.300 |
#
# ### Three-panel graph — GARCH–Merton · 2013-2014 · SPY · `none`
#
# ![Study 9 SPY](results/SPY/figures/2013-2014_garch_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 10/19 — GBM · 2018-2019 · SPY
#
# > **underlying=`SPY` · model=`GBM` · regime=`2018-2019` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.9143** |
# | MAE | 0.6779 |
# | Bias (model − market) | -0.6169 |
# | Mean early-exercise frac | 0.184 |
#
# ### Three-panel graph — GBM · 2018-2019 · SPY · `none`
#
# ![Study 10 SPY](results/SPY/figures/2018-2019_gbm/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 11/19 — Merton · 2018-2019 · SPY
#
# > **underlying=`SPY` · model=`Merton` · regime=`2018-2019` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.8772** |
# | MAE | 0.6495 |
# | Bias (model − market) | -0.6022 |
# | Mean early-exercise frac | 0.215 |
#
# ### Three-panel graph — Merton · 2018-2019 · SPY · `none`
#
# ![Study 11 SPY](results/SPY/figures/2018-2019_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 12/19 — Heston · 2018-2019 · SPY
#
# > **underlying=`SPY` · model=`Heston` · regime=`2018-2019` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.8999** |
# | MAE | 1.5289 |
# | Bias (model − market) | 1.5185 |
# | Mean early-exercise frac | 0.337 |
#
# ### Three-panel graph — Heston · 2018-2019 · SPY · `none`
#
# ![Study 12 SPY](results/SPY/figures/2018-2019_heston/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 13/19 — Heston–Merton · 2018-2019 · SPY
#
# > **underlying=`SPY` · model=`Heston–Merton` · regime=`2018-2019` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.9380** |
# | MAE | 1.5526 |
# | Bias (model − market) | 1.5434 |
# | Mean early-exercise frac | 0.318 |
#
# ### Three-panel graph — Heston–Merton · 2018-2019 · SPY · `none`
#
# ![Study 13 SPY](results/SPY/figures/2018-2019_heston_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 14/19 — GARCH–Merton · 2018-2019 · SPY
#
# > **underlying=`SPY` · model=`GARCH–Merton` · regime=`2018-2019` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.7625** |
# | MAE | 0.5523 |
# | Bias (model − market) | -0.4911 |
# | Mean early-exercise frac | 0.210 |
#
# ### Three-panel graph — GARCH–Merton · 2018-2019 · SPY · `none`
#
# ![Study 14 SPY](results/SPY/figures/2018-2019_garch_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 15/19 — GBM · 2019-2020 · SPY
#
# > **underlying=`SPY` · model=`GBM` · regime=`2019-2020` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.0618** |
# | MAE | 1.8741 |
# | Bias (model − market) | 1.8556 |
# | Mean early-exercise frac | 0.285 |
#
# ### Three-panel graph — GBM · 2019-2020 · SPY · `none`
#
# ![Study 15 SPY](results/SPY/figures/2019-2020_gbm/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 16/19 — Merton · 2019-2020 · SPY
#
# > **underlying=`SPY` · model=`Merton` · regime=`2019-2020` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.1733** |
# | MAE | 1.9500 |
# | Bias (model − market) | 1.9500 |
# | Mean early-exercise frac | 0.190 |
#
# ### Three-panel graph — Merton · 2019-2020 · SPY · `none`
#
# ![Study 16 SPY](results/SPY/figures/2019-2020_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 17/19 — Heston · 2019-2020 · SPY
#
# > **underlying=`SPY` · model=`Heston` · regime=`2019-2020` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **3.8858** |
# | MAE | 3.5975 |
# | Bias (model − market) | 3.5975 |
# | Mean early-exercise frac | 0.301 |
#
# ### Three-panel graph — Heston · 2019-2020 · SPY · `none`
#
# ![Study 17 SPY](results/SPY/figures/2019-2020_heston/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 18/19 — Heston–Merton · 2019-2020 · SPY
#
# > **underlying=`SPY` · model=`Heston–Merton` · regime=`2019-2020` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **3.7852** |
# | MAE | 3.4568 |
# | Bias (model − market) | 3.4568 |
# | Mean early-exercise frac | 0.288 |
#
# ### Three-panel graph — Heston–Merton · 2019-2020 · SPY · `none`
#
# ![Study 18 SPY](results/SPY/figures/2019-2020_heston_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 19/19 — GARCH–Merton · 2019-2020 · SPY
#
# > **underlying=`SPY` · model=`GARCH–Merton` · regime=`2019-2020` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **7.2019** |
# | MAE | 6.7792 |
# | Bias (model − market) | 6.7792 |
# | Mean early-exercise frac | 0.188 |
#
# ### Three-panel graph — GARCH–Merton · 2019-2020 · SPY · `none`
#
# ![Study 19 SPY](results/SPY/figures/2019-2020_garch_merton/none_panel.png)

# %% [markdown]
# # Underlying: `AAPL`

# %% [markdown]
# ## Quick RMSE table — `AAPL` · `none`
#
# | # | Regime | Model | RMSE | MAE | Bias |
# |---|--------|-------|-----:|----:|-----:|
# | 1 | 2008-2009 | GBM | **2.6818** | 2.2452 | 1.7229 |
# | 2 | 2008-2009 | Merton | **2.6862** | 2.2723 | 1.7733 |
# | 3 | 2008-2009 | Heston–Merton | **2.1383** | 1.7406 | 1.0709 |
# | 4 | 2008-2009 | GARCH–Merton | **3.0728** | 2.6049 | 2.2066 |
# | 5 | 2013-2014 | GBM | **5.0578** | 3.8875 | 3.6376 |
# | 6 | 2013-2014 | Merton | **4.3754** | 3.4310 | 3.1359 |
# | 7 | 2013-2014 | Heston | **9.0211** | 7.2012 | 7.0427 |
# | 8 | 2013-2014 | Heston–Merton | **8.4855** | 6.7266 | 6.5633 |
# | 9 | 2013-2014 | GARCH–Merton | **12.2803** | 10.2589 | 10.2589 |
# | 10 | 2018-2019 | GBM | **0.9192** | 0.7432 | -0.6415 |
# | 11 | 2018-2019 | Merton | **0.8663** | 0.6983 | -0.6017 |
# | 12 | 2018-2019 | Heston | **1.9530** | 1.6165 | 1.4002 |
# | 13 | 2018-2019 | Heston–Merton | **2.2353** | 1.8328 | 1.6432 |
# | 14 | 2018-2019 | GARCH–Merton | **0.6696** | 0.5564 | -0.2049 |
# | 15 | 2019-2020 | GBM | **3.2126** | 2.6738 | 2.6192 |
# | 16 | 2019-2020 | Merton | **3.1599** | 2.5943 | 2.5082 |
# | 17 | 2019-2020 | Heston | **6.6526** | 6.1334 | 6.1334 |
# | 18 | 2019-2020 | Heston–Merton | **7.2074** | 6.5932 | 6.5932 |
# | 19 | 2019-2020 | GARCH–Merton | **8.0466** | 7.1471 | 7.1471 |

# %% [markdown]
# ---
#
# ## Study 1/19 — GBM · 2008-2009 · AAPL
#
# > **underlying=`AAPL` · model=`GBM` · regime=`2008-2009` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.6818** |
# | MAE | 2.2452 |
# | Bias (model − market) | 1.7229 |
# | Mean early-exercise frac | 0.246 |
#
# ### Three-panel graph — GBM · 2008-2009 · AAPL · `none`
#
# ![Study 1 AAPL](results/AAPL/figures/2008-2009_gbm/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 2/19 — Merton · 2008-2009 · AAPL
#
# > **underlying=`AAPL` · model=`Merton` · regime=`2008-2009` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.6862** |
# | MAE | 2.2723 |
# | Bias (model − market) | 1.7733 |
# | Mean early-exercise frac | 0.233 |
#
# ### Three-panel graph — Merton · 2008-2009 · AAPL · `none`
#
# ![Study 2 AAPL](results/AAPL/figures/2008-2009_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 3/19 — Heston–Merton · 2008-2009 · AAPL
#
# > **underlying=`AAPL` · model=`Heston–Merton` · regime=`2008-2009` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.1383** |
# | MAE | 1.7406 |
# | Bias (model − market) | 1.0709 |
# | Mean early-exercise frac | 0.309 |
#
# ### Three-panel graph — Heston–Merton · 2008-2009 · AAPL · `none`
#
# ![Study 3 AAPL](results/AAPL/figures/2008-2009_heston_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 4/19 — GARCH–Merton · 2008-2009 · AAPL
#
# > **underlying=`AAPL` · model=`GARCH–Merton` · regime=`2008-2009` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **3.0728** |
# | MAE | 2.6049 |
# | Bias (model − market) | 2.2066 |
# | Mean early-exercise frac | 0.161 |
#
# ### Three-panel graph — GARCH–Merton · 2008-2009 · AAPL · `none`
#
# ![Study 4 AAPL](results/AAPL/figures/2008-2009_garch_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 5/19 — GBM · 2013-2014 · AAPL
#
# > **underlying=`AAPL` · model=`GBM` · regime=`2013-2014` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **5.0578** |
# | MAE | 3.8875 |
# | Bias (model − market) | 3.6376 |
# | Mean early-exercise frac | 0.271 |
#
# ### Three-panel graph — GBM · 2013-2014 · AAPL · `none`
#
# ![Study 5 AAPL](results/AAPL/figures/2013-2014_gbm/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 6/19 — Merton · 2013-2014 · AAPL
#
# > **underlying=`AAPL` · model=`Merton` · regime=`2013-2014` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **4.3754** |
# | MAE | 3.4310 |
# | Bias (model − market) | 3.1359 |
# | Mean early-exercise frac | 0.213 |
#
# ### Three-panel graph — Merton · 2013-2014 · AAPL · `none`
#
# ![Study 6 AAPL](results/AAPL/figures/2013-2014_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 7/19 — Heston · 2013-2014 · AAPL
#
# > **underlying=`AAPL` · model=`Heston` · regime=`2013-2014` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **9.0211** |
# | MAE | 7.2012 |
# | Bias (model − market) | 7.0427 |
# | Mean early-exercise frac | 0.277 |
#
# ### Three-panel graph — Heston · 2013-2014 · AAPL · `none`
#
# ![Study 7 AAPL](results/AAPL/figures/2013-2014_heston/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 8/19 — Heston–Merton · 2013-2014 · AAPL
#
# > **underlying=`AAPL` · model=`Heston–Merton` · regime=`2013-2014` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **8.4855** |
# | MAE | 6.7266 |
# | Bias (model − market) | 6.5633 |
# | Mean early-exercise frac | 0.221 |
#
# ### Three-panel graph — Heston–Merton · 2013-2014 · AAPL · `none`
#
# ![Study 8 AAPL](results/AAPL/figures/2013-2014_heston_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 9/19 — GARCH–Merton · 2013-2014 · AAPL
#
# > **underlying=`AAPL` · model=`GARCH–Merton` · regime=`2013-2014` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **12.2803** |
# | MAE | 10.2589 |
# | Bias (model − market) | 10.2589 |
# | Mean early-exercise frac | 0.178 |
#
# ### Three-panel graph — GARCH–Merton · 2013-2014 · AAPL · `none`
#
# ![Study 9 AAPL](results/AAPL/figures/2013-2014_garch_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 10/19 — GBM · 2018-2019 · AAPL
#
# > **underlying=`AAPL` · model=`GBM` · regime=`2018-2019` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.9192** |
# | MAE | 0.7432 |
# | Bias (model − market) | -0.6415 |
# | Mean early-exercise frac | 0.239 |
#
# ### Three-panel graph — GBM · 2018-2019 · AAPL · `none`
#
# ![Study 10 AAPL](results/AAPL/figures/2018-2019_gbm/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 11/19 — Merton · 2018-2019 · AAPL
#
# > **underlying=`AAPL` · model=`Merton` · regime=`2018-2019` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.8663** |
# | MAE | 0.6983 |
# | Bias (model − market) | -0.6017 |
# | Mean early-exercise frac | 0.249 |
#
# ### Three-panel graph — Merton · 2018-2019 · AAPL · `none`
#
# ![Study 11 AAPL](results/AAPL/figures/2018-2019_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 12/19 — Heston · 2018-2019 · AAPL
#
# > **underlying=`AAPL` · model=`Heston` · regime=`2018-2019` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.9530** |
# | MAE | 1.6165 |
# | Bias (model − market) | 1.4002 |
# | Mean early-exercise frac | 0.291 |
#
# ### Three-panel graph — Heston · 2018-2019 · AAPL · `none`
#
# ![Study 12 AAPL](results/AAPL/figures/2018-2019_heston/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 13/19 — Heston–Merton · 2018-2019 · AAPL
#
# > **underlying=`AAPL` · model=`Heston–Merton` · regime=`2018-2019` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.2353** |
# | MAE | 1.8328 |
# | Bias (model − market) | 1.6432 |
# | Mean early-exercise frac | 0.283 |
#
# ### Three-panel graph — Heston–Merton · 2018-2019 · AAPL · `none`
#
# ![Study 13 AAPL](results/AAPL/figures/2018-2019_heston_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 14/19 — GARCH–Merton · 2018-2019 · AAPL
#
# > **underlying=`AAPL` · model=`GARCH–Merton` · regime=`2018-2019` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.6696** |
# | MAE | 0.5564 |
# | Bias (model − market) | -0.2049 |
# | Mean early-exercise frac | 0.256 |
#
# ### Three-panel graph — GARCH–Merton · 2018-2019 · AAPL · `none`
#
# ![Study 14 AAPL](results/AAPL/figures/2018-2019_garch_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 15/19 — GBM · 2019-2020 · AAPL
#
# > **underlying=`AAPL` · model=`GBM` · regime=`2019-2020` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **3.2126** |
# | MAE | 2.6738 |
# | Bias (model − market) | 2.6192 |
# | Mean early-exercise frac | 0.295 |
#
# ### Three-panel graph — GBM · 2019-2020 · AAPL · `none`
#
# ![Study 15 AAPL](results/AAPL/figures/2019-2020_gbm/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 16/19 — Merton · 2019-2020 · AAPL
#
# > **underlying=`AAPL` · model=`Merton` · regime=`2019-2020` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **3.1599** |
# | MAE | 2.5943 |
# | Bias (model − market) | 2.5082 |
# | Mean early-exercise frac | 0.268 |
#
# ### Three-panel graph — Merton · 2019-2020 · AAPL · `none`
#
# ![Study 16 AAPL](results/AAPL/figures/2019-2020_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 17/19 — Heston · 2019-2020 · AAPL
#
# > **underlying=`AAPL` · model=`Heston` · regime=`2019-2020` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **6.6526** |
# | MAE | 6.1334 |
# | Bias (model − market) | 6.1334 |
# | Mean early-exercise frac | 0.343 |
#
# ### Three-panel graph — Heston · 2019-2020 · AAPL · `none`
#
# ![Study 17 AAPL](results/AAPL/figures/2019-2020_heston/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 18/19 — Heston–Merton · 2019-2020 · AAPL
#
# > **underlying=`AAPL` · model=`Heston–Merton` · regime=`2019-2020` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **7.2074** |
# | MAE | 6.5932 |
# | Bias (model − market) | 6.5932 |
# | Mean early-exercise frac | 0.295 |
#
# ### Three-panel graph — Heston–Merton · 2019-2020 · AAPL · `none`
#
# ![Study 18 AAPL](results/AAPL/figures/2019-2020_heston_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 19/19 — GARCH–Merton · 2019-2020 · AAPL
#
# > **underlying=`AAPL` · model=`GARCH–Merton` · regime=`2019-2020` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **8.0466** |
# | MAE | 7.1471 |
# | Bias (model − market) | 7.1471 |
# | Mean early-exercise frac | 0.208 |
#
# ### Three-panel graph — GARCH–Merton · 2019-2020 · AAPL · `none`
#
# ![Study 19 AAPL](results/AAPL/figures/2019-2020_garch_merton/none_panel.png)

# %% [markdown]
# # Underlying: `MSFT`

# %% [markdown]
# ## Quick RMSE table — `MSFT` · `none`
#
# | # | Regime | Model | RMSE | MAE | Bias |
# |---|--------|-------|-----:|----:|-----:|
# | 1 | 2008-2009 | GBM | **0.3358** | 0.2090 | -0.1033 |
# | 2 | 2008-2009 | Merton | **0.3426** | 0.2275 | -0.0974 |
# | 3 | 2008-2009 | Heston–Merton | **0.3301** | 0.2146 | -0.0945 |
# | 4 | 2008-2009 | GARCH–Merton | **0.4026** | 0.3296 | 0.1598 |
# | 5 | 2013-2014 | GBM | **0.2040** | 0.1647 | 0.1250 |
# | 6 | 2013-2014 | Merton | **0.2040** | 0.1647 | 0.1250 |
# | 7 | 2013-2014 | Heston | **0.3412** | 0.2805 | 0.2558 |
# | 8 | 2013-2014 | Heston–Merton | **0.3412** | 0.2805 | 0.2558 |
# | 9 | 2013-2014 | GARCH–Merton | **0.2338** | 0.1917 | 0.1596 |
# | 10 | 2018-2019 | GBM | **0.6724** | 0.4624 | -0.3920 |
# | 11 | 2018-2019 | Merton | **0.7817** | 0.5655 | -0.4468 |
# | 12 | 2018-2019 | Heston | **0.5027** | 0.4110 | 0.1097 |
# | 13 | 2018-2019 | Heston–Merton | **0.4981** | 0.4148 | 0.1474 |
# | 14 | 2018-2019 | GARCH–Merton | **0.6083** | 0.5206 | 0.2160 |
# | 15 | 2019-2020 | GBM | **1.4759** | 1.2637 | 1.2527 |
# | 16 | 2019-2020 | Merton | **1.5104** | 1.2809 | 1.2723 |
# | 17 | 2019-2020 | Heston | **2.8037** | 2.5701 | 2.5701 |
# | 18 | 2019-2020 | Heston–Merton | **2.8202** | 2.5587 | 2.5587 |
# | 19 | 2019-2020 | GARCH–Merton | **4.2725** | 3.8936 | 3.8936 |

# %% [markdown]
# ---
#
# ## Study 1/19 — GBM · 2008-2009 · MSFT
#
# > **underlying=`MSFT` · model=`GBM` · regime=`2008-2009` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.3358** |
# | MAE | 0.2090 |
# | Bias (model − market) | -0.1033 |
# | Mean early-exercise frac | 0.307 |
#
# ### Three-panel graph — GBM · 2008-2009 · MSFT · `none`
#
# ![Study 1 MSFT](results/MSFT/figures/2008-2009_gbm/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 2/19 — Merton · 2008-2009 · MSFT
#
# > **underlying=`MSFT` · model=`Merton` · regime=`2008-2009` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.3426** |
# | MAE | 0.2275 |
# | Bias (model − market) | -0.0974 |
# | Mean early-exercise frac | 0.307 |
#
# ### Three-panel graph — Merton · 2008-2009 · MSFT · `none`
#
# ![Study 2 MSFT](results/MSFT/figures/2008-2009_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 3/19 — Heston–Merton · 2008-2009 · MSFT
#
# > **underlying=`MSFT` · model=`Heston–Merton` · regime=`2008-2009` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.3301** |
# | MAE | 0.2146 |
# | Bias (model − market) | -0.0945 |
# | Mean early-exercise frac | 0.309 |
#
# ### Three-panel graph — Heston–Merton · 2008-2009 · MSFT · `none`
#
# ![Study 3 MSFT](results/MSFT/figures/2008-2009_heston_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 4/19 — GARCH–Merton · 2008-2009 · MSFT
#
# > **underlying=`MSFT` · model=`GARCH–Merton` · regime=`2008-2009` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.4026** |
# | MAE | 0.3296 |
# | Bias (model − market) | 0.1598 |
# | Mean early-exercise frac | 0.257 |
#
# ### Three-panel graph — GARCH–Merton · 2008-2009 · MSFT · `none`
#
# ![Study 4 MSFT](results/MSFT/figures/2008-2009_garch_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 5/19 — GBM · 2013-2014 · MSFT
#
# > **underlying=`MSFT` · model=`GBM` · regime=`2013-2014` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.2040** |
# | MAE | 0.1647 |
# | Bias (model − market) | 0.1250 |
# | Mean early-exercise frac | 0.307 |
#
# ### Three-panel graph — GBM · 2013-2014 · MSFT · `none`
#
# ![Study 5 MSFT](results/MSFT/figures/2013-2014_gbm/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 6/19 — Merton · 2013-2014 · MSFT
#
# > **underlying=`MSFT` · model=`Merton` · regime=`2013-2014` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.2040** |
# | MAE | 0.1647 |
# | Bias (model − market) | 0.1250 |
# | Mean early-exercise frac | 0.307 |
#
# ### Three-panel graph — Merton · 2013-2014 · MSFT · `none`
#
# ![Study 6 MSFT](results/MSFT/figures/2013-2014_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 7/19 — Heston · 2013-2014 · MSFT
#
# > **underlying=`MSFT` · model=`Heston` · regime=`2013-2014` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.3412** |
# | MAE | 0.2805 |
# | Bias (model − market) | 0.2558 |
# | Mean early-exercise frac | 0.319 |
#
# ### Three-panel graph — Heston · 2013-2014 · MSFT · `none`
#
# ![Study 7 MSFT](results/MSFT/figures/2013-2014_heston/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 8/19 — Heston–Merton · 2013-2014 · MSFT
#
# > **underlying=`MSFT` · model=`Heston–Merton` · regime=`2013-2014` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.3412** |
# | MAE | 0.2805 |
# | Bias (model − market) | 0.2558 |
# | Mean early-exercise frac | 0.319 |
#
# ### Three-panel graph — Heston–Merton · 2013-2014 · MSFT · `none`
#
# ![Study 8 MSFT](results/MSFT/figures/2013-2014_heston_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 9/19 — GARCH–Merton · 2013-2014 · MSFT
#
# > **underlying=`MSFT` · model=`GARCH–Merton` · regime=`2013-2014` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.2338** |
# | MAE | 0.1917 |
# | Bias (model − market) | 0.1596 |
# | Mean early-exercise frac | 0.234 |
#
# ### Three-panel graph — GARCH–Merton · 2013-2014 · MSFT · `none`
#
# ![Study 9 MSFT](results/MSFT/figures/2013-2014_garch_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 10/19 — GBM · 2018-2019 · MSFT
#
# > **underlying=`MSFT` · model=`GBM` · regime=`2018-2019` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.6724** |
# | MAE | 0.4624 |
# | Bias (model − market) | -0.3920 |
# | Mean early-exercise frac | 0.298 |
#
# ### Three-panel graph — GBM · 2018-2019 · MSFT · `none`
#
# ![Study 10 MSFT](results/MSFT/figures/2018-2019_gbm/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 11/19 — Merton · 2018-2019 · MSFT
#
# > **underlying=`MSFT` · model=`Merton` · regime=`2018-2019` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.7817** |
# | MAE | 0.5655 |
# | Bias (model − market) | -0.4468 |
# | Mean early-exercise frac | 0.244 |
#
# ### Three-panel graph — Merton · 2018-2019 · MSFT · `none`
#
# ![Study 11 MSFT](results/MSFT/figures/2018-2019_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 12/19 — Heston · 2018-2019 · MSFT
#
# > **underlying=`MSFT` · model=`Heston` · regime=`2018-2019` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.5027** |
# | MAE | 0.4110 |
# | Bias (model − market) | 0.1097 |
# | Mean early-exercise frac | 0.309 |
#
# ### Three-panel graph — Heston · 2018-2019 · MSFT · `none`
#
# ![Study 12 MSFT](results/MSFT/figures/2018-2019_heston/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 13/19 — Heston–Merton · 2018-2019 · MSFT
#
# > **underlying=`MSFT` · model=`Heston–Merton` · regime=`2018-2019` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.4981** |
# | MAE | 0.4148 |
# | Bias (model − market) | 0.1474 |
# | Mean early-exercise frac | 0.257 |
#
# ### Three-panel graph — Heston–Merton · 2018-2019 · MSFT · `none`
#
# ![Study 13 MSFT](results/MSFT/figures/2018-2019_heston_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 14/19 — GARCH–Merton · 2018-2019 · MSFT
#
# > **underlying=`MSFT` · model=`GARCH–Merton` · regime=`2018-2019` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **0.6083** |
# | MAE | 0.5206 |
# | Bias (model − market) | 0.2160 |
# | Mean early-exercise frac | 0.274 |
#
# ### Three-panel graph — GARCH–Merton · 2018-2019 · MSFT · `none`
#
# ![Study 14 MSFT](results/MSFT/figures/2018-2019_garch_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 15/19 — GBM · 2019-2020 · MSFT
#
# > **underlying=`MSFT` · model=`GBM` · regime=`2019-2020` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.4759** |
# | MAE | 1.2637 |
# | Bias (model − market) | 1.2527 |
# | Mean early-exercise frac | 0.261 |
#
# ### Three-panel graph — GBM · 2019-2020 · MSFT · `none`
#
# ![Study 15 MSFT](results/MSFT/figures/2019-2020_gbm/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 16/19 — Merton · 2019-2020 · MSFT
#
# > **underlying=`MSFT` · model=`Merton` · regime=`2019-2020` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **1.5104** |
# | MAE | 1.2809 |
# | Bias (model − market) | 1.2723 |
# | Mean early-exercise frac | 0.248 |
#
# ### Three-panel graph — Merton · 2019-2020 · MSFT · `none`
#
# ![Study 16 MSFT](results/MSFT/figures/2019-2020_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 17/19 — Heston · 2019-2020 · MSFT
#
# > **underlying=`MSFT` · model=`Heston` · regime=`2019-2020` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.8037** |
# | MAE | 2.5701 |
# | Bias (model − market) | 2.5701 |
# | Mean early-exercise frac | 0.263 |
#
# ### Three-panel graph — Heston · 2019-2020 · MSFT · `none`
#
# ![Study 17 MSFT](results/MSFT/figures/2019-2020_heston/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 18/19 — Heston–Merton · 2019-2020 · MSFT
#
# > **underlying=`MSFT` · model=`Heston–Merton` · regime=`2019-2020` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **2.8202** |
# | MAE | 2.5587 |
# | Bias (model − market) | 2.5587 |
# | Mean early-exercise frac | 0.270 |
#
# ### Three-panel graph — Heston–Merton · 2019-2020 · MSFT · `none`
#
# ![Study 18 MSFT](results/MSFT/figures/2019-2020_heston_merton/none_panel.png)

# %% [markdown]
# ---
#
# ## Study 19/19 — GARCH–Merton · 2019-2020 · MSFT
#
# > **underlying=`MSFT` · model=`GARCH–Merton` · regime=`2019-2020` · rolling=`none` · lookback=6 months**
#
# | Metric | Value |
# |--------|------:|
# | **RMSE** | **4.2725** |
# | MAE | 3.8936 |
# | Bias (model − market) | 3.8936 |
# | Mean early-exercise frac | 0.183 |
#
# ### Three-panel graph — GARCH–Merton · 2019-2020 · MSFT · `none`
#
# ![Study 19 MSFT](results/MSFT/figures/2019-2020_garch_merton/none_panel.png)
